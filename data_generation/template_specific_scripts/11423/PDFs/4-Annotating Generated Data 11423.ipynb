# %%
import pandas as pd
df = pd.read_excel("11423.xlsx")

# %%
number=0
while True:

    names='11423_'+str(number)
    if number==1400:
        break

    import pdfquery
    # loading a pdf
    pdf = pdfquery.PDFQuery(names+".pdf")
    pdf.load()
    # if you want, you can store the entire pdf as an xml file

    pdf.tree.write(names+".xml", pretty_print=True, encoding="utf-8")
    import xml.etree.ElementTree as ET
    tree = ET.parse(names+'.xml')
    root = tree.getroot()

    author=df['author'][number]
    title=df['title'][number]
    journal=df['journal'][number]
    date="August "+ str(df['year'][number])
    affiliation=df['affiliation'][number]
    
    bounding_box_list=[]
    author_list=[]
    title_list=[]
    journal_list=[]
    #doi_list=[]
    date_list=[]
    #abstract_list=[]
    #address_list=[]
    affiliation_list=[]
    #email_list=[]

    for child in root:
        print('START')
        print (child.tag,"----", child.attrib)
        for fchild in child:
            #print('----------------------------')
            print(fchild)
            #print('----------------------------')
            print (fchild.tag,"----", fchild.attrib)
            for ffchild in fchild:
                print (ffchild.tag,"----", ffchild.attrib)
                print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
                print(ffchild.text)
                #print(ffchild.attrib['x0'])

                try:
                    bounding_box_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                            ffchild.attrib['y1']]])

                    if ffchild.text.strip() in author and ffchild.text.strip() is not '' and len(ffchild.text.strip())>5:
                        author_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                          ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in title and ffchild.text.strip() is not '' and len(ffchild.text.strip())>5:
                        title_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                         ffchild.attrib['y1']]])
                    elif journal in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>5:
                        journal_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in journal and ffchild.text.strip() is not '' and len(ffchild.text.strip())>5:
                        journal_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
                    elif date in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>3:
                        date_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
                    elif affiliation in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>5:
                        affiliation_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in affiliation and ffchild.text.strip() is not '' and len(ffchild.text.strip())>5:
                        affiliation_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
                
                except:
                    continue
                #print(ffchild)
            print('END')
            print('\n')

    coordinates_author = []
    coordinates_title = []
    coordinates_journal = []
    #coordinates_doi=[]
    coordinates_date=[]
    #coordinates_abstract=[]
    #coordinates_address=[]
    coordinates_affiliation=[]
    #coordinates_email=[]

    try:
        lst1=[]
        lst2=[]
        lst3=[]
        lst4=[]

        for lst in author_list:
            bboxes=lst[1]

            lst1.append([float(bboxes[0])])
            lst2.append([float(bboxes[1])])
            lst3.append([842-float(bboxes[2])])
            lst4.append([842-float(bboxes[3])])  
        apt1=[min(lst1)[0]-15,min(lst4)[0]-5]
        apt2=[min(lst1)[0]-15,max(lst3)[0]+5]
        apt3=[max(lst2)[0]+5,max(lst3)[0]+5]
        apt4=[max(lst2)[0]+5,min(lst4)[0]-5]
        coordinates_author.append([ apt1,apt2,apt3,apt4 ])  
        print('-----------')
        print(coordinates_author)


        tlst1=[]
        tlst2=[]
        tlst3=[]
        tlst4=[]

        for lst in title_list:
            bboxes=lst[1]

            tlst1.append([float(bboxes[0])])
            tlst2.append([float(bboxes[1])])
            tlst3.append([842-float(bboxes[2])])
            tlst4.append([842-float(bboxes[3])])  
        tpt1=[min(tlst1)[0]-15,min(tlst4)[0]-5]
        tpt2=[min(tlst1)[0]-15,max(tlst3)[0]+15]
        tpt3=[max(tlst2)[0]+5,max(tlst3)[0]+15]
        tpt4=[max(tlst2)[0]+5,min(tlst4)[0]-5]
        coordinates_title.append([ tpt1,tpt2,tpt3,tpt4 ])  
        print('-----------')
        print(coordinates_title)


        if journal.strip()=="ZUMA Nachrichten":
            addd=len(journal)*6
        else:
            addd=len(journal)*4.855555

        coordinates_journal.append([ [float(543-addd-10),float(38)],[float(543-addd-10),float(75)],[float(543),float(75)],[float(543),float(38)] ])
        coordinates_date.append([ [float(476),float(22)],[float(476),float(34)],[float(535),float(34)],[float(535),float(22)] ])

        add=len(affiliation)*4.2
        coordinates_affiliation.append([ [float(51),float(13)],[float(51),float(48)],[float(51+10+add),float(48)],[float(51+10+add),float(13)] ])
        print(coordinates_affiliation)
        
    except:
        number=number+1
        continue
    lst=[coordinates_author,coordinates_title,coordinates_journal,coordinates_date,coordinates_affiliation]

    abase = {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a1base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a2base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a3base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a4base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    tbase = {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t1base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t2base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t3base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t4base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t5base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t6base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t7base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t8base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    jbase = {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j1base = {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j2base = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
    j3base = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
    dbase = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    d1base = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    dabase = {
          "label": "date",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    da1base = {
          "label": "date",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    absbase = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs1base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs2base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs3base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs4base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs5base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs6base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs7base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs8base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs9base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs10base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs11base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs12base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs13base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs14base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs15base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs16base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs17base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs18base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs19base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs20base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs21base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    absbase2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs1base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs2base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs3base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs4base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs5base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs6base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs7base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs8base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs9base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs10base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs11base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs12base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs13base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs14base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs15base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs16base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs17base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs18base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs19base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs20base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs21base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    
    adbase = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ad1base = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    afbase = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    af1base = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ebase = {
          "label": "email",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    e1base = {
          "label": "email",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    
    
    ab=[abase,a1base,a2base,a3base,a4base]
    tb=[tbase,t1base,t2base,t3base,t4base,t5base,t6base,t7base,t8base]
    jb=[jbase,j1base,j2base,j3base]
    db=[dbase,d1base]
    dab=[dabase,da1base]
    absb=[absbase,abs1base,abs2base,abs3base,abs4base,abs5base,abs6base,abs7base,abs8base,abs9base,abs10base,abs11base,abs12base,abs13base,abs14base,abs15base,abs16base,abs17base,abs18base,abs19base,abs20base,abs21base]
    abs2b=[absbase2,abs1base2,abs2base2,abs3base2,abs4base2,abs5base2,abs6base2,abs7base2,abs8base2,abs9base2,abs10base2,abs11base2,abs12base2,abs13base2,abs14base2,abs15base2,abs16base2,abs17base2,abs18base2,abs19base2,abs20base2,abs21base2]
    adb=[adbase,ad1base]
    afb=[afbase,af1base]
    eb=[ebase,e1base]

    
    liste=[]
    try:
        counter=0
        for no in range(len(coordinates_author)):   

            ab[counter]['points']=lst[0][counter]
            print(ab[counter])
            liste.append(ab[counter])
            counter=counter+1

        counter=0
        for no in range(len(coordinates_title)):   

            tb[counter]['points']=lst[1][counter]
            print(tb[counter])
            liste.append(tb[counter])
            counter=counter+1    

        counter=0
        for no in range(len(coordinates_journal)):   

            jb[counter]['points']=lst[2][counter]
            print(jb[counter])
            liste.append(jb[counter])
            counter=counter+1
        
        counter=0
        for no in range(len(coordinates_date)):   

            dab[counter]['points']=lst[3][counter]
            print(dab[counter])
            liste.append(dab[counter])
            counter=counter+1 
            
        counter=0
        for no in range(len(coordinates_affiliation)):   

            afb[counter]['points']=lst[4][counter]
            print(afb[counter])
            liste.append(afb[counter])
            counter=counter+1 
            
    
    except:
        print('============================================================================')
        print(number)
        number=number+1
        continue

    import base64
    import json

    file=names+".jpeg"
    image_data = base64.b64encode(open(file, "rb").read())
    imagedata=str(image_data)[1:].replace("'","")

    x ='''[{
      "version": "4.4.0",  "flags": {},

      "shapes": [
        {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "group_id": null,"shape_type": "polygon", "flags": {}
        },

        {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
          "group_id": null, "shape_type": "polygon","flags": {}
        },

        {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "group_id": null,"shape_type": "polygon","flags": {}
        }  ],

      "imagePath": "6041.jpg",
      "imageData": "...",
      "imageHeight": 2339,
      "imageWidth": 1653
    }]'''

    try:
        info=json.loads(x)
        print('User count', len(info))
        print("-------------")

        info[0]['shapes']=liste

        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
        print(info[0]['shapes'])
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

        info[0]['imageData']=imagedata
        info[0]['imagePath']=file
        print("-------------------------------------------------------------------------------------------")

        for key in info:
            my_details=key
        name=names+".json"
        with open(name, 'w') as json_file:
            json.dump(my_details, json_file)
    except:
        
        print('============================================================================')
        print(number)
        number=number+1
        continue

    print('============================================================================')
    print(number)
    number=number+1
# Out:
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1d5b7afe208>
# LTTextLineHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.025', 'x1': '280.46', 'width': '221.435', 'height': '10.56', 'bbox': '[59.025, 701.562, 280.46, 712.122]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.025', 'x1': '280.46', 'width': '221.435', 'height': '10.56', 'bbox': '[59.025, 701.562, 280.46, 712.122]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# iqing Luo, Zuming Liu, Sucai Luo, Xigang Yuan
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7afef48>
# LTTextBoxHorizontal ---- {'y0': '552.31', 'y1': '685.96', 'x0': '51.96', 'x1': '528.9', 'width': '476.94', 'height': '133.65', 'bbox': '[51.96, 552.31, 528.9, 685.96]', 'index': '5'}
# LTTextLineHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '70.29', 'x1': '485.41', 'width': '415.12', 'height': '30.0', 'bbox': '[70.29, 655.96, 485.41, 685.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hermodynamic analysis of non-
# LTTextLineHorizontal ---- {'y0': '621.52', 'y1': '651.52', 'x0': '51.96', 'x1': '528.9', 'width': '476.94', 'height': '30.0', 'bbox': '[51.96, 621.52, 528.9, 651.52]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# isothermal mixings influence on the
# LTTextLineHorizontal ---- {'y0': '586.96', 'y1': '616.96', 'x0': '51.96', 'x1': '433.75', 'width': '381.79', 'height': '30.0', 'bbox': '[51.96, 586.96, 433.75, 616.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# energy target of water-using
# LTTextLineHorizontal ---- {'y0': '552.31', 'y1': '582.49', 'x0': '51.96', 'x1': '187.79', 'width': '135.83', 'height': '30.18', 'bbox': '[51.96, 552.31, 187.79, 582.49]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# networks.
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7afef08>
# LTTextBoxHorizontal ---- {'y0': '66.873', 'y1': '115.25', 'x0': '51.96', 'x1': '413.173', 'width': '361.213', 'height': '48.377', 'bbox': '[51.96, 66.873, 413.173, 115.25]', 'index': '6'}
# LTTextLineHorizontal ---- {'y0': '106.25', 'y1': '115.25', 'x0': '57.963', 'x1': '413.173', 'width': '355.21', 'height': '9.0', 'bbox': '[57.963, 106.25, 413.173, 115.25]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '51.96', 'x1': '141.996', 'width': '90.036', 'height': '9.0', 'bbox': '[51.96, 93.174, 141.996, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '401.511', 'x1': '412.887', 'width': '11.376', 'height': '9.0', 'bbox': '[401.511, 93.174, 412.887, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# LTTextLineHorizontal ---- {'y0': '80.214', 'y1': '89.214', 'x0': '51.96', 'x1': '412.913', 'width': '360.953', 'height': '9.0', 'bbox': '[51.96, 80.214, 412.913, 89.214]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# LTTextLineHorizontal ---- {'y0': '66.873', 'y1': '76.833', 'x0': '51.96', 'x1': '205.1', 'width': '153.14', 'height': '9.96', 'bbox': '[51.96, 66.873, 205.1, 76.833]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# angewandte Politikforschung (C·A·P).
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '147.765', 'x1': '395.859', 'width': '248.094', 'height': '9.0', 'bbox': '[147.765, 93.174, 395.859, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b5fbec88>
# LTTextLineVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '59.004', 'width': '7.044', 'height': '73.926', 'bbox': '[51.96, 701.562, 59.004, 775.488]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '59.004', 'width': '7.044', 'height': '73.926', 'bbox': '[51.96, 701.562, 59.004, 775.488]', 'index': '9'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Y
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b5fbe248>
# LTTextLineHorizontal ---- {'y0': '542.398', 'y1': '554.398', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 542.398, 54.96, 554.398]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '542.398', 'y1': '554.398', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 542.398, 54.96, 554.398]', 'index': '10'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7e252c8>
# LTTextLineVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '70.29', 'width': '18.33', 'height': '45.948', 'bbox': '[51.96, 655.96, 70.29, 701.908]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '70.29', 'width': '18.33', 'height': '45.948', 'bbox': '[51.96, 655.96, 70.29, 701.908]', 'index': '11'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  T
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7e25088>
# LTTextLineVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'index': '12'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b5fba748>
# LTTextLineVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'index': '13'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTImage' at 0x1d5b5fba588>
# LTImage ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[964, 1]', 'stream': "<PDFStream(5): raw=35, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 964, 'Height': 1, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 33}>"}
# LTFigure ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 55.819]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTImage' at 0x1d5b7db6c48>
# LTImage ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[1315, 86]', 'stream': "<PDFStream(12): raw=357, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 1315, 'Height': 86, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 355}>"}
# LTFigure ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'matrix': '[493.25, 0.0, 0.0, 36.0, 51.05, 805.12]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# <Element 'LTImage' at 0x1d5b5b11d48>
# LTImage ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[323, 80]', 'stream': "<PDFStream(13): raw=106, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 323, 'Height': 80, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 104}>"}
# LTFigure ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'matrix': '[287.45, 0.0, 0.0, 32.596, 256.3, 772.47]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# ['59.025', '280.46', '701.562', '712.122']
# -----------
# [[[49.025, 129.87800000000004], [49.025, 140.438], [280.46, 140.438], [280.46, 129.87800000000004]]]
# ['70.29', '485.41', '655.96', '685.96']
# ['51.96', '528.9', '621.52', '651.52']
# ['51.96', '433.75', '586.96', '616.96']
# ['51.96', '187.79', '552.31', '582.49']
# -----------
# [[[41.96, 156.03999999999996], [41.96, 289.69000000000005], [528.9, 289.69000000000005], [528.9, 156.03999999999996]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# [[[51.0, 18.0], [51.0, 33.0], [168.60000000000002, 33.0], [168.60000000000002, 18.0]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# {'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [280.46, 140.438], [280.46, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 289.69000000000005], [528.9, 289.69000000000005], [528.9, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [168.60000000000002, 33.0], [168.60000000000002, 18.0]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [{'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [280.46, 140.438], [280.46, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 289.69000000000005], [528.9, 289.69000000000005], [528.9, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [168.60000000000002, 33.0], [168.60000000000002, 18.0]], 'shape_type': 'polygon', 'flags': {}}]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------------------------------------------------------------------------------------------
# ============================================================================
# 0
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1d5b7b8c088>
# LTTextLineHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '76.95', 'x1': '528.86', 'width': '451.91', 'height': '30.0', 'bbox': '[76.95, 655.96, 528.86, 685.96]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '76.95', 'x1': '528.86', 'width': '451.91', 'height': '30.0', 'bbox': '[76.95, 655.96, 528.86, 685.96]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ILP-based optimization of oxygen
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7b8c188>
# LTTextBoxHorizontal ---- {'y0': '586.78', 'y1': '651.52', 'x0': '51.96', 'x1': '482.13', 'width': '430.17', 'height': '64.74', 'bbox': '[51.96, 586.78, 482.13, 651.52]', 'index': '5'}
# LTTextLineHorizontal ---- {'y0': '621.52', 'y1': '651.52', 'x0': '51.96', 'x1': '482.13', 'width': '430.17', 'height': '30.0', 'bbox': '[51.96, 621.52, 482.13, 651.52]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# distribution system in integrated
# LTTextLineHorizontal ---- {'y0': '586.78', 'y1': '616.96', 'x0': '51.96', 'x1': '199.43', 'width': '147.47', 'height': '30.18', 'bbox': '[51.96, 586.78, 199.43, 616.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# steel mills.
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7cdbc48>
# LTTextLineHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.025', 'x1': '216.26', 'width': '157.235', 'height': '10.56', 'bbox': '[59.025, 701.562, 216.26, 712.122]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.025', 'x1': '216.26', 'width': '157.235', 'height': '10.56', 'bbox': '[59.025, 701.562, 216.26, 712.122]', 'index': '6'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# eikun Zhang, Li Wang, Lige Tong
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7cdb508>
# LTTextLineVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '76.95', 'width': '24.99', 'height': '45.948', 'bbox': '[51.96, 655.96, 76.95, 701.908]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '76.95', 'width': '24.99', 'height': '45.948', 'bbox': '[51.96, 655.96, 76.95, 701.908]', 'index': '7'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  M
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7e6a208>
# LTTextBoxHorizontal ---- {'y0': '66.873', 'y1': '115.25', 'x0': '51.96', 'x1': '413.173', 'width': '361.213', 'height': '48.377', 'bbox': '[51.96, 66.873, 413.173, 115.25]', 'index': '8'}
# LTTextLineHorizontal ---- {'y0': '106.25', 'y1': '115.25', 'x0': '57.963', 'x1': '413.173', 'width': '355.21', 'height': '9.0', 'bbox': '[57.963, 106.25, 413.173, 115.25]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '51.96', 'x1': '141.996', 'width': '90.036', 'height': '9.0', 'bbox': '[51.96, 93.174, 141.996, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '401.511', 'x1': '412.887', 'width': '11.376', 'height': '9.0', 'bbox': '[401.511, 93.174, 412.887, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# LTTextLineHorizontal ---- {'y0': '80.214', 'y1': '89.214', 'x0': '51.96', 'x1': '412.788', 'width': '360.828', 'height': '9.0', 'bbox': '[51.96, 80.214, 412.788, 89.214]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# LTTextLineHorizontal ---- {'y0': '66.873', 'y1': '76.833', 'x0': '51.96', 'x1': '205.1', 'width': '153.14', 'height': '9.96', 'bbox': '[51.96, 66.873, 205.1, 76.833]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# angewandte Politikforschung (C·A·P).
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '147.765', 'x1': '395.859', 'width': '248.094', 'height': '9.0', 'bbox': '[147.765, 93.174, 395.859, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7b82408>
# LTTextLineVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '59.004', 'width': '7.044', 'height': '73.926', 'bbox': '[51.96, 701.562, 59.004, 775.488]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '59.004', 'width': '7.044', 'height': '73.926', 'bbox': '[51.96, 701.562, 59.004, 775.488]', 'index': '11'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  P
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7d3d848>
# LTTextLineHorizontal ---- {'y0': '576.958', 'y1': '588.958', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 576.958, 54.96, 588.958]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '576.958', 'y1': '588.958', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 576.958, 54.96, 588.958]', 'index': '12'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7d3d808>
# LTTextLineVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'index': '13'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7e73788>
# LTTextLineVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'index': '14'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7d50148>
# LTImage ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[964, 1]', 'stream': "<PDFStream(5): raw=35, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 964, 'Height': 1, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 33}>"}
# LTFigure ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 55.819]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTImage' at 0x1d5b7cd4088>
# LTImage ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[1315, 86]', 'stream': "<PDFStream(12): raw=357, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 1315, 'Height': 86, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 355}>"}
# LTFigure ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'matrix': '[493.25, 0.0, 0.0, 36.0, 51.05, 805.12]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7e49048>
# LTImage ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[323, 80]', 'stream': "<PDFStream(13): raw=106, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 323, 'Height': 80, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 104}>"}
# LTFigure ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'matrix': '[287.45, 0.0, 0.0, 32.596, 256.3, 772.47]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# ['59.025', '216.26', '701.562', '712.122']
# -----------
# [[[49.025, 129.87800000000004], [49.025, 140.438], [216.26, 140.438], [216.26, 129.87800000000004]]]
# ['76.95', '528.86', '655.96', '685.96']
# ['51.96', '482.13', '621.52', '651.52']
# ['51.96', '199.43', '586.78', '616.96']
# -----------
# [[[41.96, 156.03999999999996], [41.96, 255.22000000000003], [528.86, 255.22000000000003], [528.86, 156.03999999999996]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# [[[51.0, 18.0], [51.0, 33.0], [202.20000000000002, 33.0], [202.20000000000002, 18.0]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# {'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [216.26, 140.438], [216.26, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 255.22000000000003], [528.86, 255.22000000000003], [528.86, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [202.20000000000002, 33.0], [202.20000000000002, 18.0]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [{'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [216.26, 140.438], [216.26, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 255.22000000000003], [528.86, 255.22000000000003], [528.86, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [202.20000000000002, 33.0], [202.20000000000002, 18.0]], 'shape_type': 'polygon', 'flags': {}}]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------------------------------------------------------------------------------------------
# ============================================================================
# 1
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1d5b7e29ac8>
# LTTextLineHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '73.62', 'x1': '477.08', 'width': '403.46', 'height': '30.0', 'bbox': '[73.62, 655.96, 477.08, 685.96]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '73.62', 'x1': '477.08', 'width': '403.46', 'height': '30.0', 'bbox': '[73.62, 655.96, 477.08, 685.96]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# FD-DEM-PBM coupled model
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7e29a88>
# LTTextBoxHorizontal ---- {'y0': '552.31', 'y1': '651.52', 'x0': '51.96', 'x1': '530.58', 'width': '478.62', 'height': '99.21', 'bbox': '[51.96, 552.31, 530.58, 651.52]', 'index': '5'}
# LTTextLineHorizontal ---- {'y0': '621.52', 'y1': '651.52', 'x0': '51.96', 'x1': '530.58', 'width': '478.62', 'height': '30.0', 'bbox': '[51.96, 621.52, 530.58, 651.52]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# development and validation of a 3D
# LTTextLineHorizontal ---- {'y0': '586.96', 'y1': '616.96', 'x0': '51.96', 'x1': '417.17', 'width': '365.21', 'height': '30.0', 'bbox': '[51.96, 586.96, 417.17, 616.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# top-spray fluidized bed wet
# LTTextLineHorizontal ---- {'y0': '552.31', 'y1': '582.49', 'x0': '51.96', 'x1': '329.65', 'width': '277.69', 'height': '30.18', 'bbox': '[51.96, 552.31, 329.65, 582.49]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# granulation process.
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7e293c8>
# LTTextLineVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '73.62', 'width': '21.66', 'height': '45.948', 'bbox': '[51.96, 655.96, 73.62, 701.908]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '73.62', 'width': '21.66', 'height': '45.948', 'bbox': '[51.96, 655.96, 73.62, 701.908]', 'index': '6'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  C
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7d34b88>
# LTTextLineHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.025', 'x1': '251.18', 'width': '192.155', 'height': '10.56', 'bbox': '[59.025, 701.562, 251.18, 712.122]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.025', 'x1': '251.18', 'width': '192.155', 'height': '10.56', 'bbox': '[59.025, 701.562, 251.18, 712.122]', 'index': '7'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# shutosh Tamrakar, Rohit Ramachandran
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7b3c508>
# LTTextBoxHorizontal ---- {'y0': '66.873', 'y1': '115.25', 'x0': '51.96', 'x1': '413.173', 'width': '361.213', 'height': '48.377', 'bbox': '[51.96, 66.873, 413.173, 115.25]', 'index': '8'}
# LTTextLineHorizontal ---- {'y0': '106.25', 'y1': '115.25', 'x0': '57.963', 'x1': '413.173', 'width': '355.21', 'height': '9.0', 'bbox': '[57.963, 106.25, 413.173, 115.25]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '51.96', 'x1': '141.996', 'width': '90.036', 'height': '9.0', 'bbox': '[51.96, 93.174, 141.996, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '401.511', 'x1': '412.887', 'width': '11.376', 'height': '9.0', 'bbox': '[401.511, 93.174, 412.887, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# LTTextLineHorizontal ---- {'y0': '80.214', 'y1': '89.214', 'x0': '51.96', 'x1': '412.788', 'width': '360.828', 'height': '9.0', 'bbox': '[51.96, 80.214, 412.788, 89.214]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# LTTextLineHorizontal ---- {'y0': '66.873', 'y1': '76.833', 'x0': '51.96', 'x1': '205.1', 'width': '153.14', 'height': '9.96', 'bbox': '[51.96, 66.873, 205.1, 76.833]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# angewandte Politikforschung (C·A·P).
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '147.765', 'x1': '395.859', 'width': '248.094', 'height': '9.0', 'bbox': '[147.765, 93.174, 395.859, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7dc37c8>
# LTTextLineVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '59.004', 'width': '7.044', 'height': '73.926', 'bbox': '[51.96, 701.562, 59.004, 775.488]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '59.004', 'width': '7.044', 'height': '73.926', 'bbox': '[51.96, 701.562, 59.004, 775.488]', 'index': '11'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7dc3bc8>
# LTTextLineHorizontal ---- {'y0': '542.398', 'y1': '554.398', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 542.398, 54.96, 554.398]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '542.398', 'y1': '554.398', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 542.398, 54.96, 554.398]', 'index': '12'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7dc3748>
# LTTextLineVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'index': '13'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7f2c588>
# LTTextLineVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'index': '14'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7f2cac8>
# LTImage ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[964, 1]', 'stream': "<PDFStream(5): raw=35, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 964, 'Height': 1, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 33}>"}
# LTFigure ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 55.819]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTImage' at 0x1d5b7dcbe88>
# LTImage ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[1315, 86]', 'stream': "<PDFStream(12): raw=357, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 1315, 'Height': 86, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 355}>"}
# LTFigure ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'matrix': '[493.25, 0.0, 0.0, 36.0, 51.05, 805.12]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7d55dc8>
# LTImage ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[323, 80]', 'stream': "<PDFStream(13): raw=106, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 323, 'Height': 80, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 104}>"}
# LTFigure ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'matrix': '[287.45, 0.0, 0.0, 32.596, 256.3, 772.47]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# ['59.025', '251.18', '701.562', '712.122']
# -----------
# [[[49.025, 129.87800000000004], [49.025, 140.438], [251.18, 140.438], [251.18, 129.87800000000004]]]
# ['73.62', '477.08', '655.96', '685.96']
# ['51.96', '530.58', '621.52', '651.52']
# ['51.96', '417.17', '586.96', '616.96']
# ['51.96', '329.65', '552.31', '582.49']
# -----------
# [[[41.96, 156.03999999999996], [41.96, 289.69000000000005], [530.58, 289.69000000000005], [530.58, 156.03999999999996]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# [[[51.0, 18.0], [51.0, 33.0], [256.8, 33.0], [256.8, 18.0]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# {'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [251.18, 140.438], [251.18, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 289.69000000000005], [530.58, 289.69000000000005], [530.58, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [256.8, 33.0], [256.8, 18.0]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [{'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [251.18, 140.438], [251.18, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 289.69000000000005], [530.58, 289.69000000000005], [530.58, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [256.8, 33.0], [256.8, 18.0]], 'shape_type': 'polygon', 'flags': {}}]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------------------------------------------------------------------------------------------
# ============================================================================
# 2
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1d5b5b2e9c8>
# LTTextLineHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '57.831', 'x1': '121.07', 'width': '63.239', 'height': '10.56', 'bbox': '[57.831, 701.562, 121.07, 712.122]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '57.831', 'x1': '121.07', 'width': '63.239', 'height': '10.56', 'bbox': '[57.831, 701.562, 121.07, 712.122]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# uis Puigjaner
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b5f7b5c8>
# LTTextLineHorizontal ---- {'y0': '655.78', 'y1': '685.96', 'x0': '71.97', 'x1': '171.2', 'width': '99.23', 'height': '30.18', 'bbox': '[71.97, 655.78, 171.2, 685.96]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '655.78', 'y1': '685.96', 'x0': '71.97', 'x1': '171.2', 'width': '99.23', 'height': '30.18', 'bbox': '[71.97, 655.78, 171.2, 685.96]', 'index': '5'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# reface.
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b5b11708>
# LTTextBoxHorizontal ---- {'y0': '66.873', 'y1': '115.25', 'x0': '51.96', 'x1': '413.173', 'width': '361.213', 'height': '48.377', 'bbox': '[51.96, 66.873, 413.173, 115.25]', 'index': '6'}
# LTTextLineHorizontal ---- {'y0': '106.25', 'y1': '115.25', 'x0': '57.963', 'x1': '413.173', 'width': '355.21', 'height': '9.0', 'bbox': '[57.963, 106.25, 413.173, 115.25]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '51.96', 'x1': '141.996', 'width': '90.036', 'height': '9.0', 'bbox': '[51.96, 93.174, 141.996, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '401.511', 'x1': '412.887', 'width': '11.376', 'height': '9.0', 'bbox': '[401.511, 93.174, 412.887, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# LTTextLineHorizontal ---- {'y0': '80.214', 'y1': '89.214', 'x0': '51.96', 'x1': '412.788', 'width': '360.828', 'height': '9.0', 'bbox': '[51.96, 80.214, 412.788, 89.214]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# LTTextLineHorizontal ---- {'y0': '66.873', 'y1': '76.833', 'x0': '51.96', 'x1': '205.1', 'width': '153.14', 'height': '9.96', 'bbox': '[51.96, 66.873, 205.1, 76.833]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# angewandte Politikforschung (C·A·P).
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '147.765', 'x1': '395.859', 'width': '248.094', 'height': '9.0', 'bbox': '[147.765, 93.174, 395.859, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7db6388>
# LTTextLineVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '57.831', 'width': '5.871', 'height': '73.926', 'bbox': '[51.96, 701.562, 57.831, 775.488]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '57.831', 'width': '5.871', 'height': '73.926', 'bbox': '[51.96, 701.562, 57.831, 775.488]', 'index': '9'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  L
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7db6488>
# LTTextLineVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '71.97', 'width': '20.01', 'height': '45.948', 'bbox': '[51.96, 655.96, 71.97, 701.908]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '71.97', 'width': '20.01', 'height': '45.948', 'bbox': '[51.96, 655.96, 71.97, 701.908]', 'index': '10'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  P
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7db6c48>
# LTTextLineHorizontal ---- {'y0': '645.988', 'y1': '657.988', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 645.988, 54.96, 657.988]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '645.988', 'y1': '657.988', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 645.988, 54.96, 657.988]', 'index': '11'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7f1f248>
# LTTextLineVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'index': '12'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7f1fa48>
# LTTextLineVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'index': '13'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7efad08>
# LTImage ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[964, 1]', 'stream': "<PDFStream(5): raw=35, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 964, 'Height': 1, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 33}>"}
# LTFigure ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 55.819]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTImage' at 0x1d5b5fbed48>
# LTImage ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[1315, 86]', 'stream': "<PDFStream(12): raw=357, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 1315, 'Height': 86, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 355}>"}
# LTFigure ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'matrix': '[493.25, 0.0, 0.0, 36.0, 51.05, 805.12]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7afea08>
# LTImage ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[323, 80]', 'stream': "<PDFStream(13): raw=106, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 323, 'Height': 80, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 104}>"}
# LTFigure ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'matrix': '[287.45, 0.0, 0.0, 32.596, 256.3, 772.47]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# ['57.831', '121.07', '701.562', '712.122']
# -----------
# [[[47.831, 129.87800000000004], [47.831, 140.438], [121.07, 140.438], [121.07, 129.87800000000004]]]
# ['71.97', '171.2', '655.78', '685.96']
# -----------
# [[[61.97, 156.03999999999996], [61.97, 186.22000000000003], [171.2, 186.22000000000003], [171.2, 156.03999999999996]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# [[[51.0, 18.0], [51.0, 33.0], [269.4, 33.0], [269.4, 18.0]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# {'label': 'author', 'points': [[47.831, 129.87800000000004], [47.831, 140.438], [121.07, 140.438], [121.07, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[61.97, 156.03999999999996], [61.97, 186.22000000000003], [171.2, 186.22000000000003], [171.2, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [269.4, 33.0], [269.4, 18.0]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [{'label': 'author', 'points': [[47.831, 129.87800000000004], [47.831, 140.438], [121.07, 140.438], [121.07, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[61.97, 156.03999999999996], [61.97, 186.22000000000003], [171.2, 186.22000000000003], [171.2, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [269.4, 33.0], [269.4, 18.0]], 'shape_type': 'polygon', 'flags': {}}]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------------------------------------------------------------------------------------------
# ============================================================================
# 3
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1d5b5fba288>
# LTTextLineHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.627', 'x1': '229.58', 'width': '169.953', 'height': '10.56', 'bbox': '[59.627, 701.562, 229.58, 712.122]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '59.627', 'x1': '229.58', 'width': '169.953', 'height': '10.56', 'bbox': '[59.627, 701.562, 229.58, 712.122]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# odolfo G. Dondo, Jaime Cerdaacute
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b5fbae08>
# LTTextLineHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '71.97', 'x1': '422.16', 'width': '350.19', 'height': '30.0', 'bbox': '[71.97, 655.96, 422.16, 685.96]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '71.97', 'x1': '422.16', 'width': '350.19', 'height': '30.0', 'bbox': '[71.97, 655.96, 422.16, 685.96]', 'index': '5'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  hybrid local improvement
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7b82748>
# LTTextBoxHorizontal ---- {'y0': '552.31', 'y1': '651.52', 'x0': '51.96', 'x1': '538.9', 'width': '486.94', 'height': '99.21', 'bbox': '[51.96, 552.31, 538.9, 651.52]', 'index': '6'}
# LTTextLineHorizontal ---- {'y0': '621.52', 'y1': '651.52', 'x0': '51.96', 'x1': '538.9', 'width': '486.94', 'height': '30.0', 'bbox': '[51.96, 621.52, 538.9, 651.52]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# algorithm for large-scale multi-depot
# LTTextLineHorizontal ---- {'y0': '586.96', 'y1': '616.96', 'x0': '51.96', 'x1': '512.07', 'width': '460.11', 'height': '30.0', 'bbox': '[51.96, 586.96, 512.07, 616.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# vehicle routing problems with time
# LTTextLineHorizontal ---- {'y0': '552.31', 'y1': '582.49', 'x0': '51.96', 'x1': '182.87', 'width': '130.91', 'height': '30.18', 'bbox': '[51.96, 552.31, 182.87, 582.49]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# windows.
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7f05188>
# LTTextBoxHorizontal ---- {'y0': '66.873', 'y1': '115.25', 'x0': '51.96', 'x1': '413.173', 'width': '361.213', 'height': '48.377', 'bbox': '[51.96, 66.873, 413.173, 115.25]', 'index': '7'}
# LTTextLineHorizontal ---- {'y0': '106.25', 'y1': '115.25', 'x0': '57.963', 'x1': '413.173', 'width': '355.21', 'height': '9.0', 'bbox': '[57.963, 106.25, 413.173, 115.25]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '51.96', 'x1': '141.996', 'width': '90.036', 'height': '9.0', 'bbox': '[51.96, 93.174, 141.996, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '401.511', 'x1': '412.887', 'width': '11.376', 'height': '9.0', 'bbox': '[401.511, 93.174, 412.887, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# LTTextLineHorizontal ---- {'y0': '80.214', 'y1': '89.214', 'x0': '51.96', 'x1': '412.913', 'width': '360.953', 'height': '9.0', 'bbox': '[51.96, 80.214, 412.913, 89.214]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# ...
# LTFigure ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 55.819]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTImage' at 0x1d5b7d44508>
# LTImage ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[1315, 86]', 'stream': "<PDFStream(12): raw=357, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 1315, 'Height': 86, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 355}>"}
# LTFigure ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'matrix': '[493.25, 0.0, 0.0, 36.0, 51.05, 805.12]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7ee9d48>
# LTImage ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[323, 80]', 'stream': "<PDFStream(13): raw=106, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 323, 'Height': 80, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 104}>"}
# LTFigure ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'matrix': '[287.45, 0.0, 0.0, 32.596, 256.3, 772.47]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# ['59.025', '230.18', '701.562', '712.122']
# -----------
# [[[49.025, 129.87800000000004], [49.025, 140.438], [230.18, 140.438], [230.18, 129.87800000000004]]]
# ['73.62', '450.48', '655.96', '685.96']
# ['51.96', '520.38', '621.52', '651.52']
# ['51.96', '453.74', '586.96', '616.96']
# ['51.96', '518.08', '552.31', '582.49']
# -----------
# [[[41.96, 156.03999999999996], [41.96, 289.69000000000005], [520.38, 289.69000000000005], [520.38, 156.03999999999996]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# [[[51.0, 18.0], [51.0, 33.0], [135.0, 33.0], [135.0, 18.0]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# {'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [230.18, 140.438], [230.18, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 289.69000000000005], [520.38, 289.69000000000005], [520.38, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [135.0, 33.0], [135.0, 18.0]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [{'label': 'author', 'points': [[49.025, 129.87800000000004], [49.025, 140.438], [230.18, 140.438], [230.18, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 289.69000000000005], [520.38, 289.69000000000005], [520.38, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [135.0, 33.0], [135.0, 18.0]], 'shape_type': 'polygon', 'flags': {}}]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------------------------------------------------------------------------------------------
# ============================================================================
# 298
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1d5b7dc2948>
# LTTextLineHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '76.95', 'x1': '532.1', 'width': '455.15', 'height': '30.0', 'bbox': '[76.95, 655.96, 532.1, 685.96]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '655.96', 'y1': '685.96', 'x0': '76.95', 'x1': '532.1', 'width': '455.15', 'height': '30.0', 'bbox': '[76.95, 655.96, 532.1, 685.96]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# odel Predictive Control Design for
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7dc2908>
# LTTextBoxHorizontal ---- {'y0': '586.78', 'y1': '651.52', 'x0': '51.96', 'x1': '481.98', 'width': '430.02', 'height': '64.74', 'bbox': '[51.96, 586.78, 481.98, 651.52]', 'index': '5'}
# LTTextLineHorizontal ---- {'y0': '621.52', 'y1': '651.52', 'x0': '51.96', 'x1': '481.98', 'width': '430.02', 'height': '30.0', 'bbox': '[51.96, 621.52, 481.98, 651.52]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Dynamical Systems Learned by
# LTTextLineHorizontal ---- {'y0': '586.78', 'y1': '616.96', 'x0': '51.96', 'x1': '348.13', 'width': '296.17', 'height': '30.18', 'bbox': '[51.96, 586.78, 348.13, 616.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Echo State Networks.
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7f2c508>
# LTTextLineVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '76.95', 'width': '24.99', 'height': '45.948', 'bbox': '[51.96, 655.96, 76.95, 701.908]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '655.96', 'y1': '701.908', 'x0': '51.96', 'x1': '76.95', 'width': '24.99', 'height': '45.948', 'bbox': '[51.96, 655.96, 76.95, 701.908]', 'index': '6'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  M
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7f2c888>
# LTTextLineHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '57.831', 'x1': '390.04', 'width': '332.209', 'height': '10.56', 'bbox': '[57.831, 701.562, 390.04, 712.122]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '701.562', 'y1': '712.122', 'x0': '57.831', 'x1': '390.04', 'width': '332.209', 'height': '10.56', 'bbox': '[57.831, 701.562, 390.04, 712.122]', 'index': '7'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# uca Bugliari Armenio, Enrico Terzi, Marcello Farina, Riccardo Scattolini
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1d5b7d3da48>
# LTTextBoxHorizontal ---- {'y0': '66.873', 'y1': '115.25', 'x0': '51.96', 'x1': '413.173', 'width': '361.213', 'height': '48.377', 'bbox': '[51.96, 66.873, 413.173, 115.25]', 'index': '8'}
# LTTextLineHorizontal ---- {'y0': '106.25', 'y1': '115.25', 'x0': '57.963', 'x1': '413.173', 'width': '355.21', 'height': '9.0', 'bbox': '[57.963, 106.25, 413.173, 115.25]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '51.96', 'x1': '141.996', 'width': '90.036', 'height': '9.0', 'bbox': '[51.96, 93.174, 141.996, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '401.511', 'x1': '412.887', 'width': '11.376', 'height': '9.0', 'bbox': '[401.511, 93.174, 412.887, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# LTTextLineHorizontal ---- {'y0': '80.214', 'y1': '89.214', 'x0': '51.96', 'x1': '412.913', 'width': '360.953', 'height': '9.0', 'bbox': '[51.96, 80.214, 412.913, 89.214]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# LTTextLineHorizontal ---- {'y0': '66.873', 'y1': '76.833', 'x0': '51.96', 'x1': '205.1', 'width': '153.14', 'height': '9.96', 'bbox': '[51.96, 66.873, 205.1, 76.833]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# angewandte Politikforschung (C·A·P).
# LTTextLineHorizontal ---- {'y0': '93.174', 'y1': '102.174', 'x0': '147.765', 'x1': '395.859', 'width': '248.094', 'height': '9.0', 'bbox': '[147.765, 93.174, 395.859, 102.174]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7b3c888>
# LTTextLineVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '57.831', 'width': '5.871', 'height': '73.926', 'bbox': '[51.96, 701.562, 57.831, 775.488]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '701.562', 'y1': '775.488', 'x0': '51.96', 'x1': '57.831', 'width': '5.871', 'height': '73.926', 'bbox': '[51.96, 701.562, 57.831, 775.488]', 'index': '11'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  L
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1d5b7b3cc48>
# LTTextLineHorizontal ---- {'y0': '576.958', 'y1': '588.958', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 576.958, 54.96, 588.958]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '576.958', 'y1': '588.958', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '12.0', 'bbox': '[51.96, 576.958, 54.96, 588.958]', 'index': '12'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7e25048>
# LTTextLineVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '106.25', 'y1': '141.29', 'x0': '51.96', 'x1': '57.963', 'width': '6.003', 'height': '35.04', 'bbox': '[51.96, 106.25, 57.963, 141.29]', 'index': '13'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# END
#
#
# <Element 'LTTextLineVertical' at 0x1d5b7e252c8>
# LTTextLineVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '51.039', 'y1': '73.152', 'x0': '51.96', 'x1': '54.96', 'width': '3.0', 'height': '22.113', 'bbox': '[51.96, 51.039, 54.96, 73.152]', 'index': '14'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7d55d08>
# LTImage ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[964, 1]', 'stream': "<PDFStream(5): raw=35, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 964, 'Height': 1, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 33}>"}
# LTFigure ---- {'y0': '55.819', 'y1': '56.319', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 55.819, 412.35, 56.319]', 'name': 'Image5', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 55.819]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# <Element 'LTImage' at 0x1d5b7d55908>
# LTImage ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[1315, 86]', 'stream': "<PDFStream(12): raw=357, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 1315, 'Height': 86, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 355}>"}
# LTFigure ---- {'y0': '805.12', 'y1': '841.12', 'x0': '51.05', 'x1': '544.3', 'width': '493.25', 'height': '36.0', 'bbox': '[51.05, 805.12, 544.3, 841.12]', 'name': 'Image12', 'matrix': '[493.25, 0.0, 0.0, 36.0, 51.05, 805.12]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# <Element 'LTImage' at 0x1d5b7bc5e08>
# LTImage ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[323, 80]', 'stream': "<PDFStream(13): raw=106, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 323, 'Height': 80, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 104}>"}
# LTFigure ---- {'y0': '772.47', 'y1': '805.066', 'x0': '256.3', 'x1': '543.75', 'width': '287.45', 'height': '32.596', 'bbox': '[256.3, 772.47, 543.75, 805.066]', 'name': 'Image13', 'matrix': '[287.45, 0.0, 0.0, 32.596, 256.3, 772.47]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# END
#
#
# ['57.831', '390.04', '701.562', '712.122']
# -----------
# [[[47.831, 129.87800000000004], [47.831, 140.438], [390.04, 140.438], [390.04, 129.87800000000004]]]
# ['76.95', '532.1', '655.96', '685.96']
# ['51.96', '481.98', '621.52', '651.52']
# ['51.96', '348.13', '586.78', '616.96']
# -----------
# [[[41.96, 156.03999999999996], [41.96, 255.22000000000003], [532.1, 255.22000000000003], [532.1, 156.03999999999996]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# [[[51.0, 18.0], [51.0, 33.0], [172.8, 33.0], [172.8, 18.0]]]
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# {'label': 'author', 'points': [[47.831, 129.87800000000004], [47.831, 140.438], [390.04, 140.438], [390.04, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 255.22000000000003], [532.1, 255.22000000000003], [532.1, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [172.8, 33.0], [172.8, 18.0]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# [{'label': 'author', 'points': [[47.831, 129.87800000000004], [47.831, 140.438], [390.04, 140.438], [390.04, 129.87800000000004]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[41.96, 156.03999999999996], [41.96, 255.22000000000003], [532.1, 255.22000000000003], [532.1, 156.03999999999996]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[442.0, 41.0], [442.0, 60.0], [543.0, 60.0], [543.0, 41.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[476.0, 22.0], [476.0, 34.0], [535.0, 34.0], [535.0, 22.0]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[51.0, 18.0], [51.0, 33.0], [172.8, 33.0], [172.8, 18.0]], 'shape_type': 'polygon', 'flags': {}}]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------------------------------------------------------------------------------------------
# ============================================================================
# 299

# %%
print("Done")
# Out:
# Done
