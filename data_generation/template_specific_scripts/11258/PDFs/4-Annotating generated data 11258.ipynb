# %%
import pandas as pd
df = pd.read_excel("11258.xlsx")

# %%
number=0
while True:

    names='11258_'+str(number)
    if number==1700:
        break

    import pdfquery
    # loading a pdf
    pdf = pdfquery.PDFQuery(names+".pdf")
    pdf.load()
    # if you want, you can store the entire pdf as an xml file

    pdf.tree.write(names+".xml", pretty_print=True, encoding="utf-8")
    import xml.etree.ElementTree as ET
    tree = ET.parse(names+'.xml')
    root = tree.getroot()

    author=df['author'][number]
    title=df['title'][number]
    journal=df['journal'][number]
    doi=df['doi'][number]
    date= 'No. 4/' + str(df['year'][number])
    address=str(df['zip'][number])+', '+str(df['city'][number])
    affiliation= df['affiliation'][number]   

    bounding_box_list=[]
    author_list=[]
    title_list=[]
    journal_list=[]
    #doi_list=[]
    date_list=[]
    #abstract_list=[]
    address_list=[]
    affiliation_list=[]
    #email_list=[]
    

    for child in root:
        print('START')
        print (child.tag,"----", child.attrib)
        for fchild in child:
            #print('----------------------------')
            #print(fchild)
            #print('----------------------------')
            print (fchild.tag,"----", fchild.attrib)
            for ffchild in fchild:
                print (ffchild.tag,"----", ffchild.attrib)
                print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
                print(ffchild.text)
                print(ffchild.attrib['x0'])

                try:
                    bounding_box_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                            ffchild.attrib['y1']]])

                    if ffchild.text.strip() in author and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                        author_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                          ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in title and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                        title_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                         ffchild.attrib['y1']]])
                    
                    elif date in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>3:
                        date_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                              ffchild.attrib['y1']]])       
                    
                    elif ffchild.text.strip() in address and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                        address_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                              ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in affiliation and ffchild.text.strip() is not '' and len(ffchild.text.strip())>3:
                        affiliation_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                              ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in journal and ffchild.text.strip() is not '' and len(ffchild.text.strip())>3:
                        journal_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                              ffchild.attrib['y1']]])
                    

                except:
                    continue

                print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
                #print(ffchild)
            print('END')
            print('\n')
    try:
        coordinates_author = []
        coordinates_title = []
        coordinates_journal = []
        #coordinates_doi=[]
        coordinates_date=[]
        coordinates_abstract=[]
        coordinates_address=[]
        coordinates_affiliation=[]
        coordinates_email=[]

        lst1=[]
        lst2=[]
        lst3=[]
        lst4=[]

        for lst in author_list:
            bboxes=lst[1]
            print((bboxes))

            lst1.append([float(bboxes[0])])
            print(lst1)
            lst2.append([float(bboxes[1])])
            lst3.append([842-float(bboxes[2])])
            lst4.append([842-float(bboxes[3])])  
        apt1=[min(lst1)[0]-5,min(lst4)[0]-5]
        apt2=[min(lst1)[0]-5,max(lst3)[0]+5]
        apt3=[max(lst2)[0]+5,max(lst3)[0]+5]
        apt4=[max(lst2)[0]+5,min(lst4)[0]-5]
        coordinates_author.append([ apt1,apt2,apt3,apt4 ])  
        print('-----------')
        print(coordinates_author)


        tlst1=[]
        tlst2=[]
        tlst3=[]
        tlst4=[]

        for lst in title_list:
            bboxes=lst[1]
            
            print((bboxes))
    
            tlst1.append([float(bboxes[0])])
            print(lst1)
            tlst2.append([float(bboxes[1])])
            tlst3.append([842-float(bboxes[2])])
            tlst4.append([842-float(bboxes[3])])  
        tpt1=[min(tlst1)[0]-5,min(tlst4)[0]-5]
        tpt2=[min(tlst1)[0]-5,max(tlst3)[0]+5]
        tpt3=[max(tlst2)[0]+5,max(tlst3)[0]+5]
        tpt4=[max(tlst2)[0]+5,min(tlst4)[0]-5]
        coordinates_title.append([ tpt1,tpt2,tpt3,tpt4 ])  
        print('-----------')
        print(coordinates_title)

        jlst1=[]
        jlst2=[]
        jlst3=[]
        jlst4=[]

        for lst in journal_list:
            bboxes=lst[1]
            print((bboxes))

            jlst1.append([float(bboxes[0])])
            print(lst1)
            jlst2.append([float(bboxes[1])])
            jlst3.append([842-float(bboxes[2])])
            jlst4.append([842-float(bboxes[3])])  
        jpt1=[min(jlst1)[0]-5,min(jlst4)[0]]
        jpt2=[min(jlst1)[0]-5,max(jlst3)[0]]
        jpt3=[max(jlst2)[0]+5,max(jlst3)[0]]
        jpt4=[max(jlst2)[0]+5,min(jlst4)[0]]
        coordinates_journal.append([ jpt1,jpt2,jpt3,jpt4 ])  
        print('-----------')
        print(coordinates_journal)

        for lst in date_list:
            bboxes=lst[1]
            print((bboxes))
            print('\n')
            dapt1=[float(bboxes[0])+23,842-float(bboxes[3])]
            dapt2=[float(bboxes[0])+23,842-float(bboxes[2])]
            dapt3=[float(bboxes[1]),842-float(bboxes[2])]
            dapt4=[float(bboxes[1]),842-float(bboxes[3])]
            coordinates_date.append([ dapt1,dapt2,dapt3,dapt4 ])
        print('-----------')
        print(coordinates_date)
              
        adlst1=[]
        adlst2=[]
        adlst3=[]
        adlst4=[]

        for lst in address_list:
            bboxes=lst[1]
            print((bboxes))

            adlst1.append([float(bboxes[0])])
            adlst2.append([float(bboxes[1])])
            adlst3.append([842-float(bboxes[2])])
            adlst4.append([842-float(bboxes[3])])  
        adpt1=[min(adlst1)[0]-5,min(adlst4)[0]-2]
        adpt2=[min(adlst1)[0]-5,max(adlst3)[0]+5]
        adpt3=[max(adlst2)[0]+5,max(adlst3)[0]+5]
        adpt4=[max(adlst2)[0]+5,min(adlst4)[0]-2]
        coordinates_address.append([ adpt1,adpt2,adpt3,adpt4 ])  
        print('-----------')
        print(coordinates_address)

        aflst1=[]
        aflst2=[]
        aflst3=[]
        aflst4=[]

        for lst in affiliation_list:
            bboxes=lst[1]
            print((bboxes))

            aflst1.append([float(bboxes[0])])
            print(aflst1)
            aflst2.append([float(bboxes[1])])
            aflst3.append([842-float(bboxes[2])])
            aflst4.append([842-float(bboxes[3])])  
        afpt1=[min(aflst1)[0]-5,min(aflst4)[0]-5]
        afpt2=[min(aflst1)[0]-5,max(aflst3)[0]+2]
        afpt3=[max(aflst2)[0]+5,max(aflst3)[0]+2]
        afpt4=[max(aflst2)[0]+5,min(aflst4)[0]-5]
        coordinates_affiliation.append([ afpt1,afpt2,afpt3,afpt4 ])  
        print('-----------')
        print(coordinates_affiliation)
    except:
        number=number+1
        continue

    lst=[coordinates_author,coordinates_title,coordinates_journal,coordinates_date,coordinates_address,coordinates_affiliation]
    lst

    abase = {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a1base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a2base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a3base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a4base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    tbase = {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t1base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t2base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t3base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t4base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t5base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t6base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t7base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t8base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    jbase = {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j1base = {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j2base = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
    j3base = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
    dbase = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    d1base = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    dabase = {
          "label": "date",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    da1base = {
          "label": "date",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    absbase = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs1base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs2base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs3base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs4base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs5base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs6base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs7base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs8base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs9base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs10base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs11base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs12base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs13base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs14base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs15base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs16base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs17base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs18base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs19base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs20base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs21base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    absbase2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs1base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs2base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs3base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs4base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs5base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs6base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs7base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs8base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs9base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs10base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs11base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs12base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs13base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs14base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs15base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs16base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs17base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs18base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs19base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs20base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs21base2 = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    
    adbase = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ad1base = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ad2base = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ad3base = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    afbase = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    af1base = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    af2base = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    af3base = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ebase = {
          "label": "email",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    e1base = {
          "label": "email",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    
    
    ab=[abase,a1base,a2base,a3base,a4base]
    tb=[tbase,t1base,t2base,t3base,t4base,t5base,t6base,t7base,t8base]
    jb=[jbase,j1base,j2base,j3base]
    db=[dbase,d1base]
    dab=[dabase,da1base]
    absb=[absbase,abs1base,abs2base,abs3base,abs4base,abs5base,abs6base,abs7base,abs8base,abs9base,abs10base,abs11base,abs12base,abs13base,abs14base,abs15base,abs16base,abs17base,abs18base,abs19base,abs20base,abs21base]
    abs2b=[absbase2,abs1base2,abs2base2,abs3base2,abs4base2,abs5base2,abs6base2,abs7base2,abs8base2,abs9base2,abs10base2,abs11base2,abs12base2,abs13base2,abs14base2,abs15base2,abs16base2,abs17base2,abs18base2,abs19base2,abs20base2,abs21base2]
    adb=[adbase,ad1base,ad2base,ad3base]
    afb=[afbase,af1base,af2base,af3base]
    eb=[ebase,e1base]
  
    liste=[]
    try:
        counter=0
        for no in range(len(coordinates_author)):   

            ab[counter]['points']=lst[0][counter]
            print(ab[counter])
            liste.append(ab[counter])
            counter=counter+1

        counter=0
        for no in range(len(coordinates_title)):   

            tb[counter]['points']=lst[1][counter]
            print(tb[counter])
            liste.append(tb[counter])
            counter=counter+1  
        
        counter=0
        for no in range(len(coordinates_journal)):   

            jb[counter]['points']=lst[2][counter]
            print(jb[counter])
            liste.append(jb[counter])
            counter=counter+1    
         
        counter=0
        for no in range(len(coordinates_date)):   

            dab[counter]['points']=lst[3][counter]
            print(dab[counter])
            liste.append(dab[counter])
            counter=counter+1 
                  
        
        counter=0
        for no in range(len(coordinates_address)):   

            adb[counter]['points']=lst[4][counter]
            print(adb[counter])
            liste.append(adb[counter])
            counter=counter+1 
            
        counter=0
        for no in range(len(coordinates_affiliation)):   

            afb[counter]['points']=lst[5][counter]
            print(afb[counter])
            liste.append(afb[counter])
            counter=counter+1 
         
    except:
        print('============================================================================')
        print(number)
        number=number+1
        continue

    import base64
    import json

    file=names+".jpeg"
    image_data = base64.b64encode(open(file, "rb").read())
    imagedata=str(image_data)[1:].replace("'","")

    x ='''[{
      "version": "4.4.0",  "flags": {},

      "shapes": [
        {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "group_id": null,"shape_type": "polygon", "flags": {}
        },

        {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
          "group_id": null, "shape_type": "polygon","flags": {}
        },

        {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "group_id": null,"shape_type": "polygon","flags": {}
        }  ],

      "imagePath": "4336.jpg",
      "imageData": "...",
      "imageHeight": 842,
      "imageWidth": 595
    }]'''

    try:
        info=json.loads(x)
        print('User count', len(info))
        print("-------------")
        info[0]['shapes']=liste
        print(info[0]['shapes'])
        info[0]['imageData']=imagedata
        info[0]['imagePath']=file
        print("-------------------------------------------------------------------------------------------")

        for key in info:
            my_details=key
        name=names+".json"
        with open(name, 'w') as json_file:
            json.dump(my_details, json_file)
    except:
        
        print('============================================================================')
        print(number)
        number=number+1
        continue
    print('============================================================================')
    print(number)
    number=number+1
# Out:
# START
# LTPage ---- {'y0': '0', 'y1': '842.04', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '842.04', 'bbox': '[0, 0, 594.96, 842.04]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# LTTextBoxHorizontal ---- {'y0': '731.552', 'y1': '777.772', 'x0': '281.81', 'x1': '508.363', 'width': '226.553', 'height': '46.22', 'bbox': '[281.81, 731.552, 508.363, 777.772]', 'index': '0'}
# LTTextLineHorizontal ---- {'y0': '763.732', 'y1': '777.772', 'x0': '281.81', 'x1': '508.206', 'width': '226.396', 'height': '14.04', 'bbox': '[281.81, 763.732, 508.206, 777.772]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ZA-Information / Zentralarchiv für
# 281.81
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '747.632', 'y1': '761.672', 'x0': '316.15', 'x1': '508.363', 'width': '192.213', 'height': '14.04', 'bbox': '[316.15, 747.632, 508.363, 761.672]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Empirische Sozialforschung
# 316.15
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '731.552', 'y1': '745.592', 'x0': '435.22', 'x1': '508.363', 'width': '73.143', 'height': '14.04', 'bbox': '[435.22, 731.552, 508.363, 745.592]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# No. 4/1997
# 435.22
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineHorizontal ---- {'y0': '719.192', 'y1': '733.232', 'x0': '423.1', 'x1': '429.43', 'width': '6.33', 'height': '14.04', 'bbox': '[423.1, 719.192, 429.43, 733.232]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '719.192', 'y1': '733.232', 'x0': '423.1', 'x1': '429.43', 'width': '6.33', 'height': '14.04', 'bbox': '[423.1, 719.192, 429.43, 733.232]', 'index': '1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 423.1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextBoxHorizontal ---- {'y0': '551.677', 'y1': '581.797', 'x0': '170.06', 'x1': '465.897', 'width': '295.837', 'height': '30.12', 'bbox': '[170.06, 551.677, 465.897, 581.797]', 'index': '2'}
# LTTextLineHorizontal ---- {'y0': '567.757', 'y1': '581.797', 'x0': '170.06', 'x1': '465.897', 'width': '295.837', 'height': '14.04', 'bbox': '[170.06, 567.757, 465.897, 581.797]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
 'x0': '170.1', 'x1': '518.7', 'width': '348.6', 'height': '5.65', 'bbox': '[170.1, 508.8, 518.7, 514.45]', 'linewidth': '0', 'pts': '[[170.1, 508.8], [518.7, 508.8], [518.7, 514.45], [170.1, 514.45]]'}
# END
#
#
# ['170.06', '245.54', '477.228', '490.188']
# [[170.06]]
# -----------
# [[[170.06, 351.812], [170.06, 364.772], [245.54, 364.772], [245.54, 351.812]]]
# ['170.06', '441.67', '583.837', '597.877']
# [[170.06]]
# -----------
# [[[170.06, 244.12300000000005], [170.06, 258.163], [441.67, 258.163], [441.67, 244.12300000000005]]]
# ['379.27', '508.363', '763.732', '777.772']
# [[170.06]]
# -----------
# [[[379.27, 64.22799999999995], [379.27, 78.26800000000003], [508.363, 78.26800000000003], [508.363, 64.22799999999995]]]
# ['435.22', '508.363', '747.632', '761.672']
#
#
# -----------
# [[[458.22, 80.32799999999997], [458.22, 94.36800000000005], [508.363, 94.36800000000005], [508.363, 80.32799999999997]]]
# ['431.74', '537.57', '324.208', '337.168']
# -----------
# ...
# LTTextLineHorizontal ---- {'y0': '300.328', 'y1': '313.288', 'x0': '311.23', 'x1': '538.642', 'width': '227.412', 'height': '12.96', 'bbox': '[311.23, 300.328, 538.642, 313.288]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# International School of Management
# 311.23
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '285.448', 'y1': '298.408', 'x0': '464.26', 'x1': '537.57', 'width': '73.31', 'height': '12.96', 'bbox': '[464.26, 285.448, 537.57, 298.408]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# (Dortmund)
# 464.26
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineHorizontal ---- {'y0': '247.138', 'y1': '260.098', 'x0': '435.34', 'x1': '537.57', 'width': '102.23', 'height': '12.96', 'bbox': '[435.34, 247.138, 537.57, 260.098]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '247.138', 'y1': '260.098', 'x0': '435.34', 'x1': '537.57', 'width': '102.23', 'height': '12.96', 'bbox': '[435.34, 247.138, 537.57, 260.098]', 'index': '5'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 73469, Riesbürg
# 435.34
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '779.208', 'y1': '801.168', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '21.96', 'bbox': '[72.024, 779.208, 75.024, 801.168]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '779.208', 'y1': '801.168', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '21.96', 'bbox': '[72.024, 779.208, 75.024, 801.168]', 'index': '6'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '600.388', 'y1': '744.628', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '144.24', 'bbox': '[72.024, 600.388, 75.024, 744.628]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '600.388', 'y1': '744.628', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '144.24', 'bbox': '[72.024, 600.388, 75.024, 744.628]', 'index': '7'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '459.478', 'y1': '560.278', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '100.8', 'bbox': '[72.024, 459.478, 75.024, 560.278]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '459.478', 'y1': '560.278', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '100.8', 'bbox': '[72.024, 459.478, 75.024, 560.278]', 'index': '8'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '316.658', 'y1': '416.498', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '99.84', 'bbox': '[72.024, 316.658, 75.024, 416.498]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '316.658', 'y1': '416.498', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '99.84', 'bbox': '[72.024, 316.658, 75.024, 416.498]', 'index': '9'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '262.058', 'y1': '286.778', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '24.72', 'bbox': '[72.024, 262.058, 75.024, 286.778]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '262.058', 'y1': '286.778', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '24.72', 'bbox': '[72.024, 262.058, 75.024, 286.778]', 'index': '10'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTRect ---- {'y0': '634.64', 'y1': '640.29', 'x0': '170.1', 'x1': '518.7', 'width': '348.6', 'height': '5.65', 'bbox': '[170.1, 634.64, 518.7, 640.29]', 'linewidth': '0', 'pts': '[[170.1, 634.64], [518.7, 634.64], [518.7, 640.29], [170.1, 640.29]]'}
# END
#
#
# LTRect ---- {'y0': '476.6', 'y1': '482.25', 'x0': '170.1', 'x1': '518.7', 'width': '348.6', 'height': '5.65', 'bbox': '[170.1, 476.6, 518.7, 482.25]', 'linewidth': '0', 'pts': '[[170.1, 476.6], [518.7, 476.6], [518.7, 482.25], [170.1, 482.25]]'}
# END
#
#
# ['170.06', '296.498', '445.068', '458.028']
# [[170.06]]
# ['170.06', '285.598', '430.068', '443.028']
# [[170.06], [170.06]]
# ['170.06', '239.06', '415.168', '428.128']
# [[170.06], [170.06], [170.06]]
# -----------
# [[[170.06, 383.972], [170.06, 426.832], [296.498, 426.832], [296.498, 383.972]]]
# ['170.06', '469.224', '583.837', '597.877']
# [[170.06], [170.06], [170.06]]
# ['170.06', '417.936', '567.757', '581.797']
# [[170.06], [170.06], [170.06]]
# ['170.06', '318.4', '551.677', '565.717']
# [[170.06], [170.06], [170.06]]
# -----------
# [[[170.06, 244.12300000000005], [170.06, 290.323], [469.224, 290.323], [469.224, 244.12300000000005]]]
# START
# LTPage ---- {'y0': '0', 'y1': '842.04', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '842.04', 'bbox': '[0, 0, 594.96, 842.04]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# LTTextBoxHorizontal ---- {'y0': '731.552', 'y1': '777.772', 'x0': '331.63', 'x1': '508.363', 'width': '176.733', 'height': '46.22', 'bbox': '[331.63, 731.552, 508.363, 777.772]', 'index': '0'}
# LTTextLineHorizontal ---- {'y0': '763.732', 'y1': '777.772', 'x0': '331.63', 'x1': '508.348', 'width': '176.718', 'height': '14.04', 'bbox': '[331.63, 763.732, 508.348, 777.772]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Zeitschrift für Berufs- und
# 331.63
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '747.632', 'y1': '761.672', 'x0': '358.15', 'x1': '508.363', 'width': '150.213', 'height': '14.04', 'bbox': '[358.15, 747.632, 508.363, 761.672]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Wirtschaftspädagogik
# 358.15
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '731.552', 'y1': '745.592', 'x0': '435.22', 'x1': '508.363', 'width': '73.143', 'height': '14.04', 'bbox': '[435.22, 731.552, 508.363, 745.592]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# No. 4/2009
# 435.22
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineHorizontal ---- {'y0': '719.192', 'y1': '733.232', 'x0': '423.1', 'x1': '429.43', 'width': '6.33', 'height': '14.04', 'bbox': '[423.1, 719.192, 429.43, 733.232]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '719.192', 'y1': '733.232', 'x0': '423.1', 'x1': '429.43', 'width': '6.33', 'height': '14.04', 'bbox': '[423.1, 719.192, 429.43, 733.232]', 'index': '1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 423.1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextBoxHorizontal ---- {'y0': '551.677', 'y1': '581.797', 'x0': '170.06', 'x1': '430.404', 'width': '260.344', 'height': '30.12', 'bbox': '[170.06, 551.677, 430.404, 581.797]', 'index': '2'}
# LTTextLineHorizontal ---- {'y0': '567.757', 'y1': '581.797', 'x0': '170.06', 'x1': '430.404', 'width': '260.344', 'height': '14.04', 'bbox': '[170.06, 567.757, 430.404, 581.797]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Drying stresses and strains in a spherical food
# 170.06
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '551.677', 'y1': '565.717', 'x0': '170.06', 'x1': '211.1', 'width': '41.04', 'height': '14.04', 'bbox': '[170.06, 551.677, 211.1, 565.717]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# model.
# 170.06
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextBoxHorizontal ---- {'y0': '415.168', 'y1': '458.028', 'x0': '170.06', 'x1': '289.78', 'width': '119.72', 'height': '42.86', 'bbox': '[170.06, 415.168, 289.78, 458.028]', 'index': '3'}
# LTTextLineHorizontal ---- {'y0': '445.068', 'y1': '458.028', 'x0': '170.06', 'x1': '289.78', 'width': '119.72', 'height': '12.96', 'bbox': '[170.06, 445.068, 289.78, 458.028]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# L. S. Arrieche, R. G.
# 170.06
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '430.068', 'y1': '443.028', 'x0': '170.06', 'x1': '285.5', 'width': '115.44', 'height': '12.96', 'bbox': '[170.06, 430.068, 285.5, 443.028]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Correcirca, D. J. M.
# 170.06
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '415.168', 'y1': '428.128', 'x0': '170.06', 'x1': '210.86', 'width': '40.8', 'height': '12.96', 'bbox': '[170.06, 415.168, 210.86, 428.128]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Sartori
# 170.06
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineHorizontal ---- {'y0': '300.328', 'y1': '313.288', 'x0': '334.99', 'x1': '537.57', 'width': '202.58', 'height': '12.96', 'bbox': '[334.99, 300.328, 537.57, 313.288]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '300.328', 'y1': '313.288', 'x0': '334.99', 'x1': '537.57', 'width': '202.58', 'height': '12.96', 'bbox': '[334.99, 300.328, 537.57, 313.288]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Dresden International University
# 334.99
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextBoxHorizontal ---- {'y0': '247.138', 'y1': '275.008', 'x0': '392.71', 'x1': '538.625', 'width': '145.915', 'height': '27.87', 'bbox': '[392.71, 247.138, 538.625, 275.008]', 'index': '5'}
# LTTextLineHorizontal ---- {'y0': '262.048', 'y1': '275.008', 'x0': '392.71', 'x1': '538.625', 'width': '145.915', 'height': '12.96', 'bbox': '[392.71, 262.048, 538.625, 275.008]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 56477, Zehnhausen bei
# 392.71
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '247.138', 'y1': '260.098', 'x0': '474.34', 'x1': '537.57', 'width': '63.23', 'height': '12.96', 'bbox': '[474.34, 247.138, 537.57, 260.098]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Rennerod
# 474.34
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '779.208', 'y1': '801.168', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '21.96', 'bbox': '[72.024, 779.208, 75.024, 801.168]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '779.208', 'y1': '801.168', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '21.96', 'bbox': '[72.024, 779.208, 75.024, 801.168]', 'index': '6'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '584.278', 'y1': '728.548', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '144.27', 'bbox': '[72.024, 584.278, 75.024, 728.548]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '584.278', 'y1': '728.548', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '144.27', 'bbox': '[72.024, 584.278, 75.024, 728.548]', 'index': '7'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '459.478', 'y1': '560.278', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '100.8', 'bbox': '[72.024, 459.478, 75.024, 560.278]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '459.478', 'y1': '560.278', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '100.8', 'bbox': '[72.024, 459.478, 75.024, 560.278]', 'index': '8'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '316.658', 'y1': '416.498', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '99.84', 'bbox': '[72.024, 316.658, 75.024, 416.498]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '316.658', 'y1': '416.498', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '99.84', 'bbox': '[72.024, 316.658, 75.024, 416.498]', 'index': '9'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineVertical ---- {'y0': '277.058', 'y1': '301.658', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '24.6', 'bbox': '[72.024, 277.058, 75.024, 301.658]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '277.058', 'y1': '301.658', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '24.6', 'bbox': '[72.024, 277.058, 75.024, 301.658]', 'index': '10'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# 72.024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTRect ---- {'y0': '618.55', 'y1': '624.2', 'x0': '170.1', 'x1': '518.7', 'width': '348.6', 'height': '5.65', 'bbox': '[170.1, 618.55, 518.7, 624.2]', 'linewidth': '0', 'pts': '[[170.1, 618.55], [518.7, 618.55], [518.7, 624.2], [170.1, 624.2]]'}
# END
#
#
# LTRect ---- {'y0': '476.6', 'y1': '482.25', 'x0': '170.1', 'x1': '518.7', 'width': '348.6', 'height': '5.65', 'bbox': '[170.1, 476.6, 518.7, 482.25]', 'linewidth': '0', 'pts': '[[170.1, 476.6], [518.7, 476.6], [518.7, 482.25], [170.1, 482.25]]'}
# END
#
#
# ['170.06', '289.78', '445.068', '458.028']
# [[170.06]]
# ['170.06', '285.5', '430.068', '443.028']
# [[170.06], [170.06]]
# ['170.06', '210.86', '415.168', '428.128']
# [[170.06], [170.06], [170.06]]
# -----------
# [[[170.06, 383.972], [170.06, 426.832], [289.78, 426.832], [289.78, 383.972]]]
# ['170.06', '430.404', '567.757', '581.797']
# [[170.06], [170.06], [170.06]]
# ['170.06', '211.1', '551.677', '565.717']
# [[170.06], [170.06], [170.06]]
# -----------
# [[[170.06, 260.203], [170.06, 290.323], [430.404, 290.323], [430.404, 260.203]]]
# ['331.63', '508.348', '763.732', '777.772']
# [[170.06], [170.06], [170.06]]
# ['358.15', '508.363', '747.632', '761.672']
# [[170.06], [170.06], [170.06]]
# -----------
# [[[331.63, 64.22799999999995], [331.63, 94.36800000000005], [508.363, 94.36800000000005], [508.363, 64.22799999999995]]]
# ['435.22', '508.363', '731.552', '745.592']
#
#
# -----------
# [[[458.22, 96.40800000000002], [458.22, 110.44799999999998], [508.363, 110.44799999999998], [508.363, 96.40800000000002]]]
# ['392.71', '538.625', '262.048', '275.008']
# ['474.34', '537.57', '247.138', '260.098']
# -----------
# [[[392.71, 566.992], [392.71, 594.862], [538.625, 594.862], [538.625, 566.992]]]
# ['334.99', '537.57', '300.328', '313.288']
# [[334.99]]
# -----------
# [[[334.99, 528.712], [334.99, 541.672], [537.57, 541.672], [537.57, 528.712]]]
# {'label': 'author', 'points': [[170.06, 383.972], [170.06, 426.832], [289.78, 426.832], [289.78, 383.972]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[170.06, 260.203], [170.06, 290.323], [430.404, 290.323], [430.404, 260.203]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'journal', 'points': [[331.63, 64.22799999999995], [331.63, 94.36800000000005], [508.363, 94.36800000000005], [508.363, 64.22799999999995]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'date', 'points': [[458.22, 96.40800000000002], [458.22, 110.44799999999998], [508.363, 110.44799999999998], [508.363, 96.40800000000002]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'address', 'points': [[392.71, 566.992], [392.71, 594.862], [538.625, 594.862], [538.625, 566.992]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'affiliation', 'points': [[334.99, 528.712], [334.99, 541.672], [537.57, 541.672], [537.57, 528.712]], 'shape_type': 'polygon', 'flags': {}}
# User count 1
# -------------
# [{'label': 'author', 'points': [[170.06, 383.972], [170.06, 426.832], [289.78, 426.832], [289.78, 383.972]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'title', 'points': [[170.06, 260.203], [170.06, 290.323], [430.404, 290.323], [430.404, 260.203]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'journal', 'points': [[331.63, 64.22799999999995], [331.63, 94.36800000000005], [508.363, 94.36800000000005], [508.363, 64.22799999999995]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'date', 'points': [[458.22, 96.40800000000002], [458.22, 110.44799999999998], [508.363, 110.44799999999998], [508.363, 96.40800000000002]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'address', 'points': [[392.71, 566.992], [392.71, 594.862], [538.625, 594.862], [538.625, 566.992]], 'shape_type': 'polygon', 'flags': {}}, {'label': 'affiliation', 'points': [[334.99, 528.712], [334.99, 541.672], [537.57, 541.672], [537.57, 528.712]], 'shape_type': 'polygon', 'flags': {}}]
# -------------------------------------------------------------------------------------------
# ============================================================================
# 299

# %%
print('done')
# Out:
# done
