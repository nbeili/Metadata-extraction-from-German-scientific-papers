# %%
number=0

while True:

    names='11703_'+str(number)
    if number==10:
        break

    import pdfquery
    # loading a pdf
    pdf = pdfquery.PDFQuery(names+".pdf")
    pdf.load()
    # if you want, you can store the entire pdf as an xml file

    pdf.tree.write(names+".xml", pretty_print=True, encoding="utf-8")

    import xml.etree.ElementTree as ET
    tree = ET.parse(names+'.xml')
    root = tree.getroot()

    author=df['author'][number]
    title=df['title'][number]
    doi=df['doi'][number]

    bounding_box_list=[]
    author_list=[]
    title_list=[]
    doi_list=[]

    for child in root:
        print('START')
        print (child.tag,"----", child.attrib)
        for fchild in child:
            #print('----------------------------')
            print(fchild)
            #print('----------------------------')
            print (fchild.tag,"----", fchild.attrib)
            for ffchild in fchild:
                print (ffchild.tag,"----", ffchild.attrib)
                print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
                #print(ffchild.text)
                print(ffchild.attrib['x0'])

                try:
                    bounding_box_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                            ffchild.attrib['y1']]])

                    if ffchild.text.strip() in author and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                        author_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                          ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in title and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                        title_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                         ffchild.attrib['y1']]])
                    elif doi in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                        doi_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
                except:
                    continue
                #print(ffchild)
            print('END')
            print('\n')

    coordinates_author = []
    coordinates_doi = []
    coordinates_title = []

    for lst in author_list:
        bboxes=lst[1]
        print((bboxes))
        print('\n')
        apt1=[float(bboxes[0]),842-float(bboxes[3])]
        apt2=[float(bboxes[0]),842-float(bboxes[2])]
        apt3=[float(bboxes[1]),842-float(bboxes[2])]
        apt4=[float(bboxes[1]),842-float(bboxes[3])]
        coordinates_author.append([ apt1,apt2,apt3,apt4 ])
    print('-----------')
    print(coordinates_author)

    for lst in title_list:
        bboxes=lst[1]
        print((bboxes))
        print('\n')
        tpt1=[float(bboxes[0]),842-float(bboxes[3])]
        tpt2=[float(bboxes[0]),842-float(bboxes[2])]
        tpt3=[float(bboxes[1]),842-float(bboxes[2])]
        tpt4=[float(bboxes[1]),842-float(bboxes[3])]
        coordinates_title.append([ tpt1,tpt2,tpt3,tpt4 ])
    print('-----------')
    print(coordinates_title)

    for lst in doi_list:
        bboxes=lst[1]
        print((bboxes))
        print('\n')
        jpt1=[float(bboxes[0]),842-float(bboxes[3])]
        jpt2=[float(bboxes[0]),842-float(bboxes[2])]
        jpt3=[float(bboxes[1]),842-float(bboxes[2])]
        jpt4=[float(bboxes[1]),842-float(bboxes[3])]
        coordinates_doi.append([ jpt1,jpt2,jpt3,jpt4 ])
    print('-----------')
    print(coordinates_doi)


    lst=[coordinates_author,coordinates_title,coordinates_doi]
    lst
    
   

    abase = {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a1base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a2base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a3base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a4base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    tbase = {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t1base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t2base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    jbase = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j1base = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    
    ab=[abase,a1base,a2base,a3base,a4base]
    tb=[tbase,t1base,t2base]
    jb=[jbase,j1base]

    
    liste=[]
    try:
        counter=0
        for no in range(len(coordinates_author)):   

            ab[counter]['points']=lst[0][counter]
            print(ab[counter])
            liste.append(ab[counter])
            counter=counter+1

        counter=0
        for no in range(len(coordinates_title)):   

            tb[counter]['points']=lst[1][counter]
            print(tb[counter])
            liste.append(tb[counter])
            counter=counter+1    

        counter=0
        for no in range(len(coordinates_doi)):   

            jb[counter]['points']=lst[2][counter]
            print(jb[counter])
            liste.append(jb[counter])
            counter=counter+1
    except:
        print('============================================================================')
        print(number)
        number=number+1
        continue

    import base64
    import json

    file=names+".jpeg"
    image_data = base64.b64encode(open(file, "rb").read())
    imagedata=str(image_data)[1:].replace("'","")

    x ='''[{
      "version": "4.4.0",  "flags": {},

      "shapes": [
        {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "group_id": null,"shape_type": "polygon", "flags": {}
        },

        {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
          "group_id": null, "shape_type": "polygon","flags": {}
        },

        {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "group_id": null,"shape_type": "polygon","flags": {}
        }  ],

      "imagePath": "6041.jpg",
      "imageData": "...",
      "imageHeight": 2339,
      "imageWidth": 1653
    }]'''

    try:
        info=json.loads(x)
        print('User count', len(info))
        print("-------------")

        info[0]['shapes']=liste

        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
        print(info[0]['shapes'])
        print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

        info[0]['imageData']=imagedata
        print("-------------------------------------------------------------------------------------------")




        #info[0]['shapes'][0]['points']=lst[0][0]
        #info[0]['shapes'][1]['points']=lst[1][0]
        #info[0]['shapes'][2]['points']=lst[2][0]
        #print(key['shapes'])
        #info[0]['imageData']=imagedata
        #print("-------------------------------------------------------------------------------------------")



        for key in info:
            my_details=key
        name=names+".json"
        with open(name, 'w') as json_file:
            json.dump(my_details, json_file)
    except:
        
        print('============================================================================')
        print(number)
        number=number+1
        continue
    
        

    print('============================================================================')
    print(number)
    number=number+1
# Out:
# START
# LTPage ---- {'y0': '0', 'y1': '842.04', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '842.04', 'bbox': '[0, 0, 594.96, 842.04]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# <Element 'LTTextLineHorizontal' at 0x1eb1672de48>
# LTTextLineHorizontal ---- {'y0': '770.448', 'y1': '782.448', 'x0': '233.57', 'x1': '348.04', 'width': '114.47', 'height': '12.0', 'bbox': '[233.57, 770.448, 348.04, 782.448]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '770.448', 'y1': '782.448', 'x0': '233.57', 'x1': '348.04', 'width': '114.47', 'height': '12.0', 'bbox': '[233.57, 770.448, 348.04, 782.448]', 'index': '0'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 233.57
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1eb1672da08>
# LTTextBoxHorizontal ---- {'y0': '580.75', 'y1': '620.38', 'x0': '132.5', 'x1': '439.808', 'width': '307.308', 'height': '39.63', 'bbox': '[132.5, 580.75, 439.808, 620.38]', 'index': '1'}
# LTTextLineHorizontal ---- {'y0': '608.38', 'y1': '620.38', 'x0': '132.5', 'x1': '439.808', 'width': '307.308', 'height': '12.0', 'bbox': '[132.5, 608.38, 439.808, 620.38]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 132.5
# LTTextLineHorizontal ---- {'y0': '594.58', 'y1': '606.58', 'x0': '141.74', 'x1': '430.472', 'width': '288.732', 'height': '12.0', 'bbox': '[141.74, 594.58, 430.472, 606.58]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 141.74
# LTTextLineHorizontal ---- {'y0': '580.75', 'y1': '592.75', 'x0': '170.78', 'x1': '400.84', 'width': '230.06', 'height': '12.0', 'bbox': '[170.78, 580.75, 400.84, 592.75]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 170.78
# END
#
#
# <Element 'LTTextLineHorizontal' at 0x1eb1672d088>
# LTTextLineHorizontal ---- {'y0': '547.562', 'y1': '561.602', 'x0': '126.02', 'x1': '466.99', 'width': '340.97', 'height': '14.04', 'bbox': '[126.02, 547.562, 466.99, 561.602]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0':
 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '54.24', 'bbox': '[72.024, 310.898, 75.024, 365.138]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '310.898', 'y1': '365.138', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '54.24', 'bbox': '[72.024, 310.898, 75.024, 365.138]', 'index': '12'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1eb166f8808>
# LTTextBoxHorizontal ---- {'y0': '284.378', 'y1': '308.258', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '23.88', 'bbox': '[72.024, 284.378, 75.024, 308.258]', 'index': '13'}
# LTTextLineHorizontal ---- {'y0': '296.258', 'y1': '308.258', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '12.0', 'bbox': '[72.024, 296.258, 75.024, 308.258]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# LTTextLineHorizontal ---- {'y0': '284.378', 'y1': '296.378', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '12.0', 'bbox': '[72.024, 284.378, 75.024, 296.378]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# END
#
#
# <Element 'LTTextBoxHorizontal' at 0x1eb1679a048>
# LTTextBoxHorizontal ---- {'y0': '236.348', 'y1': '274.778', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '38.43', 'bbox': '[72.024, 236.348, 75.024, 274.778]', 'index': '14'}
# LTTextLineHorizontal ---- {'y0': '262.778', 'y1': '274.778', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '12.0', 'bbox': '[72.024, 262.778, 75.024, 274.778]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# LTTextLineHorizontal ---- {'y0': '248.228', 'y1': '260.228', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '12.0', 'bbox': '[72.024, 248.228, 75.024, 260.228]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# LTTextLineHorizontal ---- {'y0': '236.348', 'y1': '248.348', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '12.0', 'bbox': '[72.024, 236.348, 75.024, 248.348]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# END
#
#
# <Element 'LTTextLineVertical' at 0x1eb1534d648>
# LTTextLineVertical ---- {'y0': '140.588', 'y1': '228.668', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '88.08', 'bbox': '[72.024, 140.588, 75.024, 228.668]', 'word_margin': '0.1'}
# LTTextBoxVertical ---- {'y0': '140.588', 'y1': '228.668', 'x0': '72.024', 'x1': '75.024', 'width': '3.0', 'height': '88.08', 'bbox': '[72.024, 140.588, 75.024, 228.668]', 'index': '15'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72.024
# END
#
#
# ['247.97', '323.8', '608.38', '620.38']
#
#
# -----------
# [[[247.97, 221.62], [247.97, 233.62], [323.8, 233.62], [323.8, 221.62]]]
# ['109.7', '483.43', '575.162', '589.202']
#
#
# -----------
# [[[109.7, 252.798], [109.7, 266.83799999999997], [483.43, 266.83799999999997], [483.43, 252.798]]]
# ['213.41', '436.63', '363.779', '373.798']
#
#
# -----------
# [[[213.41, 468.202], [213.41, 478.221], [436.63, 478.221], [436.63, 468.202]]]
# {'label': 'author', 'points': [[247.97, 221.62], [247.97, 233.62], [323.8, 233.62], [323.8, 221.62]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'title', 'points': [[109.7, 252.798], [109.7, 266.83799999999997], [483.43, 266.83799999999997], [483.43, 252.798]], 'shape_type': 'polygon', 'flags': {}}
# {'label': 'doi', 'points': [[213.41, 468.202], [213.41, 478.221], [436.63, 478.221], [436.63, 468.202]], 'shape_type': 'polygon', 'flags': {}}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ea9ffa33bc46> in <module>
#     198
#     199     file=names+".jpeg"
# --> 200     image_data = base64.b64encode(open(file, "rb").read())
#     201     imagedata=str(image_data)[1:].replace("'","")
#     202
#
# FileNotFoundError: [Errno 2] No such file or directory: '11703_9.jpeg'

# %%
print('D')
# Out:
# D

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('11423_0.xml')
root = tree.getroot()

# %%
root
# Out:
# <Element 'pdfxml' at 0x27880b57048>

# %%
root.tag
# Out:
# 'pdfxml'

# %%
root.attrib
# Out:
# {'Author': 'Windows User',
#  'Creator': 'Microsoft® Word for Office 365',
#  'CreationDate': "D:20200705100732+02'00'",
#  'ModDate': "D:20200705100732+02'00'",
#  'Producer': 'Microsoft® Word for Office 365'}

# %%
for child in root:
    print('START')
    for fchild in child:
        for ffchild in fchild:
            print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
            print(ffchild.text)
            print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')

        print('END')
        print('\n')
# Out:
# START
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard,
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Thomas Prescher , Michael Schwarz , Yuval Yarom
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Spectre Attacks: Exploiting Speculative Execution.
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Politik am Centrum
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ist
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# angewandte Politikforschung (C·A·P).
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  A
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END

# %%
df.head(2)
# Out:
#                                               author year  \
# 0  Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...   na
# 1  Moritz Lipp, Michael Schwarz , Daniel Gruss, T...   na
#
#                                                title  \
# 0  Spectre Attacks: Exploiting Speculative Execut...
# 1                                           Meltdown
#
#                                        doi             journal publisher
# 0    https://spectreattack.com/spectre.pdf  meltdownattack.com        na
# 1  https://meltdownattack.com/meltdown.pdf  meltdownattack.com        na

# %%
author=df['author'][0]
title=df['title'][0]
journal=df['journal'][0]

bounding_box_list=[]
author_list=[]
title_list=[]
journal_list=[]

for child in root:
    print('START')
    print (child.tag,"----", child.attrib)
    for fchild in child:
        #print('----------------------------')
        #print(fchild)
        #print('----------------------------')
        print (fchild.tag,"----", fchild.attrib)
        for ffchild in fchild:
            print (ffchild.tag,"----", ffchild.attrib)
            print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
            print(ffchild.text)
            print(ffchild.attrib['x0'])
            
            try:
                bounding_box_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                            ffchild.attrib['y1']]])
            
                if ffchild.text.strip() in author and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                    author_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                          ffchild.attrib['y1']]])
                elif ffchild.text.strip() in title and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                    title_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                         ffchild.attrib['y1']]])
                elif journal in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>2:
                    journal_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                           ffchild.attrib['y1']]])
            except:
                continue
            print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
            #print(ffchild)
        print('END')
        print('\n')
# Out:
# START
# LTPage ---- {'y0': '0', 'y1': '841.92', 'x0': '0', 'x1': '594.96', 'width': '594.96', 'height': '841.92', 'bbox': '[0, 0, 594.96, 841.92]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# LTTextBoxHorizontal ---- {'y0': '708.762', 'y1': '731.442', 'x0': '51.96', 'x1': '538.594', 'width': '486.634', 'height': '22.68', 'bbox': '[51.96, 708.762, 538.594, 731.442]', 'index': '3'}
# LTTextLineHorizontal ---- {'y0': '720.882', 'y1': '731.442', 'x0': '54.84', 'x1': '538.594', 'width': '483.754', 'height': '10.56', 'bbox': '[54.84, 720.882, 538.594, 731.442]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard,
# 54.84
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# LTTextLineHorizontal ---- {'y0': '708.762', 'y1': '719.322', 'x0': '51.96', 'x1': '294.4', 'width': '242.44', 'height': '10.56', 'bbox': '[51.96, 708.762, 294.4, 719.322]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Thomas Prescher , Michael Schwarz , Yuval Yarom
# 51.96
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# END
#
#
# LTTextLineHorizontal ---- {'y0': '675.192', 'y1': '694.752', 'x0': '57.384', 'x1': '497.544', 'width': '440.16', 'height': '19.56', 'bbox': '[57.384, 675.192, 497.544, 694.752]', 'word_margin': '0.1'}
# LTTextBoxHorizontal ---- {'y0': '675.192', 'y1': '694.752', 'x0': '57.384', 'x1': '497.544', 'width': '440.16', 'height': '19.56', 'bbox': '[57.384, 675.192, 497.544, 694.752]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
 'colorspace': '["/DeviceRGB"]', 'bits': '8', 'imagemask': 'null', 'srcsize': '[964, 1]', 'stream': "<PDFStream(7): raw=35, {'Type': /'XObject', 'Subtype': /'Image', 'Width': 964, 'Height': 1, 'ColorSpace': /'DeviceRGB', 'BitsPerComponent': 8, 'Interpolate': False, 'Filter': /'FlateDecode', 'Length': 33}>"}
# LTFigure ---- {'y0': '126.73', 'y1': '127.23', 'x0': '50.95', 'x1': '412.35', 'width': '361.4', 'height': '0.5', 'bbox': '[50.95, 126.73, 412.35, 127.23]', 'name': 'Image7', 'matrix': '[361.4, 0.0, 0.0, 0.5, 50.95, 126.73]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# 50.95
# END

# %%
bounding_box_list
# Out:
# [['Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard,',
#   ['54.84', '538.594', '720.882', '731.442']],
#  ['Thomas Prescher , Michael Schwarz , Yuval Yarom',
#   ['51.96', '294.4', '708.762', '719.322']],
#  ['Spectre Attacks: Exploiting Speculative Execution.',
#   ['57.384', '497.544', '675.192', '694.752']],
#  ['lmut Metz ist wissenschaftliche Mitarbeiterin in der Bertelsmann Forschungs-gruppe',
#   ['57.963', '413.548', '177.17', '186.17']],
#  ['Politik am Centrum', ['51.96', '142.113', '164.09', '173.09']],
#  ['ist', ['401.853', '413.211', '164.09', '173.09']],
#  ['Forschungsassistentin in der Bertelsmann Forschungsgruppe Politik am Centrum für',
#   ['51.96', '413.542', '151.13', '160.13']],
#  ['angewandte Politikforschung (C·A·P).',
#   ['51.96', '205.1', '137.789', '147.749']],
#  ['', ['51.96', '54.96', '132.068', '144.068']],
#  ['', ['51.96', '54.96', '720.882', '792.768']],
#  ['', ['51.96', '57.398', '675.192', '709.228']],
#  ['A', ['51.96', '57.963', '177.17', '676.588']],
#  ['', ['50.9', '544.15', '776.27', '841.47']]]

# %%
author_list
# Out:
# [['Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard,',
#   ['54.84', '538.594', '720.882', '731.442']],
#  ['Thomas Prescher , Michael Schwarz , Yuval Yarom',
#   ['51.96', '294.4', '708.762', '719.322']]]

# %%
title_list
# Out:
# [['Spectre Attacks: Exploiting Speculative Execution.',
#   ['57.384', '497.544', '675.192', '694.752']]]

# %%
journal_list
# Out:
# []

# %%
coordinates_author = []
coordinates_journal = []
coordinates_title = []

for lst in author_list:
    bboxes=lst[1]
    print((bboxes))
    print('\n')
    apt1=[float(bboxes[0]),842-float(bboxes[3])]
    apt2=[float(bboxes[0]),842-float(bboxes[2])]
    apt3=[float(bboxes[1]),842-float(bboxes[2])]
    apt4=[float(bboxes[1]),842-float(bboxes[3])]
    coordinates_author.append([ apt1,apt2,apt3,apt4 ])
print('-----------')
print(coordinates_author)
# Out:
# ['54.024', '303.319', '613.953', '629.913']
#
#
# ['54.024', '316.965', '595.113', '611.073']
#
#
# ['54.024', '265.478', '576.253', '592.213']
#
#
# ['54.024', '315.034', '557.293', '573.253']
#
#
# ['54.024', '149.42', '538.453', '554.413']
#
#
# -----------
# [[[54.024, 212.087], [54.024, 228.04700000000003], [303.319, 228.04700000000003], [303.319, 212.087]], [[54.024, 230.92700000000002], [54.024, 246.88699999999994], [316.965, 246.88699999999994], [316.965, 230.92700000000002]], [[54.024, 249.78700000000003], [54.024, 265.74699999999996], [265.478, 265.74699999999996], [265.478, 249.78700000000003]], [[54.024, 268.74699999999996], [54.024, 284.707], [315.034, 284.707], [315.034, 268.74699999999996]], [[54.024, 287.587], [54.024, 303.547], [149.42, 303.547], [149.42, 287.587]]]

# %%
for lst in title_list:
    bboxes=lst[1]
    print((bboxes))
    print('\n')
    tpt1=[float(bboxes[0]),842-float(bboxes[3])]
    tpt2=[float(bboxes[0]),842-float(bboxes[2])]
    tpt3=[float(bboxes[1]),842-float(bboxes[2])]
    tpt4=[float(bboxes[1]),842-float(bboxes[3])]
    coordinates_title.append([ tpt1,tpt2,tpt3,tpt4 ])
print('-----------')
print(coordinates_title)
# Out:
# ['65.166', '397.409', '502.891', '522.931']
#
#
# ['54.024', '147.14', '477.211', '497.251']
#
#
# -----------
# [[[65.166, 319.06899999999996], [65.166, 339.109], [397.409, 339.109], [397.409, 319.06899999999996]], [[54.024, 344.749], [54.024, 364.789], [147.14, 364.789], [147.14, 344.749]]]

# %%
for lst in journal_list:
    bboxes=lst[1]
    print((bboxes))
    print('\n')
    jpt1=[float(bboxes[0]),842-float(bboxes[3])]
    jpt2=[float(bboxes[0]),842-float(bboxes[2])]
    jpt3=[float(bboxes[1]),842-float(bboxes[2])]
    jpt4=[float(bboxes[1]),842-float(bboxes[3])]
    coordinates_journal.append([ jpt1,jpt2,jpt3,jpt4 ])
print('-----------')
print(coordinates_journal)
# Out:
# -----------
# []

# %%
lst=[coordinates_author,coordinates_title,coordinates_journal]
lst
# Out:
# [[[[54.024, 212.087],
#    [54.024, 228.04700000000003],
#    [303.319, 228.04700000000003],
#    [303.319, 212.087]],
#   [[54.024, 230.92700000000002],
#    [54.024, 246.88699999999994],
#    [316.965, 246.88699999999994],
#    [316.965, 230.92700000000002]],
#   [[54.024, 249.78700000000003],
#    [54.024, 265.74699999999996],
#    [265.478, 265.74699999999996],
#    [265.478, 249.78700000000003]],
#   [[54.024, 268.74699999999996],
#    [54.024, 284.707],
#    [315.034, 284.707],
#    [315.034, 268.74699999999996]],
#   [[54.024, 287.587],
#    [54.024, 303.547],
#    [149.42, 303.547],
#    [149.42, 287.587]]],
#  [[[65.166, 319.06899999999996],
#    [65.166, 339.109],
#    [397.409, 339.109],
#    [397.409, 319.06899999999996]],
#   [[54.024, 344.749],
#    [54.024, 364.789],
#    [147.14, 364.789],
#    [147.14, 344.749]]],
#  []]

# %%
import base64
import json

file=names+".jpeg"
image_data = base64.b64encode(open(file, "rb").read())
imagedata=str(image_data)[1:].replace("'","")

x ='''[{
  "version": "4.4.0",  "flags": {},
  
  "shapes": [
    {
      "label": "author",
      "points": [       [250,269],[250,283],[329,283],[329,269]         ],
      "group_id": null,"shape_type": "polygon", "flags": {}
    },
    
    {
      "label": "title",
      "points": [        [197,332],[197,350],[383,350],[383,332]      ],
      "group_id": null, "shape_type": "polygon","flags": {}
    },
    
    {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "group_id": null,"shape_type": "polygon","flags": {}
    }  ],
    
  "imagePath": "1181.jpg",
  "imageData": "...",
  "imageHeight": 2339,
  "imageWidth": 1653
}]'''


info=json.loads(x)
print('User count', len(info))
print("-------------")


info[0]['shapes'][0]['points']=lst[0][0]
info[0]['shapes'][1]['points']=lst[1][0]
info[0]['shapes'][2]['points']=lst[2][0]
#print(key['shapes'])
info[0]['imageData']=imagedata
print("-------------------------------------------------------------------------------------------")



for key in info:
    my_details=key
name=names+".json"
with open(name, 'w') as json_file:
    json.dump(my_details, json_file)
# Out:
# User count 1
# -------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-a117e2bcee55> in <module>
#      42 info[0]['shapes'][0]['points']=lst[0][0]
#      43 info[0]['shapes'][1]['points']=lst[1][0]
# ---> 44 info[0]['shapes'][2]['points']=lst[2][0]
#      45 #print(key['shapes'])
#      46 info[0]['imageData']=imagedata
#
# IndexError: list index out of range

# %%
abase = {
      "label": "author",
      "points": [       [250,269],[250,283],[329,283],[329,269]         ],
      "shape_type": "polygon", "flags": {}
    }
tbase = {
      "label": "title",
      "points": [        [197,332],[197,350],[383,350],[383,332]      ],
       "shape_type": "polygon","flags": {}
    }
jbase = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
a1base={
      "label": "author",
      "points": [       [250,269],[250,283],[329,283],[329,269]         ],
      "shape_type": "polygon", "flags": {}
    }
a2base={
      "label": "author",
      "points": [       [250,269],[250,283],[329,283],[329,269]         ],
      "shape_type": "polygon", "flags": {}
    }
t1base={
      "label": "title",
      "points": [        [197,332],[197,350],[383,350],[383,332]      ],
       "shape_type": "polygon","flags": {}
    }

# %%
ll=[]
ll.append(abase)
ll.append(tbase)
ll.append(jbase)
ll.append(a1base)
ll.append(a2base)
ll.append(t1base)

# %%
ll

# %%
lst

# %%
ll[0]['points']=lst[0][0]
ll[1]['points']=lst[1][0]
ll[2]['points']=lst[2][0]
ll[3]['points']=lst[0][1]
ll[4]['points']=lst[0][2]
ll[5]['points']=lst[1][1]

# %%
ll

# %%
lssst=[]
counter=0
for x in [0,1]:
    
    abase = info[0]['shapes'][0]
    print(abase)
    print('%%%%%%%%%%%%%%')
    abase['points']=lst[0][counter]
    print(abase)
    lssst.append(abase)
    counter=counter+1
lssst

# %%
adic1="a"
adic2="b"
adic3="c"
adic4="d"

anames=[adic1,adic2,adic3,adic4]

# %%
number=0
for key in info:

    print("-------------")
    for lines in range(len(coordinates_author)-1):
        anames[number]=key['shapes'][0]
        anames[number]['points']=lst[0][lines+1]
        print(anames[number])
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        key['shapes'].append(anames[number])
        number=number+1
    for lines in range(len(coordinates_title)-1):
        b=key['shapes'][1]
        b['points']=lst[1][lines+1]
        key['shapes'].append(b)
    for lines in range(len(coordinates_journal)-1): 
        c=key['shapes'][2]
        c['points']=lst[2][lines+1]
        key['shapes'].append(c)
            
            

    
   # num=num+1
    #key['shapes'].append(label)
print(key['shapes'])
key['imageData']=imagedata
print("-------------------------------------------------------------------------------------------")

# %%
for key in info:
    print(key['shapes'][0])
    print('')
    print(key['shapes'][1])
    print('')
    print(key['shapes'][2])
    print('')
    print(key['shapes'][3])
    print('')
    print(key['shapes'][4])
    print('')
    print(key['shapes'][5])
    print('')
    print(key['shapes'][6])

# %%
info[0]['shapes'][4]['points']=lst[0][1]

# %%
for key in info:
    print(key['shapes'][0])
    print('')
    print(key['shapes'][1])
    print('')
    print(key['shapes'][2])
    print('')
    print(key['shapes'][3])
    print('')
    print(key['shapes'][4])
    print('')
    print(key['shapes'][5])
    print('')
    print(key['shapes'][6])

# %%
info

# %%
for key in info:
    my_details=key
name="1181_0.json"
with open(name, 'w') as json_file:
    json.dump(my_details, json_file)

# %%
import base64
import json

file="1181_0.png"
image_data = base64.b64encode(open(file, "rb").read())
imagedata=str(image_data)[1:].replace("'","")

x ='''[{
  "version": "4.4.0",  "flags": {},
  
  "shapes": [
    {
      "label": "author",
      "points": [       [250,269],[250,283],[329,283],[329,269]         ],
      "group_id": null,"shape_type": "polygon", "flags": {}
    },
    
    {
      "label": "title",
      "points": [        [197,332],[197,350],[383,350],[383,332]      ],
      "group_id": null, "shape_type": "polygon","flags": {}
    },
    
    {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "group_id": null,"shape_type": "polygon","flags": {}
    }  ],
    
  "imagePath": "1181.jpg",
  "imageData": "...",
  "imageHeight": 2339,
  "imageWidth": 1653
}]'''


info=json.loads(x)
print('User count', len(info))
print("-------------")

info[0]['shapes']=ll


print(key['shapes'])
info[0]['imageData']=imagedata
print("-------------------------------------------------------------------------------------------")



for key in info:
    my_details=key
name="1181_0.json"
with open(name, 'w') as json_file:
    json.dump(my_details, json_file)

# %%
info

# %%
for key in info:
    print(key['shapes'][0])
    print('')
    print(key['shapes'][1])
    print('')
    print(key['shapes'][2])
    print('')
    print(key['shapes'][3])
    print('')
    print(key['shapes'][4])
    print('')
    print(key['shapes'][5])
    print('')
    print(key['shapes'][6])

# %%
lst

# %%
for key in info:
    print((key['shapes']))

# %%
coordinates_author.append([ [bboxes[0],str(int(bboxes[3])-842)] , [bboxes[0],str(int(bboxes[1])-842)] , [bboxes[2],str(int(bboxes[1])-842)] , [bboxes[2],str(int(bboxes[2])-842)] ])

# %%
for c in nn:
    if c[0] == '':
        #print(c)
        if c[0] in journal:
            print('Yes')

# %%
for x in al:
    print(x, '\n')

# %%
root[0][0][0].text

# %%
for article in root.findall('LTPage'):
    print(article.text)
    print("------------------")

# %%
print(d)

# %%
article_data

# %%
import pandas as pd
df = pd.DataFrame(columns={'author','title','journal','year','doi','publisher'})

# %%
df.loc[0,'author'] = article_data[0][0]

# %%
xx=0
for x in article_data:
    df.loc[xx,'author']= x[0]
    df.loc[xx,'title']= x[1]
    df.loc[xx,'journal']= x[2]
    df.loc[xx,'year']= x[3]
    df.loc[xx,'doi']= x[4]
    df.loc[xx,'publisher']= x[5]
    xx=xx+1

# %%
df

# %%
df.to_excel("dataframe.xlsx")

# %%
df['author'][0]

# %%
dois = article.findall('url')
try:
    f=dois[0]
    print("food")
except:
    print("noooo")

# %%
########### dataframe cleaning and preprocessing complete ###########################
import pandas as pd
df = pd.read_excel("dataframe.xlsx")
df

counter=0
for x in df['author']:
    df['author'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['author'][counter])
    counter = counter+1
#df['author'][0].replace("[","").replace("'","").replace("]","")

counter=0
for x in df['year']:
    df['year'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['year'][counter])
    counter = counter+1
   
counter=0
for x in df['title']:
    df['title'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['title'][counter])
    counter = counter+1
    
counter=0
for x in df['doi']:
    df['doi'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['doi'][counter])
    counter = counter+1
      
counter=0
for x in df['journal']:
    df['journal'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['journal'][counter])
    counter = counter+1
    
counter=0
for x in df['publisher']:
    df['publisher'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['publisher'][counter])
    counter = counter+1
    
df=df.replace('',"na")
df
# Out:
#                                                 author year  \
# 0    Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...   na
# 1    Moritz Lipp, Michael Schwarz , Daniel Gruss, T...   na
# 2                                         Frank Manola   na
# 3               Michael L. Brodie, Michael Stonebraker   na
# 4     Mark F. Hornick, Joe D. Morrison, Farshad Nayeri   na
# ..                                                 ...  ...
# 559                                         E. F. Codd   na
# 560                                         E. F. Codd   na
# 561                                      Markus Tresch   na
# 562                                         E. F. Codd   na
# 563  Markus Casper, Gayane Grigoryan, Oliver Gronz,...   na
#
#                                                  title  \
# 0    Spectre Attacks: Exploiting Speculative Execut...
# 1                                             Meltdown
# 2    An Evaluation of Object-Oriented DBMS Developm...
# 3    DARWIN: On the Incremental Migration of Legacy...
# 4    Integrating Heterogeneous, Autonomous, Distrib...
# ..                                                 ...
# 559  Further Normalization of the Data Base Relatio...
# 560  Derivability, Redundancy and Consistency of Re...
# 561  Principles of Distributed Object Database Lang...
# 562  The Capabilities of Relational Database Manage...
# 563  Analysis of projected hydrological behavior of...
#
#                                                  doi  \
# 0              https://spectreattack.com/spectre.pdf
# 1            https://meltdownattack.com/meltdown.pdf
# 2    db/journals/gtelab/index.html#TR-0263-08-94-165
# 3    db/journals/gtelab/index.html#TR-0222-10-92-165
# 4    db/journals/gtelab/index.html#TR-0174-12-91-165
# ..                                               ...
# 559                                               na
# 560                                               na
# 561         https://doi.org/10.3929/ethz-a-006651652
# 562                                               na
# 563         https://doi.org/10.5194/hess-16-409-2012
#
#                                                journal publisher
# 0                                   meltdownattack.com        na
# 1                                   meltdownattack.com        na
# 2                        GTE Laboratories Incorporated        na
# 3                        GTE Laboratories Incorporated        na
# 4                        GTE Laboratories Incorporated        na
# ..                                                 ...       ...
# 559  Research Report / RJ / IBM / San Jose, California        na
# 560  Research Report / RJ / IBM / San Jose, California        na
# 561  ETH Zurich, Department of Computer Science / T...        na
# 562  Research Report / RJ / IBM / San Jose, California        na
# 563                Hydrology and Earth System Sciences        na
#
# [564 rows x 6 columns]

# %%
df['author'].replace('na','Thorsten Theobald, Christoph Meinel',inplace=True)

# %%
df['doi'].replace('na','db/journals/gtelab/index.html#TM-0332-11-90-165',inplace=True)
