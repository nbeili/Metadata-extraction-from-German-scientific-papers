# %%
########### dataframe cleaning and preprocessing ###########################
# importing dataframe.xlsx file

import pandas as pd
df = pd.read_excel("dataframe.xlsx")
df

counter=0
for x in df['author']:
    df['author'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['author'][counter])
    counter = counter+1
#df['author'][0].replace("[","").replace("'","").replace("]","")

counter=0
for x in df['year']:
    df['year'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['year'][counter])
    counter = counter+1
   
counter=0
for x in df['title']:
    df['title'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['title'][counter])
    counter = counter+1
    
counter=0
for x in df['doi']:
    df['doi'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['doi'][counter])
    counter = counter+1
      
counter=0
for x in df['journal']:
    df['journal'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['journal'][counter])
    counter = counter+1
    
counter=0
for x in df['publisher']:
    df['publisher'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['publisher'][counter])
    counter = counter+1
    
df=df.replace('',"na")
df.head()

# %% [markdown]
# ## Generating Data in form of .docx files

# %% [markdown]
# ##### Go to link https://pdf2docx.com/ and convert your pdf file to docx file and save it in the same folder to generate new docx files

# %%
# generating new data from template in the form of docx files 

import re
from docx import Document

temp = ""

# function to replace text in docx file
def docx_replace_regex(doc_obj, regex , replace, temp):
    
    # p variable refers to paragraph below
    for p in doc_obj.paragraphs:
        inline = p.runs
        
        if regex in p.text:            
            for i in range(len(inline)):                
                temp = temp + inline[i].text
                
                if regex in temp:
                    if replace=="na":
                        continue 
                    else:
                        temp = temp.replace(regex, replace)
                        inline[i].text=temp        

'''print function to check the layout of word file , this may vary from template to template, 
this is key step for the annotations generation later on, if the templates do not have special variations (like sometimes 
title will be read as 6-7 lines while in reality it is just one line and so on...), then it is fine, otherwise
you may need to create a new one similar to original manually and it will not be very demanding task in most cases
'''                       
def printf (doc_obj):
    
    for p in doc_obj.paragraphs:
        if p.text=='':
            continue
        else:
            print(p.text)
    print(" \n ############################################################################# \n")

# put the text you want to replace here, depending on how many classes of metadata is in that template and comment the other ones
text_to_replace1 = "Marion Linke Sonderegger"
text_to_replace2 = "Mehr als nur staatliche Kinderbetreuung"
text_to_replace3 = "Optionserweiterungen und Geschlechterrollen in der"
text_to_replace4 = "aktuellen dänischen Familienpolitik"
text_to_replace5 = "ZeS-Arbeitspapier Nr. 07/2004"
#text_to_replace6 = "TUTS-WP-1-2005"

# select data from dataframe to replace with
count=0
number=0
stopnumber=0
for row in df.index:
    replace1 = df['author'][count]
    replace2 = df['title'][count]
    replace3 = ""
    replace4 = ""
    replace5 = df['journal'][count]
    #replace5 = ""
    #replace6 = ""
    #print(replace1)
    count=count+1
    
    
    ############### put the templace docx file name here to read  ########################
    
    filename = "10939.docx"
    doc = Document(filename)
    docx_replace_regex(doc, text_to_replace1 , replace1, temp)
    docx_replace_regex(doc, text_to_replace2 , replace2, temp)
    docx_replace_regex(doc, text_to_replace3 , replace3, temp)
    docx_replace_regex(doc, text_to_replace4 , replace4, temp)
    docx_replace_regex(doc, text_to_replace5 , replace5, temp)
    #docx_replace_regex(doc, text_to_replace6 , replace6, temp)
    printf (doc)
    print(" \n ---------------------------------------------------------------------------------------- \n")

    # save the generated file
    doc.save('10939_' + str(number) +  '.docx')
    number = number+1
    stopnumber=stopnumber+1
    
    # put the stop number to how many files you want to generate
    if stopnumber==563:
        break
