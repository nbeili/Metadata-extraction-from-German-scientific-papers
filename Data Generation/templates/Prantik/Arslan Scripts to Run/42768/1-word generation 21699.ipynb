# %%
import pandas as pd
df = pd.read_excel("1.xlsx")

# %%
############ PAPER 31506 FINAL  ####################

import re
from docx import Document

temp = ""
def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        for i in range(len(inline)):
            print(inline[i].text)
  
        
        print("####################")
        if regex in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if regex in temp:
                    if replace=="na":
                        #print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                        continue 
                    else:
                        temp = temp.replace(regex, replace)
                        #print(temp)
                        inline[i].text=temp        
        
#    for i in range(len(inline)):
#        print(inline[i].text)
  
def printf (doc_obj):
    
    for p in doc_obj.paragraphs:
        if p.text=='':
            continue
        else:
            print(p.text)
            #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
    print(" \n ############################################################################# \n")

    
    
    

text_to_replace1 = "tzrtzrtzrtztrzr"
text_to_replace2 = "rtzrtzrtzrtztrzgf"
text_to_replace3 = "July 2011"
#text_to_replace4 = "xx"
text_to_replace5 = "fgggffghghgh"
text_to_replace6 = 'ffffffff'


count=0
number=0
stopnumber=0
for row in df.index:

    replace1 = df['title'][count+4000]
    replace2 = df['author'][count+4000]
    replace3 = "July " + str(df['year'][count+4000])
    #replace4 = 'Seite 6                       '+df['journal'][count]
    replace5 = df['affiliation'][count+4000]
    replace6 = df['journal'][count+4000]
    #replace6 = df['doi'][count]
    #print(replace1)
    count=count+1
    
    
    
    filename = "42768.docx"
    doc = Document(filename)
    docx_replace_regex(doc, text_to_replace1 , replace1, temp)
    docx_replace_regex(doc, text_to_replace2 , replace2, temp)
    docx_replace_regex(doc, text_to_replace3 , replace3, temp)
    #docx_replace_regex(doc, text_to_replace4 , replace4, temp)
    docx_replace_regex(doc, text_to_replace5 , replace5, temp)
    docx_replace_regex(doc, text_to_replace6 , replace6, temp)
    
    printf (doc)
    
    print(" \n ---------------------------------------------------------------------------------------- \n")

    doc.save('42768_' + str(number) +  '.docx')
    number = number+1
    stopnumber=stopnumber+1
    if stopnumber==1600:
        break

    
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = "AAAAAAAAAAAAAAA"


# filename = "1181.docx"
# doc = Document(filename)
# docx_replace_regex(doc, text_to_replace1 , replace1, temp)
# docx_replace_regex(doc, text_to_replace2 , replace2, temp)
# docx_replace_regex(doc, text_to_replace3 , replace3, temp)
# docx_replace_regex(doc, text_to_replace4 , replace4, temp)
# docx_replace_regex(doc, text_to_replace5 , replace5, temp)
# docx_replace_regex(doc, text_to_replace6 , replace6, temp)

# doc.save('1181e.docx')
# Out:
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# The influence of information technology strategy and management support to the internal business process, competitive advantage, financial and non-financial performance of the company.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# The influence of information technology strategy and management support to the internal business process, competitive advantage, financial and non-financial performance of the company.
# ####################
# Endang Siti Astuti, Suhadak, Sri Mangesti Rahayu, Wilopo
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# The influence of information technology strategy and management support to the internal business process, competitive advantage, financial and non-financial performance of the company.
# ####################
# Endang Siti Astuti, Suhadak, Sri Mangesti Rahayu, Wilopo
# ####################
# ####################
# ####################
# ####################
# July 1997
# ####################
# ####################
# ####################
#
# ####################
# Staatliche Hochschule für Bildende Künste – Städelschule (Frankfurt am Main)
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# The influence of information technology strategy and management support to the internal business process, competitive advantage, financial and non-financial performance of the company.
# ####################
# Endang Siti Astuti, Suhadak, Sri Mangesti Rahayu, Wilopo
# ####################
# ####################
# ####################
# ####################
# July 1997
# ####################
# ####################
# ####################
#
# ####################
# Staatliche Hochschule für Bildende Künste – Städelschule (Frankfurt am Main)
# Zeitschrift für Berufs- und Wirtschaftspädagogik
#
#
# The influence of information technology strategy and management support to the internal business process, competitive advantage, financial and non-financial performance of the company.
# Endang Siti Astuti, Suhadak, Sri Mangesti Rahayu, Wilopo
# July 1997
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Crowd logistics: the contribution of social crowds in logistics activities.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Crowd logistics: the contribution of social crowds in logistics activities.
# ####################
# Andreas Mladenow, Christine Bauer , Christine Strauss
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Crowd logistics: the contribution of social crowds in logistics activities.
# ####################
# Andreas Mladenow, Christine Bauer , Christine Strauss
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Europa-Universität Viadrina (Frankfurt (Oder))
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Crowd logistics: the contribution of social crowds in logistics activities.
# ####################
# Andreas Mladenow, Christine Bauer , Christine Strauss
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Europa-Universität Viadrina (Frankfurt (Oder))
# Zeitschrift für Berufs- und Wirtschaftspädagogik
#
#
# Crowd logistics: the contribution of social crowds in logistics activities.
# Andreas Mladenow, Christine Bauer , Christine Strauss
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# DaVinci - A model-driven web engineering framework.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# DaVinci - A model-driven web engineering framework.
# ####################
# Andreas Langegger, Juumlrgen Palkoska, Roland R. Wagner
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# DaVinci - A model-driven web engineering framework.
# ####################
# Andreas Langegger, Juumlrgen Palkoska, Roland R. Wagner
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Technische Universität Bergakademie Freiberg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# DaVinci - A model-driven web engineering framework.
# ####################
# Andreas Langegger, Juumlrgen Palkoska, Roland R. Wagner
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Technische Universität Bergakademie Freiberg
# ZUMA Nachrichten
#
#
# DaVinci - A model-driven web engineering framework.
# Andreas Langegger, Juumlrgen Palkoska, Roland R. Wagner
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using the structure of B+-trees for enhancing logging mechanisms of databases.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using the structure of B+-trees for enhancing logging mechanisms of databases.
# ####################
# Peter Kieseberg, Sebastian Schrittwieser, Lorcan Morgan, Martin Mulazzani, Markus Huber , Edgar R. Weippl
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using the structure of B+-trees for enhancing logging mechanisms of databases.
# ####################
# Peter Kieseberg, Sebastian Schrittwieser, Lorcan Morgan, Martin Mulazzani, Markus Huber , Edgar R. Weippl
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Albert-Ludwigs-Universität Freiburg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using the structure of B+-trees for enhancing logging mechanisms of databases.
# ####################
# Peter Kieseberg, Sebastian Schrittwieser, Lorcan Morgan, Martin Mulazzani, Markus Huber , Edgar R. Weippl
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Albert-Ludwigs-Universität Freiburg
# ZUMA Nachrichten
#
#
# Using the structure of B+-trees for enhancing logging mechanisms of databases.
# Peter Kieseberg, Sebastian Schrittwieser, Lorcan Morgan, Martin Mulazzani, Markus Huber , Edgar R. Weippl
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Ontology-based heuristic patent search.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Ontology-based heuristic patent search.
# ####################
# Cong-Phuoc Phan, Hong-Quang Nguyen, Tan-Tai Nguyen
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Ontology-based heuristic patent search.
# ####################
# Cong-Phuoc Phan, Hong-Quang Nguyen, Tan-Tai Nguyen
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Evangelische Hochschule Freiburg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Ontology-based heuristic patent search.
# ####################
# Cong-Phuoc Phan, Hong-Quang Nguyen, Tan-Tai Nguyen
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Evangelische Hochschule Freiburg
# ZUMA Nachrichten
#
#
# Ontology-based heuristic patent search.
# Cong-Phuoc Phan, Hong-Quang Nguyen, Tan-Tai Nguyen
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# AdaptRDF: adaptive storage management for RDF databases.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# AdaptRDF: adaptive storage management for RDF databases.
# ####################
# Hooran MahmoudiNasab, Sherif Sakr
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# AdaptRDF: adaptive storage management for RDF databases.
# ####################
# Hooran MahmoudiNasab, Sherif Sakr
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Hochschule für Musik Freiburg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# AdaptRDF: adaptive storage management for RDF databases.
# ####################
# Hooran MahmoudiNasab, Sherif Sakr
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Hochschule für Musik Freiburg
# ZUMA Nachrichten
#
#
# AdaptRDF: adaptive storage management for RDF databases.
# Hooran MahmoudiNasab, Sherif Sakr
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method engineering perspective for service-oriented system engineering.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
# A method engineering perspective for service-oriented system engineering.
# ####################
# Boutheina Gherib, Youcef Baghdadi, Naoufel Kraiumlem
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method engineering perspective for service-oriented system engineering.
# ####################
# Boutheina Gherib, Youcef Baghdadi, Naoufel Kraiumlem
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Hochschule für Kunst, Design und Populäre Musik Freiburg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method engineering perspective for service-oriented system engineering.
# ####################
# Boutheina Gherib, Youcef Baghdadi, Naoufel Kraiumlem
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Hochschule für Kunst, Design und Populäre Musik Freiburg
# ZUMA Nachrichten
#
#
# A method engineering perspective for service-oriented system engineering.
# Boutheina Gherib, Youcef Baghdadi, Naoufel Kraiumlem
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using web search logs to identify query classification terms.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using web search logs to identify query classification terms.
# ####################
# Isak Taksa, Sarah Zelikovitz, Amanda Spink
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using web search logs to identify query classification terms.
# ####################
# Isak Taksa, Sarah Zelikovitz, Amanda Spink
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Katholische Hochschule Freiburg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Using web search logs to identify query classification terms.
# ####################
# Isak Taksa, Sarah Zelikovitz, Amanda Spink
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Katholische Hochschule Freiburg
# ZUMA Nachrichten
#
#
# Using web search logs to identify query classification terms.
# Isak Taksa, Sarah Zelikovitz, Amanda Spink
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semantic-syntax model for XML query construction.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semantic-syntax model for XML query construction.
# ####################
# Keng Hoon Gan, Keat Keong Phang
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semantic-syntax model for XML query construction.
# ####################
# Keng Hoon Gan, Keat Keong Phang
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Pädagogische Hochschule Freiburg
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semantic-syntax model for XML query construction.
# ####################
# Keng Hoon Gan, Keat Keong Phang
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Pädagogische Hochschule Freiburg
# ZUMA Nachrichten
#
#
# A semantic-syntax model for XML query construction.
# Keng Hoon Gan, Keat Keong Phang
# July 1996
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Calculation of account reachability risk for users having multiple SNS accounts from users profile and regional information.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Calculation of account reachability risk for users having multiple SNS accounts from users profile and regional information.
# ####################
# Ayano Yoshikuni, Chiemi Watanabe
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Calculation of account reachability risk for users having multiple SNS accounts from users profile and regional information.
# ####################
# Ayano Yoshikuni, Chiemi Watanabe
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Hochschule Geisenheim
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Calculation of account reachability risk for users having multiple SNS accounts from users profile and regional information.
# ####################
# Ayano Yoshikuni, Chiemi Watanabe
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Hochschule Geisenheim
# Zeitschrift für Berufs- und Wirtschaftspädagogik
#
#
# Calculation of account reachability risk for users having multiple SNS accounts from users profile and regional information.
# Ayano Yoshikuni, Chiemi Watanabe
# July 2000
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Web ontology data matching for integration: method and framework.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Web ontology data matching for integration: method and framework.
# ####################
# Chao Wang, Jie Lu , Guangquan Zhang
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Web ontology data matching for integration: method and framework.
# ####################
# Chao Wang, Jie Lu , Guangquan Zhang
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Fachhochschule für öffentliche Verwaltung Nordrhein-Westfalen (Gelsenkirchen)
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Web ontology data matching for integration: method and framework.
# ####################
# Chao Wang, Jie Lu , Guangquan Zhang
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Fachhochschule für öffentliche Verwaltung Nordrhein-Westfalen (Gelsenkirchen)
# WZB-Mitteilungen
#
#
# Web ontology data matching for integration: method and framework.
# Chao Wang, Jie Lu , Guangquan Zhang
# July 2000
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A model for web-based course registration systems.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A model for web-based course registration systems.
# ####################
# Ruben Estevez, Sean Rankin, Ricardo Silva, Indratmo
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A model for web-based course registration systems.
# ####################
# Ruben Estevez, Sean Rankin, Ricardo Silva, Indratmo
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Westfälische Hochschule Gelsenkirchen Bocholt Recklinghausen
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A model for web-based course registration systems.
# ####################
# Ruben Estevez, Sean Rankin, Ricardo Silva, Indratmo
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Westfälische Hochschule Gelsenkirchen Bocholt Recklinghausen
# Journal of Econometrics
#
#
# A model for web-based course registration systems.
# Ruben Estevez, Sean Rankin, Ricardo Silva, Indratmo
# July 2000
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method for detecting local events using the spatiotemporal locality of microblog posts.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method for detecting local events using the spatiotemporal locality of microblog posts.
# ####################
# Takuya Sugitani, Masumi Shirakawa, Takahiro Hara, Shojiro Nishio
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method for detecting local events using the spatiotemporal locality of microblog posts.
# ####################
# Takuya Sugitani, Masumi Shirakawa, Takahiro Hara, Shojiro Nishio
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Duale Hochschule Gera-Eisenach
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A method for detecting local events using the spatiotemporal locality of microblog posts.
# ####################
# Takuya Sugitani, Masumi Shirakawa, Takahiro Hara, Shojiro Nishio
# ####################
# ####################
# ####################
# ####################
# July 2000
# ####################
# ####################
# ####################
#
# ####################
# Duale Hochschule Gera-Eisenach
# Journal of Econometrics
#
#
# A method for detecting local events using the spatiotemporal locality of microblog posts.
# Takuya Sugitani, Masumi Shirakawa, Takahiro Hara, Shojiro Nishio
# July 2000
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semi-automatic approach for bridging DSMLs with UML.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semi-automatic approach for bridging DSMLs with UML.
# ####################
# Manuel Wimmer
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semi-automatic approach for bridging DSMLs with UML.
# ####################
# Manuel Wimmer
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Freie Theologische Hochschule Gießen
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# A semi-automatic approach for bridging DSMLs with UML.
# ####################
# Manuel Wimmer
# ####################
# ####################
# ####################
# ####################
# July 1996
# ####################
# ####################
# ####################
#
# ####################
# Freie Theologische Hochschule Gießen
# Journal of Econometrics
#
#
# ...
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Cleaning House: The Impact of Information Technology Monitoring on Employee Theft and Productivity.
# ####################
# Lamar Pierce, Daniel C. Snow, Andrew McAfee
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Friedrich-Schiller-Universität Jena
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Cleaning House: The Impact of Information Technology Monitoring on Employee Theft and Productivity.
# ####################
# Lamar Pierce, Daniel C. Snow, Andrew McAfee
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Friedrich-Schiller-Universität Jena
# ZA-Information / Zentralarchiv für Empirische Sozialforschung
#
#
# Cleaning House: The Impact of Information Technology Monitoring on Employee Theft and Productivity.
# Lamar Pierce, Daniel C. Snow, Andrew McAfee
# July 2010
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# On Maximizing the Net Present Value of a Project Under Renewable Resource Constraints.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# On Maximizing the Net Present Value of a Project Under Renewable Resource Constraints.
# ####################
# Mario Vanhoucke, Erik Demeulemeester, Willy Herroelen
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# On Maximizing the Net Present Value of a Project Under Renewable Resource Constraints.
# ####################
# Mario Vanhoucke, Erik Demeulemeester, Willy Herroelen
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Hochschule Kaiserslautern
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# On Maximizing the Net Present Value of a Project Under Renewable Resource Constraints.
# ####################
# Mario Vanhoucke, Erik Demeulemeester, Willy Herroelen
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Hochschule Kaiserslautern
# ZA-Information / Zentralarchiv für Empirische Sozialforschung
#
#
# On Maximizing the Net Present Value of a Project Under Renewable Resource Constraints.
# Mario Vanhoucke, Erik Demeulemeester, Willy Herroelen
# July 2010
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Effects of E-Waste Regulation on New Product Introduction.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Effects of E-Waste Regulation on New Product Introduction.
# ####################
# Erica L. Plambeck, Qiong Wang
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Effects of E-Waste Regulation on New Product Introduction.
# ####################
# Erica L. Plambeck, Qiong Wang
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Technische Universität Kaiserslautern
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Effects of E-Waste Regulation on New Product Introduction.
# ####################
# Erica L. Plambeck, Qiong Wang
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Technische Universität Kaiserslautern
# ZA-Information / Zentralarchiv für Empirische Sozialforschung
#
#
# Effects of E-Waste Regulation on New Product Introduction.
# Erica L. Plambeck, Qiong Wang
# July 2010
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Revolving Rating Analysts and Ratings of Mortgage-Backed and Asset-Backed Securities: Evidence from LinkedIn.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Revolving Rating Analysts and Ratings of Mortgage-Backed and Asset-Backed Securities: Evidence from LinkedIn.
# ####################
# John X. Jiang, Isabel Y. Wang, K. Philip Wang
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Revolving Rating Analysts and Ratings of Mortgage-Backed and Asset-Backed Securities: Evidence from LinkedIn.
# ####################
# John X. Jiang, Isabel Y. Wang, K. Philip Wang
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Hochschule für Musik Karlsruhe
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# Revolving Rating Analysts and Ratings of Mortgage-Backed and Asset-Backed Securities: Evidence from LinkedIn.
# ####################
# John X. Jiang, Isabel Y. Wang, K. Philip Wang
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Hochschule für Musik Karlsruhe
# ZA-Information / Zentralarchiv für Empirische Sozialforschung
#
#
# Revolving Rating Analysts and Ratings of Mortgage-Backed and Asset-Backed Securities: Evidence from LinkedIn.
# John X. Jiang, Isabel Y. Wang, K. Philip Wang
# July 2010
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# tzrtzrtzrtztrzr
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# From Wires to Partners: How the Internet Has Fostered RampD Collaborations Within Firms.
# ####################
# rtzrtzrtzrtztrzgf
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# From Wires to Partners: How the Internet Has Fostered RampD Collaborations Within Firms.
# ####################
# Chris M. Forman, Nicolas van Zeebroeck
# ####################
# ####################
# ####################
# ####################
# July 2011
# ####################
# ####################
# ####################
#
# ####################
# fgggffghghgh
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# From Wires to Partners: How the Internet Has Fostered RampD Collaborations Within Firms.
# ####################
# Chris M. Forman, Nicolas van Zeebroeck
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Hochschule Karlsruhe – Technik und Wirtschaft
# ####################
# ffffffff
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
#
# ####################
#
# ####################
#
# From Wires to Partners: How the Internet Has Fostered RampD Collaborations Within Firms.
# ####################
# Chris M. Forman, Nicolas van Zeebroeck
# ####################
# ####################
# ####################
# ####################
# July 2010
# ####################
# ####################
# ####################
#
# ####################
# Hochschule Karlsruhe – Technik und Wirtschaft
# ZA-Information / Zentralarchiv für Empirische Sozialforschung
#
#
# From Wires to Partners: How the Internet Has Fostered RampD Collaborations Within Firms.
# Chris M. Forman, Nicolas van Zeebroeck
# July 2010
#
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------

# %%
print('Done')
# Out:
# Done

# %%
############ PAPER 10939

import re
from docx import Document

text_to_replace1 = "Marion Linke Sonderegger"
replace1 = "Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom"

text_to_replace2 = "Mehr als nur staatliche Kinderbetreuung"
replace2 = "Spectre Attacks: Exploiting Speculative Execution"

text_to_replace3 = "Optionserweiterungen und Geschlechterrollen in der"
replace3 = ""

text_to_replace4 = "aktuellen dänischen Familienpolitik"
replace4 = ""

text_to_replace5 = "ZeS-Arbeitspapier Nr. 07/2004"
replace5 = "meltdownattack.com"



temp = ""


def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        print("####################")
        if regex in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if regex in temp:
                    temp = temp.replace(regex, replace)
                    #print(temp)
                    inline[i].text=temp        
        
        for i in range(len(inline)):
            print(inline[i].text)
            

        #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = "AAAAAAAAAAAAAAA"


filename = "10939.docx"
doc = Document(filename)
docx_replace_regex(doc, text_to_replace1 , replace1, temp)
docx_replace_regex(doc, text_to_replace2 , replace2, temp)
docx_replace_regex(doc, text_to_replace3 , replace3, temp)
docx_replace_regex(doc, text_to_replace4 , replace4, temp)
docx_replace_regex(doc, text_to_replace5 , replace5, temp)
doc.save('452885e.docx')
# Out:
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Mehr als nur staatliche Kinderbetreuung
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail: marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Spectre Attacks: Exploiting Speculative Execution
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail: marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Spectre Attacks: Exploiting Speculative Execution
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail: marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Spectre Attacks: Exploiting Speculative Execution
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail: marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Spectre Attacks: Exploiting Speculative Execution
# ####################
# ####################
# ####################
# meltdownattack.com
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail: marion.linke@sfb597.uni-bremen.de

# %%
############ PAPER 4336

import re
from docx import Document

text_to_replace1 = "Heinz Timmermann"
replace1 = "Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom"

text_to_replace2 = "Aspekte von Machtbehauptung und Opposition im Kommunismus"
replace2 = "Spectre Attacks: Exploiting Speculative Execution"

text_to_replace3 = "Revolution und Gegenbewegung"
replace3 = ""

text_to_replace4 = "Bericht des BIOst Nr. 6/1998"
replace4 = "meltdownattack.com"

temp = ""


def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        print("####################")
        if regex in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if regex in temp:
                    temp = temp.replace(regex, replace)
                    #print(temp)
                    inline[i].text=temp        
        
        for i in range(len(inline)):
            print(inline[i].text)
            

        #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = "AAAAAAAAAAAAAAA"


filename = "4336.docx"
doc = Document(filename)
docx_replace_regex(doc, text_to_replace1 , replace1, temp)
docx_replace_regex(doc, text_to_replace2 , replace2, temp)
docx_replace_regex(doc, text_to_replace3 , replace3, temp)
docx_replace_regex(doc, text_to_replace4 , replace4, temp)
doc.save('452885e.docx')
# Out:
# ####################
#
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Revolution und Gegenbewegung
# ####################
# ####################
# Aspekte von Machtbehauptung und Opposition imKom munismus
# ####################
# ####################
# Bericht des BIOst Nr. 6/1998
# ####################
# ####################
# ####################
# ####################
# ####################
# Kurzfassung
# ####################
# ####################
# Vorbemerkung
# ####################
# ####################
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# ####################
# ####################
# Ergebnisse
# ####################
# ####################
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# ####################
# ####################
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# ####################
# ####################
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# ####################
# ####################
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# ####################
# ####################
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism
#
# us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
# ####################
#
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
# Revolution und Gegenbewegung
# ####################
# ####################
# Aspekte von Machtbehauptung und Opposition imKom munismus
# ####################
# ####################
# Bericht des BIOst Nr. 6/1998
# ####################
# ####################
# ####################
# ####################
# ####################
# Kurzfassung
# ####################
# ####################
# Vorbemerkung
# ####################
# ####################
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# ####################
# ####################
# Ergebnisse
# ####################
# ####################
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# ####################
# ####################
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# ####################
# ####################
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# ####################
# ####################
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# ####################
# ####################
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism
#
# us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
# ####################
#
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
#
# ####################
# ####################
# Aspekte von Machtbehauptung und Opposition imKom munismus
# ####################
# ####################
# Bericht des BIOst Nr. 6/1998
# ####################
# ####################
# ####################
# ####################
# ####################
# Kurzfassung
# ####################
# ####################
# Vorbemerkung
# ####################
# ####################
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# ####################
# ####################
# Ergebnisse
# ####################
# ####################
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# ####################
# ####################
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# ####################
# ####################
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# ####################
# ####################
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# ####################
# ####################
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism
#
# us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
# ####################
#
# ####################
# ####################
# ####################
# ####################
# ####################
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher 0002, Michael Schwarz 0001, Yuval Yarom
# ####################
# ####################
#
# ####################
# ####################
# Aspekte von Machtbehauptung und Opposition imKom munismus
# ####################
# ####################
# meltdownattack.com
# ####################
# ####################
# ####################
# ####################
# ####################
# Kurzfassung
# ####################
# ####################
# Vorbemerkung
# ####################
# ####################
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# ####################
# ####################
# Ergebnisse
# ####################
# ####################
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# ####################
# ####################
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# ####################
# ####################
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# ####################
# ####################
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# ####################
# ####################
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism
#
# us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-

# %%
############ PAPER 4336 FINAL  ####################

import re
from docx import Document

temp = ""
def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        #print("####################")
        if regex in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if regex in temp:
                    if replace=="na":
                        #print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                        continue 
                    else:
                        temp = temp.replace(regex, replace)
                        #print(temp)
                        inline[i].text=temp        
        
#         for i in range(len(inline)):
#             print(inline[i].text)
  
def printf (doc_obj):
    
    for p in doc_obj.paragraphs:
        if p.text=='':
            continue
        else:
            print(p.text)
            #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
    print(" \n ############################################################################# \n")

    
    
    
text_to_replace1 = "Heinz Timmermann"
text_to_replace2 = "Revolution und Gegenbewegung"
text_to_replace3 = "Aspekte von Machtbehauptung und Opposition imKom munismus"
text_to_replace4 = "Bericht des BIOst Nr. 6/1998"
#text_to_replace5 = "Working Papers"
#text_to_replace6 = "TUTS-WP-1-2005"

count=0
number=0
stopnumber=0
for row in df.index:

    replace1 = df['author'][count]
    replace2 = df['title'][count]
    replace3 = ""
    replace4 = df['journal'][count]
    #replace5 = ""
    #replace6 = ""
    #print(replace1)
    count=count+1
    
    
    
    filename = "4336.docx"
    doc = Document(filename)
    docx_replace_regex(doc, text_to_replace1 , replace1, temp)
    docx_replace_regex(doc, text_to_replace2 , replace2, temp)
    docx_replace_regex(doc, text_to_replace3 , replace3, temp)
    docx_replace_regex(doc, text_to_replace4 , replace4, temp)
    #docx_replace_regex(doc, text_to_replace5 , replace5, temp)
    #docx_replace_regex(doc, text_to_replace6 , replace6, temp)
    
    printf (doc)
    
    print(" \n ---------------------------------------------------------------------------------------- \n")

    doc.save('4336_' + str(number) +  '.jpeg')
    number = number+1
    stopnumber=stopnumber+1
    if stopnumber==5:
        break

    
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = "AAAAAAAAAAAAAAA"


# filename = "1181.docx"
# doc = Document(filename)
# docx_replace_regex(doc, text_to_replace1 , replace1, temp)
# docx_replace_regex(doc, text_to_replace2 , replace2, temp)
# docx_replace_regex(doc, text_to_replace3 , replace3, temp)
# docx_replace_regex(doc, text_to_replace4 , replace4, temp)
# docx_replace_regex(doc, text_to_replace5 , replace5, temp)
# docx_replace_regex(doc, text_to_replace6 , replace6, temp)

# doc.save('1181e.docx')
# Out:
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher , Michael Schwarz , Yuval Yarom
# Spectre Attacks: Exploiting Speculative Execution.
# meltdownattack.com
# Kurzfassung
# Vorbemerkung
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# Ergebnisse
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Moritz Lipp, Michael Schwarz , Daniel Gruss, Thomas Prescher , Werner Haas, Stefan Mangard, Paul Kocher, Daniel Genkin, Yuval Yarom, Mike Hamburg
# Meltdown
# meltdownattack.com
# Kurzfassung
# Vorbemerkung
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# Ergebnisse
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# An Evaluation of Object-Oriented DBMS Developments: 1994 Edition.
# GTE Laboratories Incorporated
# Kurzfassung
# Vorbemerkung
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# Ergebnisse
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael L. Brodie, Michael Stonebraker
# DARWIN: On the Incremental Migration of Legacy Information Systems
# GTE Laboratories Incorporated
# Kurzfassung
# Vorbemerkung
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# Ergebnisse
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Mark F. Hornick, Joe D. Morrison, Farshad Nayeri
# Integrating Heterogeneous, Autonomous, Distributed Applications Using the DOM Prototype.
# GTE Laboratories Incorporated
# Kurzfassung
# Vorbemerkung
# Der vorliegende Bericht befaßt sich exem plarisch m it Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kom munisten seit der Oktoberrevolution von 1917 sowie m it Bestrebungen, aus der kom munistischen Bewegung heraus reform orientierte Gegenbewegungen zu bilden. Dabei wird an ei nigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unt er Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Partei en und zieht darüber hinaus Beiträge vornehm - lich russischer und deutscher Spezialisten heran.
# Ergebnisse
# 1. Nach Freigabe einer kritischen Geschichts  diskussion im Zeichen der Glasnost Gorbat-schows entstanden in Rußland starke Tende   nzen, die Ereignisse des Oktober 1917 als
# "Putsch" einer kleinen Machtclique zu charak terisieren und nicht länger als breit veranker-te "Revolution". Eine solche Interpretation scheint jedoch zumindest verkürzt. Gewiß läßt sich die gewaltsam e Machtergreifung durch Lenin und seine Anhänger in engerem Sinne
# tatsächlich als "Putsch" einer kleinen Minderh eit definieren. Diese Minderheit hätte aber keinerlei Durchsetzungschancen gehabt, hätte n ihn seine Protagonisten nicht m it Forde-rungen verbunden, die unter der Bevölkerung damals ungeheuer populär waren.
# Nicht weniger problem atisch ist es, die dara us hervorgegangene kom munistische Diktatur auf ihren Aspekt von Zwang und Gewalt zu reduz ieren. Natürlich stand dieser Aspekt im Vordergrund und bildete die Voraussetzung für die KP-Herrschaft. Dabei darf jedoch nicht übersehen werden, daß die revolutionären Um brüche zugleich auch Konsens für das Re-gimeschuf en. Dies geschah in einer W eise, daß den Millionen repressierten "Absteigern" in der Gesellschaft Millionen von "Aufsteige rn" gegenüberstanden, die dem Regim eihre oft steile Karriere verdankten und es entsprechend unterstützten.
# 3. Paradoxerweise bewirkte Stalins These von der Möglichkeit des "Sozialism us in einem Land", die die Vorstellungen von Marx und Leni n geradezu auf den Kopf stellten, einen weiteren Konsensschub, weil sie den traditionelle n Internationalismus mit demgroßrussi-schen Nationalismus verband. Denn fortan ging es vorrangig um Stärkung und Moderni-
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------

# %%
########### dataframe cleaning and preprocessing complete ###########################
import pandas as pd
df = pd.read_excel("dataframe.xlsx")
df

counter=0
for x in df['author']:
    df['author'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['author'][counter])
    counter = counter+1
#df['author'][0].replace("[","").replace("'","").replace("]","")

counter=0
for x in df['year']:
    df['year'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['year'][counter])
    counter = counter+1
   
counter=0
for x in df['title']:
    df['title'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['title'][counter])
    counter = counter+1
    
counter=0
for x in df['doi']:
    df['doi'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['doi'][counter])
    counter = counter+1
      
counter=0
for x in df['journal']:
    df['journal'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['journal'][counter])
    counter = counter+1
    
counter=0
for x in df['publisher']:
    df['publisher'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['publisher'][counter])
    counter = counter+1
    
df=df.replace('',"na")
df
# Out:
#                                                 author year  \
# 0    Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...   na
# 1    Moritz Lipp, Michael Schwarz , Daniel Gruss, T...   na
# 2                                         Frank Manola   na
# 3               Michael L. Brodie, Michael Stonebraker   na
# 4     Mark F. Hornick, Joe D. Morrison, Farshad Nayeri   na
# 5                                         Frank Manola   na
# 6                                         Frank Manola   na
# 7    Alejandro P. Buchmann, M. Tamer Özsu, Dimitrio...   na
# 8                          Frank Manola, Sandra Heiler   na
# 9                                         Frank Manola   na
# 10                                        Frank Manola   na
# 11   Frank Manola, Mark F. Hornick, Alejandro P. Bu...   na
# 12                                        Frank Manola   na
# 13                    Farshad Nayeri, Benjamin Hurwitz   na
# 14                                 Michael Stonebraker   na
# 15                          David Beech, Cetin Ozbutun   na
# 16   Krishna G. Kulkarni, Jim Melton, Jonathan Baue...   na
# 17                                           Phil Shaw   na
# 18     Jim Melton, Jonathan Bauer, Krishna G. Kulkarni   na
# 19                                         David Beech   na
# 20                                         Rolf Sander   na
# 21                                       Thomas Ludwig   na
# 22                 Werner Emde, Claus-Rainer Rollinger   na
# 23       Christoph Beierle, Udo Pletat, Hans Uszkoreit   na
# 24            Ulrike Rackow, Ido Dagan, Ulrike Schwall   na
# 25                              Brigitte Bartsch-Spörl   na
# 26                    Erich Gehlen, Burkhard Kehrbusch   na
# 27                         Markus Höhfeld, Gert Smolka   na
# 28                                       Birgit Wesche   na
# 29                                   Christopher Habel   na
# ..                                                 ...  ...
# 534                         Elena Dubrova, Harald Sack   na
# 535                                      Lothar Breuer   na
# 536                                      Peter Dierolf   na
# 537               Alexander Kaplan, Rainer Tichatschke   na
# 538                  Christoph W. Keßler, Helmut Seidl   na
# 539                      Christoph Meinel, Harald Sack   na
# 540  Jochen Bern, Jordan Gergov, Christoph Meinel, ...   na
# 541                       Peter Gritzmann, Victor Klee   na
# 542                     R. J. Gardner, Peter Gritzmann   na
# 543  Ulrich Hertrampf, Clemens Lautemann, Thomas Sc...   na
# 544            Peter Gritzmann, Victor Klee, B. S. Tam   na
# 545                                        Dieter Baum   na
# 546                                  Markus Müller-Olm   na
# 547  Klaus Jansen, Petra Scheffler, Gerhard J. Woeg...   na
# 548                                       Jens Hofmann   na
# 549                                       Klaus Jansen   na
# 550  Jacques Wainer, Michael Eckmann, Siome Goldens...   na
# 551                                                 na   na
# 552                                         E. F. Codd   na
# 553                                         E. F. Codd   na
# 554                                        Michael Ley   na
# 555                             E. F. Codd, C. J. Date   na
# 556                                         E. F. Codd   na
# 557  Rita Ley, Markus Casper, Hugo Hellebrand, Ralf...   na
# 558                                 Patrick A. V. Hall   na
# 559                                         E. F. Codd   na
# 560                                         E. F. Codd   na
# 561                                      Markus Tresch   na
# 562                                         E. F. Codd   na
# 563  Markus Casper, Gayane Grigoryan, Oliver Gronz,...   na
#
#                                                  title  \
# 0    Spectre Attacks: Exploiting Speculative Execut...
# 1                                             Meltdown
# 2    An Evaluation of Object-Oriented DBMS Developm...
# 3    DARWIN: On the Incremental Migration of Legacy...
# 4    Integrating Heterogeneous, Autonomous, Distrib...
# 5    Object Model Capabilities For Distributed Obje...
# 6    Integrating Object-Oriented Applications and M...
# 7     Towards a Transaction Management System for DOM.
# 8    A RISC Object Model for Object System Interope...
# 9    MetaObject Protocol Concepts for a RISC Object...
# 10   Object Data Language Facilities for Multimedia...
# 11   Object Data Model Facilities for Multimedia Da...
# 12           Distributed Object Management Technology.
# 13   Experiments with Dispatching in a Distributed ...
# 14              Muffin: A Distributed Database Machine
# 15   Object Oriented DBMS as a Generalization of Re...
# 16                      Inheritance for ADTs (revised)
# 17                  Modification of User Defined Types
# 18      Object ADTs (with improvements for Value ADTs)
# 19                Unification of Value and Object ADTs
# 20   Die Repräsentation räumlichen Wissens und die ...
# 21         Algebraical Optimization of FTA-Expressions
# 22       Wissensrepräsentation und Maschinelles Lernen
# 23               An Algebraic Characterization of STUF
# 24   A Combined Symbolic-Empirical Apprach for the ...
# 25                     Zur Systemarchitektur von LILOG
# 26   Mengenorientierte Auswertung von Anfragen in d...
# 27       Definite Resolution over Constraint Languages
# 28        Dokumentation der Syntax der LILOG-Grammatik
# 29   Cognitive Linguistics: The Processing of Spati...
# ..                                                 ...
# 534  Probabilistic Verification of Multiple-Valued ...
# 535  From Markov Jump Processes to Inhomogeneous BMAPs
# 536  The Structure Theorem for Linear Transfer Systems
# 537                 Proximal Point Methods in Examples
# 538  ForkLight: A Control-Synchronous Parallel Prog...
# 539         Improving XOR-Node Placement for (+)-OBDDs
# 540  Boolean Manipulation with Free BDDs - First Ex...
# 541  Separation by Hyperplanes in Finite-Dimensiona...
# 542  Successive Determination and Verification of P...
# 543          On the Power of Polynomial Bit-Reductions
# 544                  Cross-Positive Matrices Revisited
# 545                     Vom M/G/1- zum BMAP/G/1-Modell
# 546  Precise Interprocedural Dependence Analysis of...
# 547                       The Disjoint Cliques Problem
# 548  Stability Conditions for the BMAP/G/1 Queue wi...
# 549  On the Complexity of a Licence Constrained Job...
# 550  Differences in productivity and impact across ...
# 551  The 1995 SQL Reunion: People, Project, and Pol...
# 552  Normalized Data Base Structure: A Brief Tutorial.
# 553  Relational Completeness of Data Base Sublangua...
# 554  DBLP: A WWW Bibliography on Databases and Logi...
# 555  Interactive Support for Non-Programmers: The R...
# 556  Data Base Sublanguage Founded on the Relationa...
# 557  Catchment classification by runoff behaviour w...
# 558  Common Subexpression Identification in General...
# 559  Further Normalization of the Data Base Relatio...
# 560  Derivability, Redundancy and Consistency of Re...
# 561  Principles of Distributed Object Database Lang...
# 562  The Capabilities of Relational Database Manage...
# 563  Analysis of projected hydrological behavior of...
#
#                                                   doi  \
# 0               https://spectreattack.com/spectre.pdf
# 1             https://meltdownattack.com/meltdown.pdf
# 2     db/journals/gtelab/index.html#TR-0263-08-94-165
# 3     db/journals/gtelab/index.html#TR-0222-10-92-165
# 4     db/journals/gtelab/index.html#TR-0174-12-91-165
# 5     db/journals/gtelab/index.html#TM-0149-06-89-165
# 6     db/journals/gtelab/index.html#TR-0310-11-95-165
# 7     db/journals/gtelab/index.html#TR-0146-06-91-165
# 8     db/journals/gtelab/index.html#TR-0231-08-93-165
# 9     db/journals/gtelab/index.html#TR-0244-12-93-165
# 10    db/journals/gtelab/index.html#TR-0169-12-91-165
# 11    db/journals/gtelab/index.html#TM-0332-11-90-165
# 12    db/journals/gtelab/index.html#TM-0014-06-88-165
# 13    db/journals/gtelab/index.html#TR-0236-09-93-165
# 14                                                 na
# 15                db/conf/x3h2/index.html#X3H2-90-412
# 16            db/conf/x3h2/index.html#X3H2-91-133rev1
# 17                db/conf/x3h2/index.html#X3H2-90-292
# 18            db/conf/x3h2/index.html#X3H2-91-083rev1
# 19                db/conf/x3h2/index.html#X3H2-92-062
# 20                                                 na
# 21                                                 na
# 22                                                 na
# 23                                                 na
# 24                                                 na
# 25                                                 na
# 26                                                 na
# 27                                                 na
# 28                                                 na
# 29                                                 na
# ..                                                ...
# 534                                                na
# 535                                                na
# 536                                                na
# 537                                                na
# 538                                                na
# 539                                                na
# 540                                                na
# 541                                                na
# 542                                                na
# 543                                                na
# 544                                                na
# 545                                                na
# 546                                                na
# 547                                                na
# 548                                                na
# 549                                                na
# 550  http://www.ic.unicamp.br/~reltech/2012/12-08.pdf
# 551   http://www.mcjones.org/System_R/SQL_Reunion_95/
# 552                                                na
# 553                                                na
# 554                                                na
# 555                                                na
# 556                                                na
# 557         https://doi.org/10.5194/hess-15-2947-2011
# 558                                                na
# 559                                                na
# 560                                                na
# 561          https://doi.org/10.3929/ethz-a-006651652
# 562                                                na
# 563          https://doi.org/10.5194/hess-16-409-2012
#
#                                                journal  \
# 0                                   meltdownattack.com
# 1                                   meltdownattack.com
# 2                        GTE Laboratories Incorporated
# 3                        GTE Laboratories Incorporated
# 4                        GTE Laboratories Incorporated
# 5                        GTE Laboratories Incorporated
# 6                        GTE Laboratories Incorporated
# 7                        GTE Laboratories Incorporated
# 8                        GTE Laboratories Incorporated
# 9                        GTE Laboratories Incorporated
# 10                       GTE Laboratories Incorporated
# 11                       GTE Laboratories Incorporated
# 12                       GTE Laboratories Incorporated
# 13                       GTE Laboratories Incorporated
# 14                University of California at Berkeley
# 15                                           ANSI X3H2
# 16                                           ANSI X2H2
# 17                                           ANSI X3H2
# 18                                           ANSI X3H2
# 19                                           ANSI X3H2
# 20                                         IWBS Report
# 21                                        LILOG-Report
# 22                                        LILOG-Report
# 23                                        LILOG-Report
# 24                                         IWBS Report
# 25                                          LILOG-Memo
# 26                                        LILOG-Report
# 27                                        LILOG-Report
# 28                                          LILOG-Memo
# 29                                        LILOG-Report
# ..                                                 ...
# 534  Universität Trier, Mathematik/Informatik, Fors...
# 535  Universität Trier, Mathematik/Informatik, Fors...
# 536  Universität Trier, Mathematik/Informatik, Fors...
# 537  Universität Trier, Mathematik/Informatik, Fors...
# 538  Universität Trier, Mathematik/Informatik, Fors...
# 539  Universität Trier, Mathematik/Informatik, Fors...
# 540  Universität Trier, Mathematik/Informatik, Fors...
# 541  Universität Trier, Mathematik/Informatik, Fors...
# 542  Universität Trier, Mathematik/Informatik, Fors...
# 543  Universität Trier, Mathematik/Informatik, Fors...
# 544  Universität Trier, Mathematik/Informatik, Fors...
# 545  Universität Trier, Mathematik/Informatik, Fors...
# 546  Universität Trier, Mathematik/Informatik, Fors...
# 547  Universität Trier, Mathematik/Informatik, Fors...
# 548  Universität Trier, Mathematik/Informatik, Fors...
# 549  Universität Trier, Mathematik/Informatik, Fors...
# 550                                   Technical Report
# 551              Digital System Research Center Report
# 552  Research Report / RJ / IBM / San Jose, California
# 553  Research Report / RJ / IBM / San Jose, California
# 554                                Compulog Newsletter
# 555  Research Report / RJ / IBM / San Jose, California
# 556  Research Report / RJ / IBM / San Jose, California
# 557                Hydrology and Earth System Sciences
# 558  Technical Rep. UKSC 0060, IBM United Kingdom S...
# 559  Research Report / RJ / IBM / San Jose, California
# 560  Research Report / RJ / IBM / San Jose, California
# 561  ETH Zurich, Department of Computer Science / T...
# 562  Research Report / RJ / IBM / San Jose, California
# 563                Hydrology and Earth System Sciences
#
#                                              publisher
# 0                                                   na
# 1                                                   na
# 2                                                   na
# 3                                                   na
# 4                                                   na
# 5                                                   na
# 6                                                   na
# 7                                                   na
# 8                                                   na
# 9                                                   na
# 10                                                  na
# 11                                                  na
# 12                                                  na
# 13                                                  na
# 14                                                  na
# 15                                                  na
# 16                                                  na
# 17                                                  na
# 18                                                  na
# 19                                                  na
# 20   IBM Germany Science Center, Institute for Know...
# 21                                IBM Deutschland GmbH
# 22                                IBM Deutschland GmbH
# 23                                IBM Deutschland GmbH
# 24   IBM Germany Science Center, Institute for Know...
# 25                                IBM Deutschland GmbH
# 26                                IBM Deutschland GmbH
# 27                                IBM Deutschland GmbH
# 28                                IBM Deutschland GmbH
# 29                                IBM Deutschland GmbH
# ..                                                 ...
# 534                                                 na
# 535                                                 na
# 536                                                 na
# 537                                                 na
# 538                                                 na
# 539                                                 na
# 540                                                 na
# 541                                                 na
# 542                                                 na
# 543                                                 na
# 544                                                 na
# 545                                                 na
# 546                                                 na
# 547                                                 na
# 548                                                 na
# 549                                                 na
# 550  Institute of Computing, University of Campinas...
# 551                                                 na
# 552                                                 na
# 553                                                 na
# 554                                                 na
# 555                                                 na
# 556                                                 na
# 557                                                 na
# 558                                                 na
# 559                                                 na
# 560                                                 na
# 561                                                 na
# 562                                                 na
# 563                                                 na
#
# [564 rows x 6 columns]

# %%
authors=df['author'][0].split()
df1.index
df2=df1.loc[authors[:],:]
x1=df2['x1'].min()
x4=df2['x4'].max()
y1=df2['y1'].min()
y2=df2['y2'].max()
x1,x4,y1,y2
pt_1=x1,y1
pt_2=x1,y2
pt_3=x4,y2
pt_4=x4,y1
pt_1,pt_2,pt_3,pt_4
# Out:
# ((358, 752), (358, 875), (1252, 875), (1252, 752))

# %%
countit=0
while True:
    try:
        df2=''
        df3=''
        df4=''
        authors=df['author'][countit].split()
        df1.index
        df2=df1.loc[authors[:],:]
        x1=df2['x1'].min()
        x4=df2['x4'].max()
        y1=df2['y1'].min()
        y2=df2['y2'].max()
        x1,x4,y1,y2
        pt_1=x1,y1
        pt_2=x1,y2
        pt_3=x4,y2
        pt_4=x4,y1
        print(pt_1,pt_2,pt_3,pt_4)

        titles=df['title'][countit].split()
        df1.index
        df3=df1.loc[titles[:],:]
        x1=df3['x1'].min()
        x4=df3['x4'].max()
        y1=df3['y1'].min()
        y2=df3['y2'].max()
        x1,x4,y1,y2
        pt_1=x1,y1
        pt_2=x1,y2
        pt_3=x4,y2
        pt_4=x4,y1
        print(pt_1,pt_2,pt_3,pt_4)

        journals=df['journal'][countit].split()
        df1.index
        df4=df1.loc[journals[:],:]
        x1=df4['x1'].min()
        x4=df4['x4'].max()
        y1=df4['y1'].min()
        y2=df4['y2'].max()
        x1,x4,y1,y2
        pt_1=x1,y1
        pt_2=x1,y2
        pt_3=x4,y2
        pt_4=x4,y1
        print(pt_1,pt_2,pt_3,pt_4)
        
        print(countit)
        countit=countit+1
        if countit==10:
            break
        print('-----------------------------------------------------------------------------------------------------')
    except:
        countit=countit+1
        if countit==10:
            break
        print(countit)
        
        print('-----------------------------------------------------------------------------------------------------')
        continue
# Out:
# (358, 752) (358, 875) (1252, 875) (1252, 752)
# (385, 962) (385, 1054) (1227, 1054) (1227, 962)
# (644, 1153) (644, 1181) (968, 1181) (968, 1153)
# 0
# -----------------------------------------------------------------------------------------------------
# (358.0, 752.0) (358.0, 875.0) (1252.0, 875.0) (1252.0, 752.0)
# 2
# -----------------------------------------------------------------------------------------------------
# 3
# -----------------------------------------------------------------------------------------------------
# (632.0, 842.0) (632.0, 870.0) (757.0, 870.0) (757.0, 842.0)
# 4
# -----------------------------------------------------------------------------------------------------
# 5
# -----------------------------------------------------------------------------------------------------
# 6
# -----------------------------------------------------------------------------------------------------
# 7
# -----------------------------------------------------------------------------------------------------
# 8
# -----------------------------------------------------------------------------------------------------
# 9
# -----------------------------------------------------------------------------------------------------
# C:\Users\Sindhu\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
journals=df['journal'][0].split()
df1.index
df4=df1.loc[journals[:],:]
x1=df4['x1'].min()
x4=df4['x4'].max()
y1=df4['y1'].min()
y2=df4['y2'].max()
x1,x4,y1,y2
pt_1=x1,y1
pt_2=x1,y2
pt_3=x4,y2
pt_4=x4,y1
pt_1,pt_2,pt_3,pt_4
# Out:
# ((644, 1153), (644, 1181), (968, 1181), (968, 1153))

# %%
df1.index
# Out:
# Index(['Paul', 'Kocher,', 'Daniel', 'Genkin,', 'Daniel', 'Gruss,', 'Werner',
#        'Haas,', 'Mike', 'Hamburg,', 'Moritz', 'Lipp,', 'Stefan', 'Mangard,',
#        'Thomas', 'Prescher', ',', 'Michael', 'Schwarz', ',', 'Yuval', 'Yarom',
#        'Spectre', 'Attacks:', 'Exploiting', 'Speculative', 'Execution.',
#        'meltdownattack.com'],
#       dtype='object', name='text')

# %%
df2=df1.loc[ll[:],:]
x1=df2['x1'].min()
x4=df2['x4'].max()
y1=df2['y1'].min()
y2=df2['y2'].max()
x1,x4,y1,y2
# Out:
# (358, 1252, 752, 875)

# %%
pt_1=x1,y1
pt_2=x1,y2
pt_3=x4,y2
pt_4=x4,y1

# %%
pt_1,pt_2,pt_3,pt_4
# Out:
# ((358, 752), (358, 875), (1252, 875), (1252, 752))

# %%
import pandas as pd
df1=pd.read_excel('1.xlsx')
df1=df1.rename(columns={'left':'x1','top':'y1'})
df1['x2']=df1['x1']
df1['y2']=df1['y1']+df1['height']
df1['x3']=df1['x1']+df1['width']
df1['y3']=df1['y2']
df1['x4']=df1['x3']
df1['y4']=df1['y1']
df1=df1.drop(columns=['width','height'])
df1=df1.set_index('text')
df1.head()
# Out:
#           x1   y1   x2   y2   x3   y3   x4   y4
# text
# Paul     358  752  358  780  426  780  426  752
# Kocher,  437  752  437  785  559  785  559  752
# Daniel   571  752  571  780  673  780  673  752
# Genkin,  684  752  684  785  806  785  806  752
# Daniel   818  752  818  780  920  780  920  752

# %%
df1.index[0]
# Out:
# 'Paul'

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6a861a8b3f1a> in <module>()
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
countit=1
# authors=df['author'][countit].split()
# df1.index
# df2=df1.loc[authors[:],:]
# x1=df2['x1'].min()
# x4=df2['x4'].max()
# y1=df2['y1'].min()
# y2=df2['y2'].max()
# x1,x4,y1,y2
# pt_1=x1,y1
# pt_2=x1,y2
# pt_3=x4,y2
# pt_4=x4,y1
# print(pt_1,pt_2,pt_3,pt_4)

# titles=df['title'][countit].split()
# df1.index
# df3=df1.loc[titles[:],:]
# x1=df3['x1'].min()
# x4=df3['x4'].max()
# y1=df3['y1'].min()
# y2=df3['y2'].max()
# x1,x4,y1,y2
# pt_1=x1,y1
# pt_2=x1,y2
# pt_3=x4,y2
# pt_4=x4,y1
# print(pt_1,pt_2,pt_3,pt_4)

# journals=df['journal'][countit].split()
# df1.index
# df4=df1.loc[journals[:],:]
# x1=df4['x1'].min()
# x4=df4['x4'].max()
# y1=df4['y1'].min()
# y2=df4['y2'].max()
# x1,x4,y1,y2
# pt_1=x1,y1
# pt_2=x1,y2
# pt_3=x4,y2
# pt_4=x4,y1
# print(pt_1,pt_2,pt_3,pt_4)
# Out:
# (644, 1153) (644, 1181) (968, 1181) (968, 1153)

# %%
df.head()
# Out:
#                                               author year  \
# 0  Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...   na
# 1  Moritz Lipp, Michael Schwarz , Daniel Gruss, T...   na
# 2                                       Frank Manola   na
# 3             Michael L. Brodie, Michael Stonebraker   na
# 4   Mark F. Hornick, Joe D. Morrison, Farshad Nayeri   na
#
#                                                title  \
# 0  Spectre Attacks: Exploiting Speculative Execut...
# 1                                           Meltdown
# 2  An Evaluation of Object-Oriented DBMS Developm...
# 3  DARWIN: On the Incremental Migration of Legacy...
# 4  Integrating Heterogeneous, Autonomous, Distrib...
#
#                                                doi  \
# 0            https://spectreattack.com/spectre.pdf
# 1          https://meltdownattack.com/meltdown.pdf
# 2  db/journals/gtelab/index.html#TR-0263-08-94-165
# 3  db/journals/gtelab/index.html#TR-0222-10-92-165
# 4  db/journals/gtelab/index.html#TR-0174-12-91-165
#
#                          journal publisher
# 0             meltdownattack.com        na
# 1             meltdownattack.com        na
# 2  GTE Laboratories Incorporated        na
# 3  GTE Laboratories Incorporated        na
# 4  GTE Laboratories Incorporated        na

# %%
titles=df['title'][1].split()
df1.index
df3=df1.loc[titles[:],:]
x1=df3['x1'].min()
x4=df3['x4'].max()
y1=df3['y1'].min()
y2=df3['y2'].max()
x1,x4,y1,y2
pt_1=x1,y1
pt_2=x1,y2
pt_3=x4,y2
pt_4=x4,y1
print(pt_1,pt_2,pt_3,pt_4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-10f2e4eb4d57> in <module>()
#       1 titles=df['title'][1].split()
#       2 df1.index
# ----> 3 df3=df1.loc[titles[:],:]
#       4 x1=df3['x1'].min()
#       5 x4=df3['x4'].max()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1161                     result = self.obj._take(indexer[indexer != -1], axis=axis)
#    1162
# -> 1163                     self._validate_read_indexer(key, new_indexer, axis)
#    1164                     result = result._reindex_with_indexers(
#    1165                         {axis: [new_target, new_indexer]},
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: "None of [['Meltdown']] are in the [index]"

# %%
# import pandas as pd
# df = pd.read_excel("dataframe.xlsx")
# df

# %%
# counter=0

# for x in df['year']:
#     df['year'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
#     print(df['year'][counter])
#     counter = counter+1

# %%
# counter=0

# for x in df['title']:
#     df['title'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
#     print(df['title'][counter])
#     counter = counter+1

# %%
# counter=0

# for x in df['doi']:
#     df['doi'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
#     print(df['doi'][counter])
#     counter = counter+1

# %%
# counter=0

# for x in df['journal']:
#     df['journal'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
#     print(df['journal'][counter])
#     counter = counter+1

# %%
# counter=0

# for x in df['publisher']:
#     df['publisher'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
#     print(df['publisher'][counter])
#     counter = counter+1

# %%
# df=df.replace('',"na")

# %%
import re
from docx import Document

text_to_replace = "Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran."
temp = ""


def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        print("####################")
        if text_to_replace in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if text_to_replace in temp:
                    temp = temp.replace(text_to_replace, "GEEKS")
                    #print(temp)
                    inline[i].text=temp
        for i in range(len(inline)):
            print(inline[i].text)
        #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = r"fgfghhytjyukiuoo8"


ilename = "1181.docx"
doc = Document(filename)
docx_replace_regex(doc, text_to_replace , replace1, temp)
doc.save('452885e.docx')
# Out:
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Uli Meyer Uli Meyer
# ####################
# ####################
# Ingo Schulz-Schaeffer
# ####################
# ####################
# Drei Formen interpretativer Flexibilität
# ####################
# ####################
# Technical University Technology Studies
# ####################
# ####################
# Working Papers
# ####################
# ####################
# TUTS-WP-1-2005
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################

# %%
############ PAPER 10939


import re
from docx import Document

text_to_replace1 = "Marion Linke Sonderegger"
replace1 = "David Beech, Cetin Ozbutun"


text_to_replace2 = "Optionserweiterungen und Geschlechterrollen in der"
replace2 = ""

text_to_replace3 = "Mehr als nur staatliche Kinderbetreuung"
replace3 = "Object Oriented DBMS as a Generalization of Relational DBMS"

text_to_replace5 = "aktuellen dänischen Familienpolitik"
replace5 = ""

text_to_replace6 = "ZeS-Arbeitspapier Nr. 07/2004"
replace6 = "ANSI X3H2"

#text_to_replace7 = "aktuellen dänischen Familienpolitik"
#replace7 = ""


temp = ""


def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        print("####################")
        if regex in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if regex in temp:
                    temp = temp.replace(regex, replace)
                    #print(temp)
                    inline[i].text=temp        
        
        for i in range(len(inline)):
            print(inline[i].text)
            

        #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = "AAAAAAAAAAAAAAA"


filename = "10939.docx"
doc = Document(filename)
docx_replace_regex(doc, text_to_replace1 , replace1, temp)
docx_replace_regex(doc, text_to_replace2 , replace2, temp)
docx_replace_regex(doc, text_to_replace3 , replace3, temp)
#docx_replace_regex(doc, text_to_replace4 , replace4, temp)
docx_replace_regex(doc, text_to_replace5 , replace5, temp)
docx_replace_regex(doc, text_to_replace6 , replace6, temp)
#docx_replace_regex(doc, text_to_replace7 , replace7, temp)
doc.save('10939e.docx')
# Out:
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# David Beech, Cetin Ozbutun
# ####################
# ####################
# Mehr als nur staatliche Kinderbetreuung
# ####################
# ####################
# Optionserweiterungen und Geschlechterrollen in der
# ####################
# ####################
# aktuellen dänischen Familienpolitik
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail
# : marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# David Beech, Cetin Ozbutun
# ####################
# ####################
# Mehr als nur staatliche Kinderbetreuung
# ####################
# ####################
#
# ####################
# ####################
# aktuellen dänischen Familienpolitik
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail
# : marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# David Beech, Cetin Ozbutun
# ####################
# ####################
# Object Oriented DBMS as a Generalization of Relational DBMS
# ####################
# ####################
#
# ####################
# ####################
# aktuellen dänischen Familienpolitik
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail
# : marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# David Beech, Cetin Ozbutun
# ####################
# ####################
# Object Oriented DBMS as a Generalization of Relational DBMS
# ####################
# ####################
#
# ####################
# ####################
#
# ####################
# ####################
# ####################
# ZeS-Arbeitspapier Nr. 07/2004
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail
# : marion.linke@sfb597.uni-bremen.de
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# David Beech, Cetin Ozbutun
# ####################
# ####################
# Object Oriented DBMS as a Generalization of Relational DBMS
# ####################
# ####################
#
# ####################
# ####################
#
# ####################
# ####################
# ####################
# ANSI X3H2
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# ####################
# Zentrum für Sozialpolitik
# ####################
# Universität Bremen
# ####################
# Parkallee 39
# ####################
# D-28209 Bremen
# ####################
# eMail
# : marion.linke@sfb597.uni-bremen.de

# %%
############ PAPER 1181 FINAL  ####################

import re
from docx import Document

temp = ""
def docx_replace_regex(doc_obj, regex , replace, temp):
    for p in doc_obj.paragraphs:
        #print(p.text)
        inline = p.runs
        #print("####################")
        if regex in p.text:
            #inline = p.runs
            #print(inline)
            # Loop added to work with runs (strings with same style)
            for i in range(len(inline)):  
                
                temp = temp + inline[i].text
                #print(temp)
                if regex in temp:
                    if replace=="na":
                        #print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                        continue 
                    else:
                        temp = temp.replace(regex, replace)
                        #print(temp)
                        inline[i].text=temp        
        
#         for i in range(len(inline)):
#             print(inline[i].text)
  
def printf (doc_obj):
    
    for p in doc_obj.paragraphs:
        if p.text=='':
            continue
        else:
            print(p.text)
            #print(p.text)
       
        #try:
            #print(inline[0].text)
        #except:
        #    continue
    print(" \n ############################################################################# \n")

    
    
    
text_to_replace1 = "Uli Meyer Uli Meyer"
text_to_replace2 = "Ingo Schulz-Schaeffer"
text_to_replace3 = "Drei Formen interpretativer Flexibilität"
text_to_replace4 = "Technical University Technology Studies"
text_to_replace5 = "Working Papers"
text_to_replace6 = "TUTS-WP-1-2005"

count=0
number=0
stopnumber=0
for row in df.index:

    replace1 = df['author'][count]
    replace2 = ""
    replace3 = df['title'][count]
    replace4 = ""
    replace5 = df['journal'][count]
    replace6 = ""
    #print(replace1)
    count=count+1
    
    
    
    filename = "1181.docx"
    doc = Document(filename)
    docx_replace_regex(doc, text_to_replace1 , replace1, temp)
    docx_replace_regex(doc, text_to_replace2 , replace2, temp)
    docx_replace_regex(doc, text_to_replace3 , replace3, temp)
    docx_replace_regex(doc, text_to_replace4 , replace4, temp)
    docx_replace_regex(doc, text_to_replace5 , replace5, temp)
    docx_replace_regex(doc, text_to_replace6 , replace6, temp)
    
    printf (doc)
    
    print(" \n ---------------------------------------------------------------------------------------- \n")

    doc.save('1181_' + str(number) +  '.docx')
    number = number+1
    stopnumber=stopnumber+1
#     if stopnumber==10:
#         break

    
#regex1 = re.compile(r"Der vorliegende Bericht befaßt sich exemplarisch mit Techniken der Machteroberung und Machtbehauptung der russischen/sowjetischen Kommunisten seit der Oktoberrevolution von 1917 sowie mit Bestrebungen, aus der kommunistischen Bewegung heraus reformorientierte Gegenbewegungen zu bilden. Dabei wird an einigen Punkten versucht, Querverbindungen zu der aus Ruinen auferstandenen KP Rußlands unter Sjuganow zu ziehen. Die Analyse stützt sich auf Originalquellen der betroffenen Parteien und zieht darüber hinaus Beiträge vornehm-lich russischer und deutscher Spezialisten heran.")
#replace1 = "AAAAAAAAAAAAAAA"


# filename = "1181.docx"
# doc = Document(filename)
# docx_replace_regex(doc, text_to_replace1 , replace1, temp)
# docx_replace_regex(doc, text_to_replace2 , replace2, temp)
# docx_replace_regex(doc, text_to_replace3 , replace3, temp)
# docx_replace_regex(doc, text_to_replace4 , replace4, temp)
# docx_replace_regex(doc, text_to_replace5 , replace5, temp)
# docx_replace_regex(doc, text_to_replace6 , replace6, temp)

# doc.save('1181e.docx')
# Out:
# Paul Kocher, Daniel Genkin, Daniel Gruss, Werner Haas, Mike Hamburg, Moritz Lipp, Stefan Mangard, Thomas Prescher , Michael Schwarz , Yuval Yarom
# Spectre Attacks: Exploiting Speculative Execution.
# meltdownattack.com
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Moritz Lipp, Michael Schwarz , Daniel Gruss, Thomas Prescher , Werner Haas, Stefan Mangard, Paul Kocher, Daniel Genkin, Yuval Yarom, Mike Hamburg
# Meltdown
# meltdownattack.com
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# An Evaluation of Object-Oriented DBMS Developments: 1994 Edition.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael L. Brodie, Michael Stonebraker
# DARWIN: On the Incremental Migration of Legacy Information Systems
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Mark F. Hornick, Joe D. Morrison, Farshad Nayeri
# Integrating Heterogeneous, Autonomous, Distributed Applications Using the DOM Prototype.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# Object Model Capabilities For Distributed Object Management.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# Integrating Object-Oriented Applications and Middleware with Relational Databases.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Alejandro P. Buchmann, M. Tamer Özsu, Dimitrios Georgakopoulos
# Towards a Transaction Management System for DOM.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola, Sandra Heiler
# A RISC Object Model for Object System Interoperation: Concepts and Applications.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# MetaObject Protocol Concepts for a RISC Object Model.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# Object Data Language Facilities for Multimedia Data Types.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola, Mark F. Hornick, Alejandro P. Buchmann
# Object Data Model Facilities for Multimedia Data Types.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Frank Manola
# Distributed Object Management Technology.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Farshad Nayeri, Benjamin Hurwitz
# Experiments with Dispatching in a Distributed Object System.
# GTE Laboratories Incorporated
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Stonebraker
# Muffin: A Distributed Database Machine
# University of California at Berkeley
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# David Beech, Cetin Ozbutun
# Object Oriented DBMS as a Generalization of Relational DBMS
# ANSI X3H2
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Krishna G. Kulkarni, Jim Melton, Jonathan Bauer, Mike Kelley
# Inheritance for ADTs (revised)
# ANSI X2H2
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Phil Shaw
# Modification of User Defined Types
# ANSI X3H2
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jim Melton, Jonathan Bauer, Krishna G. Kulkarni
# Object ADTs (with improvements for Value ADTs)
# ANSI X3H2
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# David Beech
# Unification of Value and Object ADTs
# ANSI X3H2
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rolf Sander
# Die Repräsentation räumlichen Wissens und die Behandlung von Einbettungsproblemen mit Quadtreedepiktionen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Thomas Ludwig
# Algebraical Optimization of FTA-Expressions
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Werner Emde, Claus-Rainer Rollinger
# Wissensrepräsentation und Maschinelles Lernen
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Udo Pletat, Hans Uszkoreit
# An Algebraic Characterization of STUF
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ulrike Rackow, Ido Dagan, Ulrike Schwall
# A Combined Symbolic-Empirical Apprach for the Automatic Translation of Compounds
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Brigitte Bartsch-Spörl
# Zur Systemarchitektur von LILOG
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Erich Gehlen, Burkhard Kehrbusch
# Mengenorientierte Auswertung von Anfragen in der Logikprogrammiersprache PROLOG
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Markus Höhfeld, Gert Smolka
# Definite Resolution over Constraint Languages
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Birgit Wesche
# Dokumentation der Syntax der LILOG-Grammatik
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# Christopher Habel
# Cognitive Linguistics: The Processing of Spatial Concepts
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Thomas Ludwig , Bernd Walter, Michael Ley, Albert Maier, Erich Gehlen
# LILOG-DB: Database Support for Knowledge-Based Systems
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Thomas Ludwig , Stefan Benzschawel, Erich Gehlen
# Differential Closure Computation for General Horn-Clause Queries
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Uli Meyer Uli Meyer
# SQL/Data System for VSE: A Relational Data System for Application Development.
# IBM Publication
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Egon Börger
# A Logical Operational Semantics of Full Prolog
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Ley
# Ein Fact Manager zur persistenten Speicherung variabel strukturierter komplexer Objekte
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Roland Seiffert
# How could a good system of practical NLP look like?
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gisela Schöpke
# Möglichkeiten des Einsatzes eines dreiwertigen Theorembeweisers
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan Böttcher
# Attribute Inheritance Implemented on Top of a Relational Database System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ulrike Schwall
# LMT - Machine Translation Demonstration
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rudi Studer, Bernd Walter
# Implementation Aspects of a Natural Language Understanding System in a Prolog/DB Environment
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Albert Maier, Michael Ley, Erich Gehlen
# Sort Processing in a Deductive Database System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Thomas Ludwig , Bernd Walter
# EFTA: A Database Retrieval Algebra for Feature Terms
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Toni Bollinger, Udo Pletat
# Knowledge in Operation
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle
# An Overview on Planning Applications in PROTOS-L
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Carola Eschenbach
# Über Ansätze zur Darstellung von Konzepten und Prototypen
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Manfred Schmidt-Schauß, Gert Smolka
# Attributive Concept Descriptions with Unions and Complements
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Hans-Joachim Goltz
# Ein praktischer Algorithmus für die E-Unifikation
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Claus-Rainer Rollinger
# Simulation Sprachlichen Verstehens: Generelle Probleme bei der semantischen Interpretation der natürlichen Sprache
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Otthein Herzog
# The Institute for Knowledge Based Systems in the IBM Germany Scientific Center
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Bernhard Beckert
# Konzeption und Implementierung von Gleichheit für einen tableau-basierten Theorem-Beweiser
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Stefan Böttcher
# PROTOS-L: Towards a Knowledge Base Programming Language
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan J. Schierholz
# Syntaktische Informationseinheiten zu deutschen Adjektiven
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Udo Pletat
# On the Interpretation of Equality, Sorts, and Logic Programming
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Birgit Wendholt
# DInG - ein Domänen-orientierter Inkrementeller und Integrierter Generator für kohärente Texte
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gudrun Klose
# Prozedurale Semantik. Repräsentation der Sprechergegenwart.
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Herweg, Mohammed Nadjib Khenkhar, Simone Pribbenow, Klaus Rehkämper
# Elsaß-Wanderung für Linguisten: Exemplarische Analyse und Repräsentation eines Satzes aus einer Reisebeschreibung
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Anja Theuner
# Dictionary Dialog - Entwurf des Funktionsumfangs für eine Benutzerschnittstelle eines integrierten maschinellen/maschinenunterstützten Übersetzungssystems und prototypische Erstellung der Bildschirmfolge für die Funktion Semantische Relation
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Brigitte Bartsch-Spörl
# Zur Behandlung komplexer Objekte in LILOG
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# Peter H. Schmitt
# Computational aspects of three-valued logic
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Udo Pletat
# Semantics of Logic Programs with Equational Abstract Data Type Specifications
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Claudia Maienborn
# Processing Spatial Knowledge in LILOG
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Brigitte Bläser, Ulrike Schwall, Angelika Storrer
# A Reusable Lexical Database Tool for Machine Translation
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Esther König
# Der Lambek-Kalkül. Eine Logik für lexikalische Grammatiken
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Claudia Mrotzek
# Parenthetische Konstruktionen des Deutschen.
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Birgit Wesche
# Symmetric Coordination: An Alternative Theory of Phrase Structure
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan Börner, Rudi Studer
# An Approach to Manage Large Inheritance Networks
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Lutz Voelkel
# On the Problem of Masking Special Errors by Serial Signature Analysis
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter H. Schmitt
# Eine dreiwertige Logik zur Verarbeitung partieller Information
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan Böttcher
# An Inference Engine for Function Free Logic Programs
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Kai-Uwe Carstensen
# Aspekte der Generierung von Wegbeschreibungen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ulrike Weiland, Martin Hübner
# Das Projekt EXCEPT: Expert-System for Computer-Aided Environmental Planning Tasks
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Egon Börger, Peter H. Schmitt
# A Formal Operational Semantics for PROLOG III: Using Dynamic Algebras
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Czymmeck
# Subsumtion für eine erweiterte attributive Sortenbeschreibungssprache
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Tarnowski
# Mathematische Grundlagen der formalen Linguistik - Ein Kompendium
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Helmar Gust, Petra Ludewig, Mechthild Rickheit
# Die Struktur des Lexikons für LILOG
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Martin Hübner, Kai von Luck, Ulrike Weiland
# Die Konzeption des EXCEPT-Systems: Ein Überblick
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Elisabeth Neugebauer
# Richtungsangabe oder Wegkonnektor? Rämliches Zurück und seine Semantik
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Mohammed Nadjib Khenkhar
# Vorüberlegungen zur depiktionalen Repräsentation räumlichen Wissens
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Sitaram Lanka, Eric Mays
# Fully Persistent B
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Petra Maier
# Der modale Infinitiv: Syntaktische oder lexikalische Beschreibung?
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michel E. Adiba, Bruce G. Lindsay
# Database Snapshots.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Birgit Wesche
# At Ease with AT
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan Börner
# Datenbankunterstützung für wissensbasierte Systeme
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gudrun Klose, Ewald Lang, Thomas Pirlein
# Die Ontologie und Axiomatik der Wissensbasis von LEU/2 - Erfahrungen, Probleme, Ausblicke
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gerd Kortüm
# Temporales Schließen in einem natürlichsprachlichen System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ipke Wachsmuth
# Zur intelligenten Organisation von Wissensbeständen in künstlichen Systemen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Udo Pletat, Christoph Beierle
# The Semantics of Asserting and Retracting Clauses to Logic Programs
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Egon Börger
# Correctness Proof for the WAM
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Birgit Wesche, Ingrid Renz
# Word Order and Focus Projection
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# Kai von Luck
# KL-ONE: Eine Einführung
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan Böttcher
# Improving the Concurrency of Integrity Checks and Write Operations
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Noam Paz
# Über Vergleichskonstruktionen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Kurt Eberle
# Ereignisse: Ihre Logik und Ontologie aus textsemantischer Sicht
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Ley, Bernd Walter
# Der LILOG-DB Fact Manager: Ein Datenbankkern zur Speicherung variabel strukturierter komplexer Objekte
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Uli Meyer Uli Meyer
# Wissensbasierte Systeme in der Medizin: GMDS/GI, Abstracts des 1. gemeinsamen Workshops der AG Expertensysteme der GMDS und der FG Diagnostik und Klassifikation im GI-Fachausschuß 1.5, 29.-30. März 1990, Heidelberg
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gregor Erbach
# An Environment for Experimentation with Parsing Strategies
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christos Garidis
# Logisches Clustering von PROTOS-L Prozeduren
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jennifer Brundage, Maren Kresse, Ulrike Schwall, Angelika Storrer
# Multiword Lexemes: A Monolingual and Contrastive Typology for NLP and MT
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Toni Bollinger
# A Model Elimination Calculus for Generalized Clauses
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan J. Schierholz, Eric Windisch
# Quantitative Analysen zu Wörterbüchern
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gregor Erbach
# Lexical Representation of Idioms
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Toni Bollinger, Udo Pletat
# The LILOG Knowledge Representation System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter Gerstl
# Mengenkonzepte in Unifikationsgrammatiken
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Dines Bjørner, E. F. Codd, Kenneth L. Deckert, Irving L. Traiger
# The Gamma-0 n-ary Relational Data Base Interface Specifications of Objects and Operations.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ulrike Rackow
# On the Treatment of Compounds in Machine Translation. A Study
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Claudia Maienborn
# Position und Bewegung: Zur Semantik lokaler Verben
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Sonja Müller
# Zur Systematik morphologischer Paradigmen: Die deutschen Verben in der Computermorphologie
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Egon Börger
# A WAM Extension for Type-Constraint Logic Programming: Specification and Correctness Proof
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rolf Mayer
# Domain Restriction and Other Kinds of Reference Set Operations in Sentence and Discourse Semantics.
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Uli Meyer Uli Meyer
# Umweltbewertung mit EXCEPT: Darstellung aus ökologischer Sicht
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rüdiger Wirth
# Lernverfahren zur Vervollständigung von Hornklauselmengen durch inverse Resolution
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Holger M. Wittmann
# Ein Beispiel zur wissensbasierten Produktionsplanung mit PROTOS-L.
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Mechthild Rickheit
# Zum Begriff Argumentstruktur im Rahmen generativer worbildungstheoretischer Ansätze
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jan Wilms
# Standards für das Programmieren in Prolog für LILOG, Version 2.0
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Ley
# The Term Retrieval Abstract Machine
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Kai Lebeth, Bernd Abb
# Syntaktische Analysevorschläge zur Behandlung von lokalen Präfixverben in einem System für die Generierung von Wegbeschreibungen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gert Smolka
# Feature Constraint Logics for Unification Grammars
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jörg Heinrich
# Ein Transaktionskonzept für LILOG
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Andreas Eisele , Jochen Dörre
# Disjunctive Unification
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rainer Bäuerle
# Ereignisse und Repräsentationen
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Sven Lorenz
# On the Role of Reasoning about Change in the Projection of Presuppositions
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Egon Börger
# A Logical Operational Semantics of Full Prolog Part II: Built-in Predicates for Database Manipulations
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Thomas Ludwig
# A Brief Overlook of LILOG-DB
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Klein
# Leistungsanalyse des Datenbanksystems LILOG-DB
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd, Robert S. Arnold, Jean-Marc Cadiou, Chin-Liang Chang, Nick Roussopoulos
# RENDEZVOUS Version 1: An Experimental English Language Query Formulation System for Casual Users of Relational Data Bases.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Tibor Kiss
# Modals and the Scope of Negation, On the Treatment of Optionality in HPSG, Some Properties of Negation in German.
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter H. Schmitt, Wolfgang Wernecke
# Tableau Calculus for Order Sorted Logic
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Roland Seiffert
# Parsingstrategien für Unifikationsgrammatiken mit ID/LP-Regeln
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Albert Maier
# Sort-Lattice Management in LILOG-DB
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jochen Dörre, Roland Seiffert
# Sorted Feature Terms and Relational Dependencies
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Toni Bollinger, Ulrich Hedtstück, Claus-Rainer Rollinger
# Reasoning for Text Understanding - Knowledge Processing in the 1st LILOG-Prototype
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Petra Maier, Petra Steffens
# Zur Syntax pränominaler Elemente in einer kategorialen Unifikationsgrammatik des Deutschen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Helmar Gust, Manfred Grothaus
# Wissensbasisverwaltung für LILOG
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Esther König
# How to Fit the Lambek Calculus into the Chomsky Hierarchy
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Karin Klabunde
# Erweiterung der Wissensrepräsentationssprache L-LILOG um Konstrukte zur Spezifikation von Kontrollinformation
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Karl Dotzek
# Strategien zur Pronominalisierung
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Sai Choi Kwan, H. Raymond Strong
# Index Path Length Evaluation for the Research Storage System of System R.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan J. Schierholz
# Der Film öded das Publikum - Zum Aufbau eines maschinenlesbaren Wörterbuchs für deutsche Verben
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Roland Seiffert
# Operationen in erweiterten Typunifikationsformalismen
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Kai-Uwe Carstensen
# WebS - ein System zur Generierung von Wegbeschreibungen
# LILOG-Memo
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Nikolaus Ott
# Statistische Untersuchungen an einsprachigen Zeitungstexten
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Uli Meyer Uli Meyer
# International Workshop on Terminological Logics - Proceedings
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Otthein Herzog, Claus-Rainer Rollinger, Peter H. Schmitt, Petra Steffens, Rudi Studer, Birgit Wesche, Brigitte Bartsch-Spörl, F. Günthner, Christopher Habel, Siegfried Kanngießer, Christian Rohrer
# LILOG - Linguistische und logische Methoden für das maschinelle Verstehen des Deutschen - Projektbeschreibung
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter H. Schmitt
# Mathematical Logic and Artificial Intelligence
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan J. Schierholz
# Syntaktische Merkmale deutsche Substantive
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Elisabeth Breidt
# Die Behandlung von mehrdeutigen Verben in der Maschinellen Übersetzung
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Oliver Wauschkuhn
# Untersuchung zur verteilten Produktionsplanung mit Methoden der logischen Programmierung
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Angi Voß
# Stepwise Software Development with Algebraic Specifications
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# Christoph Beierle
# Types, Modules and Databases in the Logic Programming Language PROTOS-L
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Jochen Dörre, Udo Pletat, Claus-Rainer Rollinger, Peter H. Schmitt, Rudi Studer
# The Knowledge Representation Language L
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Kurt Eberle
# Eine Prolog-Theorie für zeitliche Beziehungen zwischen Ereignissen
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jochen Dörre, Ingo Raasch
# The Stuttgart Type Unification Formalism - User Manual
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Claudia Maienborn
# Lokale Verben und Präpositionen: Semantische und konzeptuelle Verarbeitung in LEU II
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Bernd I. Dahn, Theodor Lettmann, Wolfgang Schönfeld
# ILFA Interface Concept
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Irving L. Traiger, Jim Gray , Cesare A. Galtieri, Bruce G. Lindsay
# Transactions and Consistency in Distributed Database Systems.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Udo Pletat, Kai von Luck
# Knowledge Representation in LILOG
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Egon Börger
# A Logical Operational Semantics of Full Prolog Part III: Built-in Predicates for Files, Terms, Arithmetic and Input-Output
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Lingenfelder, Astrid Schmücker-Schend
# Using Knowledge-Based Methods to Administrate an Access Control System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Simone Pribbenow
# Zur Verarbeitung von Lokalisierungsausdrücken in einem hybriden System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Joachim Maier
# Integration von Constraints in die L
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Klaus Rehkämper
# Mentale Bilder und Wegbedeutungen
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Hinrich Schütze
# Pluralbehandlung in natürlichsprachlichen Wissensverabeitungssystemen
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Beierle, Ulrich Hedtstück, Udo Pletat, Peter H. Schmitt, Jörg H. Siekmann
# An Order-Sorted Logic for Knowledge Representation Systems
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Petra Ludewig
# Incremental Vocabulary Extensions in Text Understanding Systems
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Sven Lorenz
# Persistence and Justified Causation: Some Remarks on Nonmonotonic Temporal Reasoning
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Stefan Böttcher, Christoph Beierle
# Database Support for the PROTOS-L System
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Herbert J. Leass
# Anaphora Resolution for Machine Translation: A Study
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ingrid Renz
# Koordination von nichtverbalen Satzkonstituenten
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Thomas Ludwig
# The Design and Implementation of TLPROLOG (V. 2.0) - Intermediate Report
# IWBS Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rudi Studer
# A Conceptual Model for Time
# LILOG-Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jan Wilms
# Standards für das Programmieren in Prolog für LILOG, Version 1.0
# LILOG-Memo
#
# ...
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Lothar Breuer
# On the GI/G/k Queue with Lebesgue-Dominated Inter-Arrival Time Distribution
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Richard Rödler
# A Phase Space Model for Spatial BMAPs
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Gianpiero Cabodi, Stefano Quer, Christoph Meinel, Harald Sack, Anna Slobodová, Christian Stangier
# Binary Decision Diagrams and the Multiple Variable Order Problem
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ditmar Erdmann
# A New Proof of the Beckenbach Inequalities
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Ruvimovich Davidson
# Primal-Dual Contraint Aggregation Method in Multistage Stochastic Programming
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Volker Schmidt, Peter Dierolf
# A Pre-Dual for the Convolution Algebra D(Gamma+)
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Dimitri Efrosinin, Lothar Breuer, Vladimir Rykov
# An Optimization Algorithm for the MAP/PH/K Queue with Heterogeneous Servers
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Martin Mundhenk
# Propositional Proofs and Their Complexity
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christopher Lusena, Judy Goldsmith, Martin Mundhenk
# Nonapproximability Results for Partially Observable Markov Decision Processes
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Lothar Breuer
# Spatial Queues with Infinitely Many Servers
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Paul B. Hermanns, Nguyen V. Thoai
# Method for Global Optimization of Class of Nonlinear Bilevel Programming Problems
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Meinel, Thorsten Theobald
# Local Encoding Transformations for Optimizing OBDD-Representations of Finite State Machines
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Reiner Horst, Nguyen V. Thoai
# A new Algorithm for Solving the General Quadratic Programming Problem
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# Markus R. Schmidt
# Dual Characterization of Super-Hedging Prices in a Currency Market with Proportional Transaction Costs
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Meinel
# Die Entwicklung der Informatik braucht Theorie und Praxis: Ein Fallbeispiel aus dem CAD-Schaltkreisentwurf
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Subhendu Bikash Hazra, Volker Schulz
# Simultaneous Pseudo-Timestepping for Aerodynamic Shape Optimization Problems with State Constraints
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jordan Gergov, Christoph Meinel
# Combinational Logic Verification with FBDDs
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Meinel, Christian Stangier
# Speeding Up Symbolic Model Checking by Accelerating Dynamic Variable Reordering
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Elena Dubrova, Harald Sack
# Probabilistic Verification of Multiple-Valued Functions
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Lothar Breuer
# From Markov Jump Processes to Inhomogeneous BMAPs
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter Dierolf
# The Structure Theorem for Linear Transfer Systems
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Alexander Kaplan, Rainer Tichatschke
# Proximal Point Methods in Examples
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph W. Keßler, Helmut Seidl
# ForkLight: A Control-Synchronous Parallel Programming Language
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Christoph Meinel, Harald Sack
# Improving XOR-Node Placement for (+)-OBDDs
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jochen Bern, Jordan Gergov, Christoph Meinel, Anna Slobodová
# Boolean Manipulation with Free BDDs - First Experimental Results
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter Gritzmann, Victor Klee
# Separation by Hyperplanes in Finite-Dimensional Vector Spaces Over Archimedean Ordered Fields
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# R. J. Gardner, Peter Gritzmann
# Successive Determination and Verification of Polytopes by their X-Rays
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Ulrich Hertrampf, Clemens Lautemann, Thomas Schwentick, Heribert Vollmer, Klaus W. Wagner
# On the Power of Polynomial Bit-Reductions
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Peter Gritzmann, Victor Klee, B. S. Tam
# Cross-Positive Matrices Revisited
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Dieter Baum
# Vom M/G/1- zum BMAP/G/1-Modell
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Markus Müller-Olm
# Precise Interprocedural Dependence Analysis of Parallel Programs
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Klaus Jansen, Petra Scheffler, Gerhard J. Woeginger
# The Disjoint Cliques Problem
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jens Hofmann
# Stability Conditions for the BMAP/G/1 Queue with Level Dependent Arrivals
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Klaus Jansen
# On the Complexity of a Licence Constrained Job Assignment Problem
# Universität Trier, Mathematik/Informatik, Forschungsbericht
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Jacques Wainer, Michael Eckmann, Siome Goldenstein, Anderson Rocha
# Differences in productivity and impact across the different computer science subareas.
# Technical Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Uli Meyer Uli Meyer
# The 1995 SQL Reunion: People, Project, and Politics, May 29, 1995.
# Digital System Research Center Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd
# Normalized Data Base Structure: A Brief Tutorial.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd
# Relational Completeness of Data Base Sublanguages.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Michael Ley
# DBLP: A WWW Bibliography on Databases and Logic Programming
# Compulog Newsletter
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
# E. F. Codd, C. J. Date
# Interactive Support for Non-Programmers: The Relational and Network Approaches.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd
# Data Base Sublanguage Founded on the Relational Calculus.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Rita Ley, Markus Casper, Hugo Hellebrand, Ralf Merz
# Catchment classification by runoff behaviour with self-organizing maps (SOM)
# Hydrology and Earth System Sciences
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Patrick A. V. Hall
# Common Subexpression Identification in General Algebraic Systems.
# Technical Rep. UKSC 0060, IBM United Kingdom Scientific Centre
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd
# Further Normalization of the Data Base Relational Model.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd
# Derivability, Redundancy and Consistency of Relations Stored in Large Data Banks.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Markus Tresch
# Principles of Distributed Object Database Languages.
# ETH Zurich, Department of Computer Science / Technical Report
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# E. F. Codd
# The Capabilities of Relational Database Management Systems.
# Research Report / RJ / IBM / San Jose, California
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------
#
# Markus Casper, Gayane Grigoryan, Oliver Gronz, Oliver Gutjahr, Günther Heinemann, Rita Ley, Andreas Rock
# Analysis of projected hydrological behavior of catchments based on signature indices
# Hydrology and Earth System Sciences
#
#  #############################################################################
#
#
#  ----------------------------------------------------------------------------------------

# %%
########### dataframe cleaning and preprocessing complete ###########################
import pandas as pd
df = pd.read_excel("dataframe.xlsx")
df

counter=0
for x in df['author']:
    df['author'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['author'][counter])
    counter = counter+1
#df['author'][0].replace("[","").replace("'","").replace("]","")

counter=0
for x in df['year']:
    df['year'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").strip()
    #print(df['year'][counter])
    counter = counter+1
   
counter=0
for x in df['title']:
    df['title'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['title'][counter])
    counter = counter+1
    
counter=0
for x in df['doi']:
    df['doi'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['doi'][counter])
    counter = counter+1
      
counter=0
for x in df['journal']:
    df['journal'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['journal'][counter])
    counter = counter+1
    
counter=0
for x in df['publisher']:
    df['publisher'][counter]=x.replace("[","").replace("'","").replace("]","").replace("0001","").replace("0002","").replace('"',"").strip()
    #print(df['publisher'][counter])
    counter = counter+1
    
df=df.replace('',"na")
df
# Out:
#                                                 author year  \
# 0    Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...   na
# 1    Moritz Lipp, Michael Schwarz , Daniel Gruss, T...   na
# 2                                         Frank Manola   na
# 3               Michael L. Brodie, Michael Stonebraker   na
# 4     Mark F. Hornick, Joe D. Morrison, Farshad Nayeri   na
# ..                                                 ...  ...
# 559                                         E. F. Codd   na
# 560                                         E. F. Codd   na
# 561                                      Markus Tresch   na
# 562                                         E. F. Codd   na
# 563  Markus Casper, Gayane Grigoryan, Oliver Gronz,...   na
#
#                                                  title  \
# 0    Spectre Attacks: Exploiting Speculative Execut...
# 1                                             Meltdown
# 2    An Evaluation of Object-Oriented DBMS Developm...
# 3    DARWIN: On the Incremental Migration of Legacy...
# 4    Integrating Heterogeneous, Autonomous, Distrib...
# ..                                                 ...
# 559  Further Normalization of the Data Base Relatio...
# 560  Derivability, Redundancy and Consistency of Re...
# 561  Principles of Distributed Object Database Lang...
# 562  The Capabilities of Relational Database Manage...
# 563  Analysis of projected hydrological behavior of...
#
#                                                  doi  \
# 0              https://spectreattack.com/spectre.pdf
# 1            https://meltdownattack.com/meltdown.pdf
# 2    db/journals/gtelab/index.html#TR-0263-08-94-165
# 3    db/journals/gtelab/index.html#TR-0222-10-92-165
# 4    db/journals/gtelab/index.html#TR-0174-12-91-165
# ..                                               ...
# 559                                               na
# 560                                               na
# 561         https://doi.org/10.3929/ethz-a-006651652
# 562                                               na
# 563         https://doi.org/10.5194/hess-16-409-2012
#
#                                                journal publisher
# 0                                   meltdownattack.com        na
# 1                                   meltdownattack.com        na
# 2                        GTE Laboratories Incorporated        na
# 3                        GTE Laboratories Incorporated        na
# 4                        GTE Laboratories Incorporated        na
# ..                                                 ...       ...
# 559  Research Report / RJ / IBM / San Jose, California        na
# 560  Research Report / RJ / IBM / San Jose, California        na
# 561  ETH Zurich, Department of Computer Science / T...        na
# 562  Research Report / RJ / IBM / San Jose, California        na
# 563                Hydrology and Earth System Sciences        na
#
# [564 rows x 6 columns]

# %%
df['author'].replace('na','Thorsten Theobald, Christoph Meinel',inplace=True)

# %%
df['doi'].replace('na','db/journals/gtelab/index.html#TM-0332-11-90-165',inplace=True)

# %%
df['journal'].value_counts()
# Out:
# Universität Trier, Mathematik/Informatik, Forschungsbericht       294
# IWBS Report                                                       158
# LILOG-Report                                                       53
# Research Report / RJ / IBM / San Jose, California                  16
# GTE Laboratories Incorporated                                      12
# LILOG-Memo                                                         12
# ANSI X3H2                                                           4
# IBM Publication                                                     3
# meltdownattack.com                                                  2
# Hydrology and Earth System Sciences                                 2
# ETH Zurich, Department of Computer Science / Technical Report       1
# Digital System Research Center Report                               1
# Technical Rep. UKSC 0060, IBM United Kingdom Scientific Centre      1
# Technical Report                                                    1
# Research Report / G / IBM / Cambridge Scientific Center             1
# Compulog Newsletter                                                 1
# ANSI X2H2                                                           1
# University of California at Berkeley                                1
# Name: journal, dtype: int64

# %%
df
# Out:
#                                                 author year  \
# 0    Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...   na
# 1    Moritz Lipp, Michael Schwarz , Daniel Gruss, T...   na
# 2                                         Frank Manola   na
# 3               Michael L. Brodie, Michael Stonebraker   na
# 4     Mark F. Hornick, Joe D. Morrison, Farshad Nayeri   na
# ..                                                 ...  ...
# 559                                         E. F. Codd   na
# 560                                         E. F. Codd   na
# 561                                      Markus Tresch   na
# 562                                         E. F. Codd   na
# 563  Markus Casper, Gayane Grigoryan, Oliver Gronz,...   na
#
#                                                  title  \
# 0    Spectre Attacks: Exploiting Speculative Execut...
# 1                                             Meltdown
# 2    An Evaluation of Object-Oriented DBMS Developm...
# 3    DARWIN: On the Incremental Migration of Legacy...
# 4    Integrating Heterogeneous, Autonomous, Distrib...
# ..                                                 ...
# 559  Further Normalization of the Data Base Relatio...
# 560  Derivability, Redundancy and Consistency of Re...
# 561  Principles of Distributed Object Database Lang...
# 562  The Capabilities of Relational Database Manage...
# 563  Analysis of projected hydrological behavior of...
#
#                                                  doi  \
# 0              https://spectreattack.com/spectre.pdf
# 1            https://meltdownattack.com/meltdown.pdf
# 2    db/journals/gtelab/index.html#TR-0263-08-94-165
# 3    db/journals/gtelab/index.html#TR-0222-10-92-165
# 4    db/journals/gtelab/index.html#TR-0174-12-91-165
# ..                                               ...
# 559  db/journals/gtelab/index.html#TM-0332-11-90-165
# 560  db/journals/gtelab/index.html#TM-0332-11-90-165
# 561         https://doi.org/10.3929/ethz-a-006651652
# 562  db/journals/gtelab/index.html#TM-0332-11-90-165
# 563         https://doi.org/10.5194/hess-16-409-2012
#
#                                                journal publisher
# 0                                   meltdownattack.com        na
# 1                                   meltdownattack.com        na
# 2                        GTE Laboratories Incorporated        na
# 3                        GTE Laboratories Incorporated        na
# 4                        GTE Laboratories Incorporated        na
# ..                                                 ...       ...
# 559  Research Report / RJ / IBM / San Jose, California        na
# 560  Research Report / RJ / IBM / San Jose, California        na
# 561  ETH Zurich, Department of Computer Science / T...        na
# 562  Research Report / RJ / IBM / San Jose, California        na
# 563                Hydrology and Earth System Sciences        na
#
# [564 rows x 6 columns]
