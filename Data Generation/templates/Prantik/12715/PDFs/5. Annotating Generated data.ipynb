# %%
# importing dataframe.xlsx file

import pandas as pd
df = pd.read_excel("dataframe_gerabstract.xlsx")
df.head(2)
# Out:
#                                    author  \
# 0  Michael L. Brodie, Michael Stonebraker
# 1                            Frank Manola
#
#                                                title  \
# 0  DARWIN: On the Incremental Migration of Legacy...
# 1  Object Model Capabilities For Distributed Obje...
#
#                                          affiliation  \
# 0                    Hochschule Albstadt-Sigmaringen
# 1  Fachhochschule für Verwaltung und Dienstleistu...
#
#                                                email  \
# 0  michael_l._brodie@hochschule_albstadt_sigmarin...
# 1  frank_manola@fachhochschule_für_verwaltung_und...
#
#                                             abstract  year  \
# 0  befragungen von mitarbeitern der verwaltung ha...  1997
# 1  Acht Jahre nach der telefonischen Befragung vo...  2009
#
#                                              journal  \
# 0  ZA-Information / Zentralarchiv für Empirische ...
# 1                                   ZUMA Nachrichten
#
#                                          doi                   street  \
# 0  https://doi.org/10.1080/00036840701736115  Schoenebergerstrasse 79
# 1  https://doi.org/10.1080/00036840701736115     Oldesloer Strasse 32
#
#         city    zip
# 0  Stralsund  18412
# 1       Suhl  98501

# %%
df_en = pd.read_excel("dataframe_engabstract.xlsx")
df_en.head(2)
# Out:
#                                               author  \
# 0  Paul Kocher, Daniel Genkin, Daniel Gruss, Wern...
# 1  Moritz Lipp, Michael Schwarz , Daniel Gruss, T...
#
#                                                title  affiliation  \
# 0  Spectre Attacks: Exploiting Speculative Execut...    FH Aachen
# 1                                           Meltdown  RWTH Aachen
#
#                         email  \
# 0    paul_kocher@fh_aachen.de
# 1  moritz_lipp@rwth_aachen.de
#
#                                      German abstract  \
# 0  eines der gesichertsten ergebnisse empirischer...
# 1  in diesem beitrag werden die ursachen für die ...
#
#                                      EnglishAbstract  year  \
# 0  one of the soundest results of empirical socia...  1997
# 1  this article analyses the reasons for the enor...  1997
#
#                                              journal  \
# 0  ZA-Information / Zentralarchiv für Empirische ...
# 1  ZA-Information / Zentralarchiv für Empirische ...
#
#                                          doi            street       city  \
# 0  https://doi.org/10.1080/00036840701736115  Mühlenstrasse 65   Würzburg
# 1  https://doi.org/10.1080/00036840701736115   Chausseestr. 29  Pinneberg
#
#      zip
# 0  97001
# 1  25409

# %% [markdown]
# ##### Generate annotation JSONs

# %%
# run this file in the same folder where images and pdfs are placed
# change the file names to the templates you are working on, like here template is 10939, so just replace 10939


number=0
while True:

    
    names='12715_'+str(number)
    
    # change the number limit to number of files you are generating
    if number==2:
        break

    import pdfquery
    # loading a pdf
    pdf = pdfquery.PDFQuery(names+".pdf")
    pdf.load()
    # if you want, you can store the entire pdf as an xml file

    pdf.tree.write(names+".xml", pretty_print=True, encoding="utf-8")

    import xml.etree.ElementTree as ET
    tree = ET.parse(names+'.xml')
    root = tree.getroot()

   
    author=df['author'][number]
    title=df['title'][number]
    journal=df['journal'][number]
    #doi=df['doi'][number]
    date=df['year'][number]
    #affiliation=df['affiliation'][number]
    #email=df['email'][number]
    #address=df['address'][number]
    abstract=df['abstract'][number]
    engabstract=df_en['EnglishAbstract'][number]
    
    
    
    # create lists for all types of metadata bounding boxes 
    bounding_box_list=[]
    author_list=[]
    title_list=[]
    journal_list=[]
    #doi_list=[]
    date_list=[]
    #affiliation_list=[]
    #email_list=[]
    #address_list=[]
    abstract_list=[]
    engabstract_list=[]

    # parse xml 
    for child in root:
        print('START')
        print (child.tag,"----", child.attrib)
        
        
        for fchild in child:
            print (fchild.tag,"----", fchild.attrib)
            for ffchild in fchild:
                print (ffchild.tag,"----", ffchild.attrib)
                print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
                print(ffchild.text)
                #print(ffchild.attrib['x0'])
                
                try:
                    bounding_box_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                                    ffchild.attrib['y1']]])

                    if author in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>1:
                        author_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                                  ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in title and ffchild.text.strip() is not '' and len(ffchild.text.strip())>1:
                        title_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                                 ffchild.attrib['y1']]])
                    elif journal in ffchild.text.strip() and ffchild.text.strip() is not '' and len(ffchild.text.strip())>1:
                        journal_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                                   ffchild.attrib['y1']]])
    #                 elif ffchild.text.strip() in doi and ffchild.text.strip() is not '' and len(ffchild.text.strip())>6:
    #                     doi_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
    #                                                               ffchild.attrib['y1']]])
    #                 elif ffchild.text.strip() in email and ffchild.text.strip() is not '' and len(ffchild.text.strip())>6:
    #                     email_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
    #                                                               ffchild.attrib['y1']]])
    #                 elif ffchild.text.strip() in address and ffchild.text.strip() is not '' and len(ffchild.text.strip())>6:
    #                     address_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
    #                                                               ffchild.attrib['y1']]])
    #                 elif ffchild.text.strip() in affiliation and ffchild.text.strip() is not '' and len(ffchild.text.strip())>6:
    #                     affiliation_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
    #                                                               ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in abstract and ffchild.text.strip() is not '' and len(ffchild.text.strip())>6:
                         abstract_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                               ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in date and ffchild.text.strip() is not '' and len(ffchild.text.strip())>3:
                         date_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                                   ffchild.attrib['y1']]])
                    elif ffchild.text.strip() in engabstract and ffchild.text.strip() is not '' and len(ffchild.text.strip())>6:
                         engabstract_list.append([ffchild.text.strip(),[ffchild.attrib['x0'],ffchild.attrib['x1'],ffchild.attrib['y0'],
                                                                   ffchild.attrib['y1']]])
                except:
                    number=number+1
                    continue

                print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
            print('END')
            print('\n')

    coordinates_author = []
    coordinates_journal = []
    coordinates_title = []
    #coordinates_doi = []
    coordinates_abstract = []
    #coordinates_address = []
    #coordinates_email = []
    coordinates_date = []
    #coordinates_affiliation = []
    coordinates_engabstract = []
    print('Prantik',author_list)
    print('Prantik',title_list)
    print('Prantik',journal_list)
    print('Prantik',abstract_list)
    print('Prantik',date_list)
    print('Prantik',engabstract_list)

    lst1=[]
    lst2=[]
    lst3=[]
    lst4=[]
    print('Prantik',author_list)
    for lst in author_list:
        bboxes=lst[1]
        print('Prantik')
        print((bboxes))
        lst1.append([float(bboxes[0])])
        lst2.append([float(bboxes[1])])
        lst3.append([842-float(bboxes[2])])
        lst4.append([842-float(bboxes[3])])  
    apt1=[min(lst1)[0],min(lst4)[0]]
    apt2=[min(lst1)[0],max(lst3)[0]]
    apt3=[max(lst2)[0],max(lst3)[0]]
    apt4=[max(lst2)[0],min(lst4)[0]]
    coordinates_author.append([ apt1,apt2,apt3,apt4 ])  
    print('-----------')
    print(coordinates_author)

    tlst1=[]
    tlst2=[]
    tlst3=[]
    tlst4=[]
    for lst in title_list:
        bboxes=lst[1]
        print((bboxes))
        tlst1.append([float(bboxes[0])])
        tlst2.append([float(bboxes[1])])
        tlst3.append([842-float(bboxes[2])])
        tlst4.append([842-float(bboxes[3])])  
    tpt1=[min(tlst1)[0],min(tlst4)[0]]
    tpt2=[min(tlst1)[0],max(tlst3)[0]]
    tpt3=[max(tlst2)[0],max(tlst3)[0]]
    tpt4=[max(tlst2)[0],min(tlst4)[0]]
    coordinates_title.append([ tpt1,tpt2,tpt3,tpt4 ])  
    print('-----------')
    print(coordinates_title)

    jlst1=[]
    jlst2=[]
    jlst3=[]
    jlst4=[]
    for lst in journal_list:
        bboxes=lst[1]
        print((bboxes))
        jlst1.append([float(bboxes[0])])
        jlst2.append([float(bboxes[1])])
        jlst3.append([842-float(bboxes[2])])
        jlst4.append([842-float(bboxes[3])])  
    jpt1=[min(jlst1)[0]-10,min(jlst4)[0]]
    jpt2=[min(jlst1)[0]-10,max(jlst3)[0]]
    jpt3=[max(jlst2)[0],max(jlst3)[0]]
    jpt4=[max(jlst2)[0],min(jlst4)[0]]
    coordinates_journal.append([ jpt1,jpt2,jpt3,jpt4 ])  
    print('-----------')
    print(coordinates_journal)

    
#     for lst in doi_list:
#         bboxes=lst[1]
#         print((bboxes))
#         print('\n')
#         dpt1=[float(bboxes[0]),842-float(bboxes[3])]
#         dpt2=[float(bboxes[0]),842-float(bboxes[2])]
#         dpt3=[float(bboxes[1]),842-float(bboxes[2])]
#         dpt4=[float(bboxes[1]),842-float(bboxes[3])]
#         coordinates_doi.append([ dpt1,dpt2,dpt3,dpt4 ])
#     print('-----------')
#     print(coordinates_doi)
    
#     aflst1=[]
#     aflst2=[]
#     aflst3=[]
#     aflst4=[]
#     for lst in affiliation_list:
#         bboxes=lst[1]
#         print((bboxes))
#         aflst1.append([float(bboxes[0])])
#         aflst2.append([float(bboxes[1])])
#         aflst3.append([842-float(bboxes[2])])
#         aflst4.append([842-float(bboxes[3])])  
#     afpt1=[min(aflst1)[0],min(aflst4)[0]]
#     afpt2=[min(aflst1)[0],max(aflst3)[0]]
#     afpt3=[max(aflst2)[0],max(aflst3)[0]]
#     afpt4=[max(aflst2)[0],min(aflst4)[0]]
#     coordinates_affiliation.append([ afpt1,afpt2,afpt3,afpt4 ])  
#     print('-----------')
#     print(coordinates_affiliation)
    
    abslst1=[]
    abslst2=[]
    abslst3=[]
    abslst4=[]
    for lst in abstract_list:
        bboxes=lst[1]
        print((bboxes))
        abslst1.append([float(bboxes[0])])
        abslst2.append([float(bboxes[1])])
        abslst3.append([842-float(bboxes[2])])
        abslst4.append([842-float(bboxes[3])])  
    abspt1=[min(abslst1)[0],min(abslst4)[0]-5]
    abspt2=[min(abslst1)[0],max(abslst3)[0]]
    abspt3=[max(abslst2)[0],max(abslst3)[0]]
    abspt4=[max(abslst2)[0],min(abslst4)[0]-5]
    coordinates_abstract.append([ abspt1,abspt2,abspt3,abspt4 ])  
    print('-----------')
    print(coordinates_abstract)
    
#     adlst1=[]
#     adlst2=[]
#     adlst3=[]
#     adlst4=[]
#     for lst in address_list:
#         bboxes=lst[1]
#         print((bboxes))
#         adlst1.append([float(bboxes[0])])
#         adlst2.append([float(bboxes[1])])
#         adlst3.append([842-float(bboxes[2])])
#         adlst4.append([842-float(bboxes[3])])  
#     adpt1=[min(adlst1)[0]-10,min(adlst4)[0]]
#     adpt2=[min(adlst1)[0]-10,max(adlst3)[0]]
#     adpt3=[max(adlst2)[0],max(adlst3)[0]]
#     adpt4=[max(adlst2)[0],min(adlst4)[0]]
#     coordinates_address.append([ adpt1,adpt2,adpt3,adpt4 ])  
#     print('-----------')
#     print(coordinates_address)

    for lst in date_list:
        bboxes=lst[1]
        print((bboxes))
        print('\n')
        dapt1=[float(bboxes[0]),842-float(bboxes[3])]
        dapt2=[float(bboxes[0]),842-float(bboxes[2])]
        dapt3=[float(bboxes[1]),842-float(bboxes[2])]
        dapt4=[float(bboxes[1]),842-float(bboxes[3])]
        coordinates_date.append([ dapt1,dapt2,dapt3,dapt4 ])
    print('-----------')
    print(coordinates_date)

#     for lst in email_list:
#         bboxes=lst[1]
#         print((bboxes))
#         print('\n')
#         ept1=[float(bboxes[0]),842-float(bboxes[3])]
#         ept2=[float(bboxes[0]),842-float(bboxes[2])]
#         ept3=[float(bboxes[1]),842-float(bboxes[2])]
#         ept4=[float(bboxes[1]),842-float(bboxes[3])]
#         coordinates_email.append([ept1,ept2,ept3,ept4 ])
#     print('-----------')
#     print(coordinates_email)

    eabslst1=[]
    eabslst2=[]
    eabslst3=[]
    eabslst4=[]
    for lst in engabstract_list:
        bboxes=lst[1]
        print((bboxes))
        eabslst1.append([float(bboxes[0])])
        eabslst2.append([float(bboxes[1])])
        eabslst3.append([842-float(bboxes[2])])
        eabslst4.append([842-float(bboxes[3])])  
    eabspt1=[min(abslst1)[0],min(abslst4)[0]-5]
    eabspt2=[min(abslst1)[0],max(abslst3)[0]]
    eabspt3=[max(abslst2)[0],max(abslst3)[0]]
    eabspt4=[max(abslst2)[0],min(abslst4)[0]-5]
    coordinates_engabstract.append([ eabspt1,eabspt2,eabspt3,eabspt4 ])  
    print('-----------')
    print(coordinates_engabstract)


#    lst=[coordinates_author,coordinates_title,coordinates_journal,coordinates_doi,coordinates_address,coordinates_affiliation,coordinates_email,coordinates_abstract,coordinates_date]
    lst=[coordinates_author,coordinates_title,coordinates_journal,coordinates_abstract,coordinates_date,coordinates_engabstract]
    lst
    
   
    # create a list of all metadata bounding boxes and use in JSON as 'shapes' value
    # abase --> for authors, tbase --> for titles and so on

    abase = {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a1base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a2base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a3base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    a4base={
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "shape_type": "polygon", "flags": {}
        }
    tbase = {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t1base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t2base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t3base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t4base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t5base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t6base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t7base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    t8base={
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
           "shape_type": "polygon","flags": {}
        }
    jbase = {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j1base = {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    j2base = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
    j3base = {
      "label": "journal",
      "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
      "shape_type": "polygon","flags": {}
    }
    dbase = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    d1base = {
          "label": "doi",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    dabase = {
          "label": "date",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    da1base = {
          "label": "date",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    absbase = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs1base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs2base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs3base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs4base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs5base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs6base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs7base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs8base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs9base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs10base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs11base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs12base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs13base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs14base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs15base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs16base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs17base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs18base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs19base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs20base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    abs21base = {
          "label": "abstract",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    adbase = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ad1base = {
          "label": "address",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    afbase = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    af1base = {
          "label": "affiliation",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    ebase = {
          "label": "email",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    e1base = {
          "label": "email",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "shape_type": "polygon","flags": {}
        }
    
    
    ab=[abase,a1base,a2base,a3base,a4base]
    tb=[tbase,t1base,t2base,t3base,t4base,t5base,t6base,t7base,t8base]
    jb=[jbase,j1base,j2base,j3base]
    db=[dbase,d1base]
    dab=[dabase,da1base]
    absb=[absbase,abs1base,abs2base,abs3base,abs4base,abs5base,abs6base,abs7base,abs8base,abs9base,abs10base,abs11base,abs12base,abs13base,abs14base,abs15base,abs16base,abs17base,abs18base,abs19base,abs20base,abs21base]
    adb=[adbase,ad1base]
    afb=[afbase,af1base]
    eb=[ebase,e1base]
    

    
    liste=[]
    try:
        counter=0
        for no in range(len(coordinates_author)):   

            ab[counter]['points']=lst[0][counter]
            print(ab[counter])
            liste.append(ab[counter])
            counter=counter+1

        counter=0
        for no in range(len(coordinates_title)):   

            tb[counter]['points']=lst[1][counter]
            print(tb[counter])
            liste.append(tb[counter])
            counter=counter+1    

        counter=0
        for no in range(len(coordinates_journal)):   

            jb[counter]['points']=lst[2][counter]
            print(jb[counter])
            liste.append(jb[counter])
            counter=counter+1
        
#         counter=0
#         for no in range(len(coordinates_doi)):   

#             db[counter]['points']=lst[3][counter]
#             print(db[counter])
#             liste.append(db[counter])
#             counter=counter+1
        
#         counter=0
#         for no in range(len(coordinates_address)):   

#             adb[counter]['points']=lst[4][counter]
#             print(adb[counter])
#             liste.append(adb[counter])
#             counter=counter+1
        
#         counter=0
#         for no in range(len(coordinates_affiliation)):   

#             afb[counter]['points']=lst[5][counter]
#             print(afb[counter])
#             liste.append(afb[counter])
#             counter=counter+1
        
        counter=0
        for no in range(len(coordinates_date)):   

            dab[counter]['points']=lst[8][counter]
            print(dab[counter])
            liste.append(dab[counter])
            counter=counter+1
        
#         counter=0
#         for no in range(len(coordinates_email)):   

#             eb[counter]['points']=lst[6][counter]
#             print(eb[counter])
#             liste.append(eb[counter])
#             counter=counter+1
        
        counter=0
        for no in range(len(coordinates_abstract)):   

            absb[counter]['points']=lst[7][counter]
            print(absb[counter])
            liste.append(absb[counter])
            counter=counter+1
        
        counter=0
        for no in range(len(coordinates_engabstract)):   

            absb[counter]['points']=lst[7][counter]
            print(absb[counter])
            liste.append(absb[counter])
            counter=counter+1
            
    except:
        print('============================================================================')
        print(number)
        number=number+1
        continue

    import base64
    import json
    # get image data 
    file=names+".jpeg"
    image_data = base64.b64encode(open(file, "rb").read())
    imagedata=str(image_data)[1:].replace("'","")

    x ='''[{
      "version": "4.4.0",  "flags": {},

      "shapes": [
        {
          "label": "author",
          "points": [       [250,269],[250,283],[329,283],[329,269]         ],
          "group_id": null,"shape_type": "polygon", "flags": {}
        },

        {
          "label": "title",
          "points": [        [197,332],[197,350],[383,350],[383,332]      ],
          "group_id": null, "shape_type": "polygon","flags": {}
        },

        {
          "label": "journal",
          "points": [        [202,381],[202, 395],[378, 395],[378, 381]      ],
          "group_id": null,"shape_type": "polygon","flags": {}
        }  ],

      "imagePath": "10939.jpg",
      "imageData": "/9j",
      "imageHeight": 842,
      "imageWidth": 595
    }]'''

    try:
        info=json.loads(x)
        print('User count', len(info))
        print("-------------")
        
        # replace shapes value in x JSON 
        info[0]['shapes']=liste


        print(info[0]['shapes'])
        info[0]['imageData']=imagedata
        info[0]['imagePath']=file
        print("-------------------------------------------------------------------------------------------")




        #info[0]['shapes'][0]['points']=lst[0][0]
        #info[0]['shapes'][1]['points']=lst[1][0]
        #info[0]['shapes'][2]['points']=lst[2][0]
        #print(key['shapes'])
        #info[0]['imageData']=imagedata
        #print("-------------------------------------------------------------------------------------------")



        for key in info:
            my_details=key
        name=names+".json"
        with open(name, 'w') as json_file:
            json.dump(my_details, json_file)
    except:
        
        print('============================================================================')
        print(number)
        number=number+1
        continue
    
        

    print('============================================================================')
    print(number)
    number=number+1
# Out:
# START
# LTPage ---- {'y0': '0', 'y1': '657.6', 'x0': '0', 'x1': '442.08', 'width': '442.08', 'height': '657.6', 'bbox': '[0, 0, 442.08, 657.6]', 'pageid': '1', 'rotate': '0', 'page_index': '0', 'page_label': ''}
# LTRect ---- {'y0': '-184.55', 'y1': '657.6', 'x0': '0.0', 'x1': '595.45', 'width': '595.45', 'height': '842.15', 'bbox': '[0.0, -184.55, 595.45, 657.6]', 'linewidth': '0', 'pts': '[[0.0, -184.55], [595.45, -184.55], [595.45, 657.6], [0.0, 657.6]]'}
# LTTextLineHorizontal ---- {'y0': '589.948', 'y1': '601.948', 'x0': '350.59', 'x1': '362.47', 'width': '11.88', 'height': '12.0', 'bbox': '[350.59, 589.948, 362.47, 601.948]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineVertical ---- {'y0': '590.625', 'y1': '609.825', 'x0': '346.03', 'x1': '350.504', 'width': '4.474', 'height': '19.2', 'bbox': '[346.03, 590.625, 350.504, 609.825]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '580.108', 'y1': '599.745', 'x0': '62.424', 'x1': '315.758', 'width': '253.334', 'height': '19.637', 'bbox': '[62.424, 580.108, 315.758, 599.745]', 'index': '2'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineHorizontal ---- {'y0': '539.29', 'y1': '557.29', 'x0': '75.42', 'x1': '209.214', 'width': '133.794', 'height': '18.0', 'bbox': '[75.42, 539.29, 209.214, 557.29]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '477.11', 'y1': '536.65', 'x0': '62.424', 'x1': '245.624', 'width': '183.2', 'height': '59.54', 'bbox': '[62.424, 477.11, 245.624, 536.65]', 'index': '4'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '452.63', 'y1': '553.45', 'x0': '251.42', 'x1': '368.286', 'width': '116.866', 'height': '100.82', 'bbox': '[251.42, 452.63, 368.286, 553.45]', 'index': '5'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineVertical ---- {'y0': '331.823', 'y1': '385.868', 'x0': '227.16', 'x1': '233.243', 'width': '6.083', 'height': '54.045', 'bbox': '[227.16, 331.823, 233.243, 385.868]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '111.296', 'y1': '340.943', 'x0': '227.16', 'x1': '388.554', 'width': '161.394', 'height': '229.647', 'bbox': '[227.16, 111.296, 388.554, 340.943]', 'index': '8'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '311.038', 'y1': '340.703', 'x0': '57.144', 'x1': '216.963', 'width': '159.819', 'height': '29.665', 'bbox': '[57.144, 311.038, 216.963, 340.703]', 'index': '11'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '288.698', 'y1': '307.178', 'x0': '57.144', 'x1': '217.038', 'width': '159.894', 'height': '18.48', 'bbox': '[57.144, 288.698, 217.038, 307.178]', 'index': '13'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '266.378', 'y1': '284.858', 'x0': '57.144', 'x1': '217.072', 'width': '159.928', 'height': '18.48', 'bbox': '[57.144, 266.378, 217.072, 284.858]', 'index': '15'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '232.988', 'y1': '262.538', 'x0': '57.144', 'x1': '216.97', 'width': '159.826', 'height': '29.55', 'bbox': '[57.144, 232.988, 216.97, 262.538]', 'index': '16'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '210.668', 'y1': '229.148', 'x0': '57.144', 'x1': '217.124', 'width': '159.98', 'height': '18.48', 'bbox': '[57.144, 210.668, 217.124, 229.148]', 'index': '17'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '177.288', 'y1': '206.828', 'x0': '57.144', 'x1': '217.037', 'width': '159.893', 'height': '29.54', 'bbox': '[57.144, 177.288, 217.037, 206.828]', 'index': '20'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '154.968', 'y1': '173.448', 'x0': '57.144', 'x1': '216.955', 'width': '159.811', 'height': '18.48', 'bbox': '[57.144, 154.968, 216.955, 173.448]', 'index': '21'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '132.648', 'y1': '151.128', 'x0': '57.144', 'x1': '136.468', 'width': '79.324', 'height': '18.48', 'bbox': '[57.144, 132.648, 136.468, 151.128]', 'index': '23'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineHorizontal ---- {'y0': '143.688', 'y1': '151.128', 'x0': '101.754', 'x1': '192.537', 'width': '90.783', 'height': '7.44', 'bbox': '[101.754, 143.688, 192.537, 151.128]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineHorizontal ---- {'y0': '132.648', 'y1': '140.088', 'x0': '153.833', 'x1': '183.236', 'width': '29.403', 'height': '7.44', 'bbox': '[153.833, 132.648, 183.236, 140.088]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '132.648', 'y1': '151.128', 'x0': '200.839', 'x1': '217.05', 'width': '16.212', 'height': '18.48', 'bbox': '[200.839, 132.648, 217.05, 151.128]', 'index': '26'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextBoxHorizontal ---- {'y0': '110.298', 'y1': '128.808', 'x0': '57.144', 'x1': '216.911', 'width': '159.767', 'height': '18.51', 'bbox': '[57.144, 110.298, 216.911, 128.808]', 'index': '27'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineVertical ---- {'y0': '590.625', 'y1': '609.825', 'x0': '62.424', 'x1': '67.996', 'width': '5.572', 'height': '19.2', 'bbox': '[62.424, 590.625, 67.996, 609.825]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineHorizontal ---- {'y0': '610.108', 'y1': '622.108', 'x0': '57.144', 'x1': '60.144', 'width': '3.0', 'height': '12.0', 'bbox': '[57.144, 610.108, 60.144, 622.108]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineVertical ---- {'y0': '539.29', 'y1': '577.96', 'x0': '62.424', 'x1': '75.42', 'width': '12.996', 'height': '38.67', 'bbox': '[62.424, 539.29, 75.42, 577.96]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineVertical ---- {'y0': '400.268', 'y1': '454.058', 'x0': '57.144', 'x1': '60.144', 'width': '3.0', 'height': '53.79', 'bbox': '[57.144, 400.268, 60.144, 454.058]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTTextLineVertical ---- {'y0': '331.583', 'y1': '385.868', 'x0': '57.144', 'x1': '62.716', 'width': '5.572', 'height': '54.285', 'bbox': '[57.144, 331.583, 62.716, 385.868]', 'word_margin': '0.1'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTRect ---- {'y0': '358.9', 'y1': '425.7', 'x0': '56.75', 'x1': '385.5', 'width': '328.75', 'height': '66.8', 'bbox': '[56.75, 358.9, 385.5, 425.7]', 'linewidth': '0', 'pts': '[[56.75, 358.9], [385.5, 358.9], [385.5, 425.7], [56.75, 425.7]]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# LTRect ---- {'y0': '580.06', 'y1': '580.54', 'x0': '57.144', 'x1': '246.384', 'width': '189.24', 'height': '0.48', 'bbox': '[57.144, 580.06, 246.384, 580.54]', 'linewidth': '0', 'pts': '[[57.144, 580.06], [246.384, 580.06], [246.384, 580.54], [57.144, 580.54]]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTRect ---- {'y0': '580.06', 'y1': '580.54', 'x0': '246.38', 'x1': '246.86', 'width': '0.48', 'height': '0.48', 'bbox': '[246.38, 580.06, 246.86, 580.54]', 'linewidth': '0', 'pts': '[[246.38, 580.06], [246.86, 580.06], [246.86, 580.54], [246.38, 580.54]]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTRect ---- {'y0': '580.06', 'y1': '580.54', 'x0': '246.86', 'x1': '340.748', 'width': '93.888', 'height': '0.48', 'bbox': '[246.86, 580.06, 340.748, 580.54]', 'linewidth': '0', 'pts': '[[246.86, 580.06], [340.748, 580.06], [340.748, 580.54], [246.86, 580.54]]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTRect ---- {'y0': '580.06', 'y1': '580.54', 'x0': '340.75', 'x1': '341.23', 'width': '0.48', 'height': '0.48', 'bbox': '[340.75, 580.06, 341.23, 580.54]', 'linewidth': '0', 'pts': '[[340.75, 580.06], [341.23, 580.06], [341.23, 580.54], [340.75, 580.54]]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# LTRect ---- {'y0': '580.06', 'y1': '580.54', 'x0': '341.23', 'x1': '378.454', 'width': '37.224', 'height': '0.48', 'bbox': '[341.23, 580.06, 378.454, 580.54]', 'linewidth': '0', 'pts': '[[341.23, 580.06], [378.454, 580.06], [378.454, 580.54], [341.23, 580.54]]'}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# None
# END
#
#
# Prantik []
# Prantik []
# Prantik []
# Prantik []
# Prantik []
# Prantik []
# Prantik []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f9c61eb4f386> in <module>
#     138         lst3.append([842-float(bboxes[2])])
#     139         lst4.append([842-float(bboxes[3])])
# --> 140     apt1=[min(lst1)[0],min(lst4)[0]]
#     141     apt2=[min(lst1)[0],max(lst3)[0]]
#     142     apt3=[max(lst2)[0],max(lst3)[0]]
#
# ValueError: min() arg is an empty sequence

# %%
# DONE!
